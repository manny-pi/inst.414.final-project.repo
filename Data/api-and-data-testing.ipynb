# %% [markdown]
# ## This is a file to test methods on how to gather data using the "Original dataset" csv file that is in this Data folder.

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# # Read Kaggle dataset, and extract the ISBN 13 for all the books

# %%
kaggle_data = pd.read_csv("books.csv")  # read the Kaggle books dataset
isbn_13 = kaggle_data['isbn13']         # extract the ISBN-13 column

isbn_13.shape
# Out:
# (11127,)

# %%
isbn_13.head(5)
# Out:
# 0    9780439785969
# 1    9780439358071
# 2    9780439554893
# 3    9780439655484
# 4    9780439682589
# Name: isbn13, dtype: object

# %% [markdown]
# # Get the books from the Google Books API using the ISNB-13s

# %%
# create an empty list to store the book data
book_data_list = []
url_base = 'https://www.googleapis.com/books/v1/volumes?q=isbn:'

# iterate over the ISBN 13 numbers, and get the information we need using the Google Books API
for i, isbn in enumerate(isbn_13):

    # generate the URL for the Google Books API search 
    url = url_base + isbn

    # get the book data; convert it to a dictionary using .json()
    book_data = requests.get(url).json()

    print(f'{i} {isbn}: {book_data.keys()}', end=': ')
    
    if 'totalItems' in book_data and book_data['totalItems'] > 0:

        print(book_data['totalItems'], end=': ')
        print(book_data['items'][0]['volumeInfo']['title'], end='')
        # extract the relevant fields and create a new row in the DataFrame
        book = {
            'title': book_data['items'][0]['volumeInfo'].get('title', ''),
            'subtitle': book_data['items'][0]['volumeInfo'].get('subtitle', ''),
            'authors': book_data['items'][0]['volumeInfo'].get('authors', ''),
            'publisher': book_data['items'][0]['volumeInfo'].get('publisher', ''),
            'publishdate': book_data['items'][0]['volumeInfo'].get('publishedDate', ''),
            'description': book_data['items'][0]['volumeInfo'].get('description', ''),
            'isbn_13': isbn,
            'page_count': book_data['items'][0]['volumeInfo'].get('pageCount', ''),
            'main_categories': book_data['items'][0]['volumeInfo'].get('categories', ''),
            'categories': book_data['items'][0]['volumeInfo'].get('categories', ''),
            'average_rating': book_data['items'][0]['volumeInfo'].get('averageRating', ''),
            'ratings_count': book_data['items'][0]['volumeInfo'].get('ratingsCount', ''),
            'maturity_rating': book_data['items'][0]['volumeInfo'].get('maturityRating', '')
        }

        # append the new dictionary to the book_data_list
        book_data_list.append(book)
    else:

        # handle the case where no results were returned for the ISBN-13 number
        # print(f"No results found for ISBN-13 {isbn}")
        pass
    
    print()

# convert the list of dictionaries to a DataFrame
response_df = pd.DataFrame(book_data_list)
# Out:
# 0 9780439785969: dict_keys(['kind', 'totalItems']):
# 1 9780439358071: dict_keys(['kind', 'totalItems']):
# 2 9780439554893: dict_keys(['kind', 'totalItems', 'items']): 1: Harry Potter and the Chamber of Secrets
# 3 9780439655484: dict_keys(['kind', 'totalItems', 'items']): 1: Harry Potter and the Prisoner of Azkaban
# 4 9780439682589: dict_keys(['kind', 'totalItems', 'items']): 1: Harry Potter
# 5 9780976540601: dict_keys(['kind', 'totalItems', 'items']): 1: Unauthorized Harry Potter and the Deathly Hallows News
# 6 9780439827607: dict_keys(['kind', 'totalItems', 'items']): 2: The Harry Potter Collection
# 7 9780517226957: dict_keys(['kind', 'totalItems', 'items']): 1: The Ultimate Hitchhiker's Guide
# 8 9780345453747: dict_keys(['kind', 'totalItems', 'items']): 1: The Ultimate Hitchhiker's Guide to the Galaxy
# 9 9781400052929: dict_keys(['kind', 'totalItems', 'items']): 2: The Hitchhiker's Guide to the Galaxy 25th Anniversary Edition
# 10 9780739322208: dict_keys(['kind', 'totalItems']):
# 11 9780517149256: dict_keys(['kind', 'totalItems', 'items']): 1: The Ultimate Hitchhiker's Guide
# 12 9780767908184: dict_keys(['kind', 'totalItems', 'items']): 1: A Short History of Nearly Everything
# 13 9780767915069: dict_keys(['kind', 'totalItems', 'items']): 1: Bill Bryson's African Diary
# 14 9780767910439: dict_keys(['kind', 'totalItems', 'items']): 1: Bryson's Dictionary of Troublesome Words
# 15 9780767903868: dict_keys(['kind', 'totalItems', 'items']): 1: In a Sunburned Country
# 16 9780767903820: dict_keys(['kind', 'totalItems', 'items']): 1: I'm a Stranger Here Myself
# 17 9780060920081: dict_keys(['kind', 'totalItems', 'items']): 1: The Lost Continent
# 18 9780380713806: dict_keys(['kind', 'totalItems', 'items']): 1: Neither Here Nor There:
# 19 9780380727506: dict_keys(['kind', 'totalItems', 'items']): 1: Notes from a Small Island
# 20 9780380715435: dict_keys(['kind', 'totalItems', 'items']): 2: The Mother Tongue
# 21 9780345538376: dict_keys(['kind', 'totalItems', 'items']): 1: The Hobbit / The Lord of the Rings
# 22 9780618517657: dict_keys(['kind', 'totalItems', 'items']): 1: The Lord of the Rings
# 23 9780618346257: dict_keys(['kind', 'totalItems', 'items']): 2: The Lord of the Rings
# 24 9780618260584: dict_keys(['kind', 'totalItems', 'items']): 3: The Two Towers
# 25 9780618391004: dict_keys(['kind', 'totalItems', 'items']): 1: The Lord of the Rings
# 26 9780618510825: dict_keys(['kind', 'totalItems', 'items']): 1: The Lord of the Rings Complete Visual Companion
# 27 9780976694007: dict_keys(['kind', 'totalItems', 'items']): 1: Agile Web Development with Rails
# 28 9780689840920: dict_keys(['kind', 'totalItems', 'items']): 1: Hatchet
# 29 9781557344496: dict_keys(['kind', 'totalItems', 'items']): 1: A Guide for Using Hatchet in the Classroom
# 30 9780385326506: dict_keys(['kind', 'totalItems', 'items']): 1: Guts
# 31 9781575606248: dict_keys(['kind', 'totalItems', 'items']): 1: Molly Hatchet
# 32 9781595580276: dict_keys(['kind', 'totalItems', 'items']): 1: Hatchet Jobs
# 33 9781595962805: dict_keys(['kind', 'totalItems', 'items']): 1: A Changeling for All Seasons
# 34 9780670059676: dict_keys(['kind', 'totalItems', 'items']): 1: Changeling
# 35 9780141312620: dict_keys(['kind', 'totalItems', 'items']): 1: The Changeling Sea
# 36 9780595321803: dict_keys(['kind', 'totalItems']):
# 37 9781590301944: dict_keys(['kind', 'totalItems', 'items']): 1: The Changeling
# 38 9780449146972: dict_keys(['kind', 'totalItems', 'items']): 1: The Changeling
# 39 9780061159176: dict_keys(['kind', 'totalItems', 'items']): 1: The Known World
# 40 9780060762735: dict_keys(['kind', 'totalItems']):
# 41 9780060749910: dict_keys(['kind', 'totalItems', 'items']): 1: The Known World LP
# 42 9780273704744: dict_keys(['kind', 'totalItems', 'items']): 1: Traders, Guns & Money
# 43 9781932386103: dict_keys(['kind', 'totalItems', 'items']): 1: Artesia: Adventures In The Known World RPG
# 44 9780374517199: dict_keys(['kind', 'totalItems']):
# 45 9780374280390: dict_keys(['kind', 'totalItems', 'items']): 1: Uncommon Carriers
# 46 9780374519742: dict_keys(['kind', 'totalItems', 'items']): 1: Heirs of General Practice
# 47 9780374522599: dict_keys(['kind', 'totalItems', 'items']): 1: The Control of Nature
# 48 9780374518738: dict_keys(['kind', 'totalItems', 'items']): 1: Annals of the Former World
# 49 9780374522872: dict_keys(['kind', 'totalItems', 'items']): 1: Coming Into the Country
# 50 9780374519322: dict_keys(['kind', 'totalItems']):
# 51 9780374516000: dict_keys(['kind', 'totalItems', 'items']): 1: Giving Good Weight
# 52 9780374520656: dict_keys(['kind', 'totalItems', 'items']): 1: Rising from the Plains
# 53 9780822205104: dict_keys(['kind', 'totalItems', 'items']): 1: The Heidi Chronicles
# 54 9780679734994: dict_keys(['kind', 'totalItems', 'items']): 1: The Heidi Chronicles
# 55 9781596670235: dict_keys(['kind', 'totalItems', 'items']): 1: Active Literacy Across the Curriculum
# 56 9781581807745: dict_keys(['kind', 'totalItems', 'items']): 2: Simply Beautiful Beaded Jewelry
# 57 9780800793616: dict_keys(['kind', 'totalItems', 'items']): 1: Always Enough
# 58 9780871202864: dict_keys(['kind', 'totalItems', 'items']): 2: Mapping the Big Picture
# 59 9780753454947: dict_keys(['kind', 'totalItems', 'items']): 1: Heidi
# 60 9780871209993: dict_keys(['kind', 'totalItems', 'items']): 1: Getting Results with Curriculum Mapping
# 61 9781852402877: dict_keys(['kind', 'totalItems', 'items']): 1: There is Always Enough
# 62 9780761129585: dict_keys(['kind', 'totalItems', 'items']): 1: What to Expect the First Year
# 63 9780972016414: dict_keys(['kind', 'totalItems', 'items']): 1: The Player's Handbook
# 64 9781581805635: dict_keys(['kind', 'totalItems', 'items']): 1: Simply Beautiful Beading
# 65 9780441294671: dict_keys(['kind', 'totalItems']):
# 66 9780441102679: dict_keys(['kind', 'totalItems', 'items']): 1: Chapterhouse: Dune
# 67 9780441172696: dict_keys(['kind', 'totalItems', 'items']): 1: Dune Messiah
# 68 9780765306470: dict_keys(['kind', 'totalItems', 'items']): 1: Dreamer of Dune
# 69 9780399128981: dict_keys(['kind', 'totalItems', 'items']): 1: Heretics of Dune
# 70 9780765353702: dict_keys(['kind', 'totalItems', 'items']): 1: The Road to Dune
# 71 9780441328000: dict_keys(['kind', 'totalItems', 'items']): 1: Heretics of Dune
# 72 9780618212903: dict_keys(['kind', 'totalItems', 'items']): 1: The Lord of the Rings
# 73 9780345410054: dict_keys(['kind', 'totalItems', 'items']): 1: The Power of One
# 74 9780385732543: dict_keys(['kind', 'totalItems', 'items']): 1: The Power of One
# 75 9780785260059: dict_keys(['kind', 'totalItems', 'items']): 1: The Power of One
# 76 9780471780939: dict_keys(['kind', 'totalItems', 'items']): 1: Power of An Hour
# 77 9780325001531: dict_keys(['kind', 'totalItems', 'items']): 1: The Power of One
# 78 9780060762872: dict_keys(['kind', 'totalItems', 'items']): 1: How to Buy, Sell, and Profit on eBay
# 79 9780470045299: dict_keys(['kind', 'totalItems', 'items']): 1: eBay For Dummies
# 80 9780072262780: dict_keys(['kind', 'totalItems', 'items']): 1: What to Sell on eBay and Where to Get It
# 81 9780764569241: dict_keys(['kind', 'totalItems', 'items']): 1: Starting an eBay Business For Dummies
# 82 9780471933823: dict_keys(['kind', 'totalItems', 'items']): 1: eBay
# 83 9780764559914: dict_keys(['kind', 'totalItems', 'items']): 1: eBay Timesaving Techniques For Dummies
# 84 9780764584381: dict_keys(['kind', 'totalItems', 'items']): 1: eBay Business All-in-One Desk Reference For Dummies
# 85 9780596523695: dict_keys(['kind', 'totalItems', 'items']): 1: Ruby Cookbook
# 86 9780806523491: dict_keys(['kind', 'totalItems', 'items']): 1: Ruby Ann's Down Home Trailer Park Cookbook
# 87 9780806525365: dict_keys(['kind', 'totalItems', 'items']): 1: Ruby Ann's Down Home Trailer Park Bbqin' Cookbook
# 88 9780596527310: dict_keys(['kind', 'totalItems', 'items']): 1: Rails Cookbook
# 89 9780143035008: dict_keys(['kind', 'totalItems', 'items']): 2: Anna Karenina
# 90 9780451528612: dict_keys(['kind', 'totalItems', 'items']): 1: Anna Karenina
# 91 9780140449174: dict_keys(['kind', 'totalItems', 'items']): 1: Penguin Classics Anna Karenina
# 92 9780822001836: dict_keys(['kind', 'totalItems', 'items']): 2: CliffsNotes on Tolstoy's Anna Karenina
# 93 9781593080273: dict_keys(['kind', 'totalItems', 'items']): 1: Anna Karenina
# 94 9780486437965: dict_keys(['kind', 'totalItems', 'items']): 1: Anna Karenina
# 95 9781593081775: dict_keys(['kind', 'totalItems', 'items']): 1: Anna Karenina
# 96 9780778322276: dict_keys(['kind', 'totalItems', 'items']): 1: Dinner with Anna Karenina
# 97 9780521313254: dict_keys(['kind', 'totalItems', 'items']): 1: Tolstoy: Anna Karenina
# 98 9780140183955: dict_keys(['kind', 'totalItems', 'items']): 1: Untouchable
# 99 9780679767473: dict_keys(['kind', 'totalItems', 'items']): 1: The Untouchable
# 100 9781568491981: dict_keys(['kind', 'totalItems', 'items']): 1: The Untouchables
# 101 9780743270793: dict_keys(['kind', 'totalItems', 'items']): 1: Untouchables
# 102 9780932863058: dict_keys(['kind', 'totalItems', 'items']): 1: Dalit
# 103 9780742508804: dict_keys(['kind', 'totalItems', 'items']): 1: Growing Up Untouchable in India
# 104 9780205358625: dict_keys(['kind', 'totalItems', 'items']): 1: The Evidence-based Social Work Skills Book
# 105 9781557344038: dict_keys(['kind', 'totalItems', 'items']): 1: A Guide for Using A Wrinkle in Time in the Classroom, Based on the Book Written by Madeleine L'Engle
# 106 9780380720446: dict_keys(['kind', 'totalItems', 'items']): 1: Wrinkles in Time
# 107 9780821925324: dict_keys(['kind', 'totalItems', 'items']): 1: A Wrinkle in Time
# 108 9780439271691: dict_keys(['kind', 'totalItems', 'items']): 1: A Wrinkle in Time
# 109 9780606105262: dict_keys(['kind', 'totalItems', 'items']): 1: Una arruga en el tiempo
# 110 9780751506433: dict_keys(['kind', 'totalItems', 'items']): 1: The Long Shadow
# 111 9780060786717: dict_keys(['kind', 'totalItems', 'items']): 1: A Long Shadow
# 112 9780743499347: dict_keys(['kind', 'totalItems', 'items']): 1: Long Way Round
# 113 9780765313409: dict_keys(['kind', 'totalItems', 'items']): 1: A Shadow in Summer
# 114 9781400032495: dict_keys(['kind', 'totalItems', 'items']): 1: New Hope for the Dead
# 115 9781400032488: dict_keys(['kind', 'totalItems', 'items']): 1: Sideswipe
# 116 9781400032464: dict_keys(['kind', 'totalItems', 'items']): 1: Miami Blues
# 117 9780679732525: dict_keys(['kind', 'totalItems', 'items']): 1: The Burnt Orange Heresy
# 118 9780312424442: dict_keys(['kind', 'totalItems', 'items']): 1: I Am Charlotte Simmons
# 119 9780806930770: dict_keys(['kind', 'totalItems', 'items']): 1: Edward Lear
# 120 9780140366600: dict_keys(['kind', 'totalItems', 'items']): 1: The Puffin Book of Nonsense Verse
# 121 9780811201124: dict_keys(['kind', 'totalItems', 'items']): 2: Henry Miller on Writing
# 122 9780802130167: dict_keys(['kind', 'totalItems', 'items']): 1: Quiet Days in Clichy
# 123 9780802131782: dict_keys(['kind', 'totalItems', 'items']): 1: Tropic of Cancer
# 124 9780802151827: dict_keys(['kind', 'totalItems', 'items']): 1: Tropic of Capricorn
# 125 9780802151780: dict_keys(['kind', 'totalItems', 'items']): 2: The Rosy Crucifixion
# 126 9780802151803: dict_keys(['kind', 'totalItems', 'items']): 1: The Rosy Crucifixion: Sexus
# 127 9780811201063: dict_keys(['kind', 'totalItems', 'items']): 2: The Air-conditioned Nightmare
# 128 9780141439631: dict_keys(['kind', 'totalItems', 'items']): 1: The Portrait of a Lady
# 129 9781593080969: dict_keys(['kind', 'totalItems', 'items']): 1: The Portrait of a Lady
# 130 9781571290533: dict_keys(['kind', 'totalItems', 'items']): 1: Writing
# 131 9781565842212: dict_keys(['kind', 'totalItems', 'items']): 1: The War
# 132 9780394743042: dict_keys(['kind', 'totalItems', 'items']): 1: The Ravishing of Lol Stein
# 133 9781851681822: dict_keys(['kind', 'totalItems', 'items']): 1: Love Letters
# 134 9781566562492: dict_keys(['kind', 'totalItems', 'items']): 1: Kahlil Gibran
# 135 9780140195538: dict_keys(['kind', 'totalItems', 'items']): 1: The Beloved
# 136 9780394431246: dict_keys(['kind', 'totalItems', 'items']): 1: Jesus the Son of Man
# 137 9780806501901: dict_keys(['kind', 'totalItems', 'items']): 1: The Broken Wings
# 138 9780679439202: dict_keys(['kind', 'totalItems', 'items']): 1: Sand and Foam
# 139 9780753453803: dict_keys(['kind', 'totalItems', 'items']): 1: Treasure Island
# 140 9781402714573: dict_keys(['kind', 'totalItems', 'items']): 2: Unabridged: Treasure Island
# 141 9781416500292: dict_keys(['kind', 'totalItems', 'items']): 1: Treasure Island
# 142 9780689854682: dict_keys(['kind', 'totalItems', 'items']): 1: Treasure Island
# 143 9780517221143: dict_keys(['kind', 'totalItems', 'items']): 1: Treasure Island
# 144 9781577658054: dict_keys(['kind', 'totalItems', 'items']): 1: Treasure Island
# 145 9780933121188: dict_keys(['kind', 'totalItems', 'items']): 1: 100 Years of Lynchings
# 146 9780785950103: dict_keys(['kind', 'totalItems', 'items']): 1: Cien Años de Soledad
# 147 9780394800844: dict_keys(['kind', 'totalItems', 'items']): 1: On Beyond Zebra
# 148 9780821778258: dict_keys(['kind', 'totalItems', 'items']): 1: The Wedding Clause
# 149 9780060733032: dict_keys(['kind', 'totalItems', 'items']): 1: The Zebra Wall
# 150 9788432216060: dict_keys(['kind', 'totalItems', 'items']): 1: El perfume
# 151 9780345413994: dict_keys(['kind', 'totalItems', 'items']): 1: The Door Into Summer
# 152 9780441788385: dict_keys(['kind', 'totalItems', 'items']): 1: Stranger in a Strange Land
# 153 9780441748600: dict_keys(['kind', 'totalItems', 'items']): 1: To Sail Beyond the Sunset
# 154 9780345316509: dict_keys(['kind', 'totalItems', 'items']): 1: Job, a Comedy of Justice
# 155 9780765314932: dict_keys(['kind', 'totalItems', 'items']): 1: Time for the Stars
# 156 9780671742515: dict_keys(['kind', 'totalItems', 'items']): 1: Long Dark Tea-Time of the Soul
# 157 9780345455291: dict_keys(['kind', 'totalItems', 'items']): 1: The Salmon of Doubt
# 158 9780345476517: dict_keys(['kind', 'totalItems', 'items']): 1: Wish You Were Here
# 159 9780345368430: dict_keys(['kind', 'totalItems', 'items']): 1: Douglas Adams's Starship Titanic
# 160 9781417622856: dict_keys(['error']):
# 161 9780573650963: dict_keys(['kind', 'totalItems', 'items']): 1: The Phantom Tollbooth
# 162 9780691122946: dict_keys(['kind', 'totalItems', 'items']): 1: On Bullshit
# 163 9780393329407: dict_keys(['kind', 'totalItems', 'items']): 1: Another Bullshit Night in Suck City: A Memoir
# 164 9780671867423: dict_keys(['kind', 'totalItems', 'items']): 1: Lincoln at Gettysburg
# 165 9780395883976: dict_keys(['kind', 'totalItems', 'items']): 1: The Gettysburg Address
# 166 9780684848150: dict_keys(['kind', 'totalItems', 'items']): 1: Underworld
# 167 9780140156041: dict_keys(['kind', 'totalItems', 'items']): 1: Libra
# 168 9780140119480: dict_keys(['error']):
# 169 9780679722946: dict_keys(['error']):
# 170 9780743244251: dict_keys(['error']):
# 171 9780140179170: dict_keys(['error']):
# 172 9780679722953: dict_keys(['kind', 'totalItems', 'items']): 1: The Names
# 173 9781594201202: dict_keys(['kind', 'totalItems', 'items']): 1: Against the Day
# 174 9780060930219: dict_keys(['error']):
# 175 9780060931674: dict_keys(['kind', 'totalItems', 'items']): 1: The Crying of Lot 49
# 176 9780140283389: dict_keys(['error']):
# 177 9780312423209: dict_keys(['error']):
# 178 9780141180632: dict_keys(['error']):
# 179 9780143039945: dict_keys(['kind', 'totalItems', 'items']): 1: Gravity's Rainbow (Classics Deluxe Edition)
# 180 9780316724432: dict_keys(['kind', 'totalItems', 'items']): 1: Slow Learner
# 181 9780140189308: dict_keys(['error']):
# 182 9781400043149: dict_keys(['kind', 'totalItems', 'items']): 1: The Year of Magical Thinking
# 183 9780374522216: dict_keys(['kind', 'totalItems', 'items']): 1: The White Album
# 184 9780679754862: dict_keys(['kind', 'totalItems', 'items']): 1: A Book of Common Prayer
# 185 9780679752868: dict_keys(['kind', 'totalItems', 'items']): 1: Where I Was From
# 186 9780374521721: dict_keys(['kind', 'totalItems', 'items']): 1: Slouching Towards Bethlehem
# 187 9780679754855: dict_keys(['kind', 'totalItems', 'items']): 1: Democracy
# 188 9780307264879: dict_keys(['error']):
# 189 9780374529949: dict_keys(['error']):
# 190 9780143039839: dict_keys(['error']):
# 191 9780140097313: dict_keys(['error']):
# 192 9780140097351: dict_keys(['error']):
# 193 9780940650763: dict_keys(['kind', 'totalItems', 'items']): 2: The New York Trilogy: The locked room
# 194 9780963188922: dict_keys(['kind', 'totalItems', 'items']): 1: Pyramids of Montauk
# 195 9780312426231: dict_keys(['kind', 'totalItems', 'items']): 1: The Brooklyn Follies
# 196 9780140115857: dict_keys(['error']):
# 197 9780140154078: dict_keys(['kind', 'totalItems', 'items']): 1: The Music of Chance
# 198 9780805081459: dict_keys(['kind', 'totalItems', 'items']): 1: Travels in the Scriptorium
# 199 9780140178135: dict_keys(['kind', 'totalItems', 'items']): 1: Leviathan
# 200 9780811214988: dict_keys(['error']):
# 201 9782742741465: dict_keys(['kind', 'totalItems', 'items']): 1: Paul Auster Coffret en 3 volumes : Moon Palace ; Léviathan ; Tombouctou
# 202 9780143036555: dict_keys(['kind', 'totalItems', 'items']): 1: Collapse
# 203 9780446579780: dict_keys(['error']):
# 204 9780521386739: dict_keys(['kind', 'totalItems', 'items']): 1: The Collapse of Complex Societies
# 205 9780743203043: dict_keys(['kind', 'totalItems', 'items']): 1: Bowling Alone
# 206 9780345438713: dict_keys(['kind', 'totalItems', 'items']): 1: The Collapse of the Common Good
# 207 9780393318289: dict_keys(['kind', 'totalItems', 'items']): 1: Reinventing the Enemy's Language
# 208 9781599869940: dict_keys(['kind', 'totalItems', 'items']): 1: My Inventions
# 209 9780806519609: dict_keys(['kind', 'totalItems', 'items']): 1: Wizard
# 210 9780822549208: dict_keys(['error']):
# 211 9780932813862: dict_keys(['kind', 'totalItems', 'items']): 1: The Tesla Papers
# 212 9780373792689: dict_keys(['error']):
# 213 9780974514055: dict_keys(['error']):
# 214 9780764585975: dict_keys(['kind', 'totalItems', 'items']): 1: CliffsNotes on Golding's Lord of the Flies
# 215 9780307281708: dict_keys(['error']):
# 216 9780812969702: dict_keys(['error']):
# 217 9780060255084: dict_keys(['error']):
# 218 9780330485388: dict_keys(['kind', 'totalItems', 'items']): 1: The Lovely Bones
# 219 9781594130236: dict_keys(['kind', 'totalItems', 'items']): 1: The Lovely Bones
# 220 9780345360359: dict_keys(['kind', 'totalItems', 'items']): 1: Lovely in Her Bones
# 221 785342303476: dict_keys(['error']):
# 222 9780321430847: dict_keys(['error']):
# 223 9783822840856: dict_keys(['error']):
# 224 9780743264464: dict_keys(['kind', 'totalItems', 'items']): 1: Killing Yourself to Live
# 225 9780743236010: dict_keys(['error']):
# 226 9780553572490: dict_keys(['kind', 'totalItems', 'items']): 1: Vice
# 227 9780060589462: dict_keys(['kind', 'totalItems', 'items']): 1: Zen and the Art of Motorcycle Maintenance
# 228 9780802789471: dict_keys(['error']):
# 229 9780688060695: dict_keys(['kind', 'totalItems', 'items']): 1: Guidebook to Zen and the Art of Motorcycle Maintenance
# 230 9781859605158: dict_keys(['error']):
# 231 9781592530878: dict_keys(['kind', 'totalItems', 'items']): 1: LogoLounge
# 232 9780451528803: dict_keys(['kind', 'totalItems']):
# 233 9780192833983: dict_keys(['error']):
# 234 9780486451381: dict_keys(['kind', 'totalItems', 'items']): 1: The Kingdom of God Is Within You
# 235 9780452011878: dict_keys(['kind', 'totalItems', 'items']): 1: Atlas Shrugged
# 236 9780451163080: dict_keys(['error']):
# 237 9780452286757: dict_keys(['kind', 'totalItems', 'items']): 1: The Fountainhead (Centennial Edition HC)
# 238 9780451163936: dict_keys(['error']):
# 239 9780452281257: dict_keys(['kind', 'totalItems', 'items']): 1: Anthem
# 240 9780451187840: dict_keys(['kind', 'totalItems', 'items']): 1: We the Living
# 241 9780451147950: dict_keys(['error']):
# 242 9780452274044: dict_keys(['kind', 'totalItems', 'items']): 1: Letters of Ayn Rand
# 243 9780471791430: dict_keys(['error']):
# 244 9780553803815: dict_keys(['kind', 'totalItems', 'items']): 1: Sailing from Byzantium
# 245 9780375755194: dict_keys(['kind', 'totalItems', 'items']): 1: Sailing Alone Around the Room
# 246 9781592283194: dict_keys(['kind', 'totalItems', 'items']): 1: The Greatest Sailing Stories Ever Told
# 247 9780975599518: dict_keys(['kind', 'totalItems', 'items']): 1: Natural Cures "they" Don't Want You to Know about
# 248 9780374502003: dict_keys(['error']):
# 249 9780307263940: dict_keys(['kind', 'totalItems', 'items']): 1: Digging to America
# 250 9780312405540: dict_keys(['kind', 'totalItems', 'items']): 1: Rereading America
# 251 9780195170139: dict_keys(['error']):
# 252 9781400079490: dict_keys(['kind', 'totalItems', 'items']): 1: The Plot Against America
# 253 9780688171629: dict_keys(['error']):
# 254 9780060932688: dict_keys(['kind', 'totalItems', 'items']): 2: Collected Stories
# 255 9781400034956: dict_keys(['kind', 'totalItems', 'items']): 1: Crónica de una muerte anunciada / Chronicle of a Death Foretold
# 256 9780307350428: dict_keys(['kind', 'totalItems', 'items']): 1: Cien años de soledad
# 257 9780307350442: dict_keys(['error']):
# 258 9781400034543: dict_keys(['kind', 'totalItems', 'items']): 1: Living to Tell the Tale
# 259 9781400095803: dict_keys(['kind', 'totalItems', 'items']): 1: Memoria de mis putas tristes / Memories of my Melancholy Whores
# 260 9780375708114: dict_keys(['kind', 'totalItems', 'items']): 1: The Elegant Universe
# 261 9780861714926: dict_keys(['error']):
# 262 9781843535843: dict_keys(['kind', 'totalItems', 'items']): 1: The Mini Rough Guide to London
# 263 9781740594776: dict_keys(['kind', 'totalItems', 'items']): 1: Best of London
# 264 9788408064763: dict_keys(['error']):
# 265 9781740592055: dict_keys(['error']):
# 266 9780618710539: dict_keys(['error']):
# 267 9780060512804: dict_keys(['kind', 'totalItems', 'items']): 1: Cryptonomicon
# 268 9782228894166: dict_keys(['error']):
# 269 9780060733353: dict_keys(['error']):
# 270 9780060593087: dict_keys(['kind', 'totalItems', 'items']): 1: Quicksilver
# 271 9780553383447: dict_keys(['kind', 'totalItems', 'items']): 1: The Cobweb
# 272 9780380816033: dict_keys(['error']):
# 273 9780553380965: dict_keys(['error']):
# 274 9780553383430: dict_keys(['kind', 'totalItems', 'items']): 1: Interface
# 275 9780060833183: dict_keys(['error']):
# 276 9780553380958: dict_keys(['error']):
# 277 9781880685358: dict_keys(['error']):
# 278 9781880685334: dict_keys(['kind', 'totalItems', 'items']): 1: Harrington on Hold 'em
# 279 9780465067107: dict_keys(['kind', 'totalItems']):
# 280 9780465051366: dict_keys(['error']):
# 281 9780465067091: dict_keys(['kind', 'totalItems']):
# 282 9780898709193: dict_keys(['kind', 'totalItems', 'items']): 1: No Price Too High
# 283 9780060887964: dict_keys(['kind', 'totalItems']):
# 284 9780061122415: dict_keys(['kind', 'totalItems', 'items']): 1: The Alchemist
# 285 9781421504605: dict_keys(['error']):
# 286 9781591169253: dict_keys(['error']):
# 287 9781421504599: dict_keys(['error']):
# 288 9781591169208: dict_keys(['error']):
# 289 9781591169291: dict_keys(['error']):
# 290 9780060192501: dict_keys(['kind', 'totalItems', 'items']): 1: The Illustrated Alchemist
# 291 9781591169239: dict_keys(['kind', 'totalItems']):
# 292 9780812974614: dict_keys(['error']):
# 293 9781587157394: dict_keys(['kind', 'totalItems', 'items']): 1: The Last Days of Pompeii
# 294 9780142000670: dict_keys(['kind', 'totalItems', 'items']): 1: Of Mice and Men
# 295 9780060554736: dict_keys(['kind', 'totalItems', 'items']): 1: The Game
# 296 9780142401200: dict_keys(['kind', 'totalItems', 'items']): 1: The Westing Game (Puffin Modern Classics)
# 297 9780808553038: dict_keys(['error']):
# 298 9781400096893: dict_keys(['kind', 'totalItems', 'items']): 1: Memoirs of a Geisha
# 299 9780739326220: dict_keys(['kind', 'totalItems', 'items']): 1: Memoirs of a Geisha
# 300 9780099498186: dict_keys(['error']):
# 301 9781557046833: dict_keys(['kind', 'totalItems', 'items']): 1: Memoirs of a Geisha
# 302 9780099771517: dict_keys(['kind', 'totalItems', 'items']): 1: Memoirs of a Geisha
# 303 9780743430593: dict_keys(['error']):
# 304 9781932664393: dict_keys(['error']):
# 305 9780521750844: dict_keys(['kind', 'totalItems', 'items']): 1: Jungle Love Level 5
# 306 9780802415318: dict_keys(['kind', 'totalItems', 'items']): 1: The Five Love Languages
# 307 9781416524793: dict_keys(['kind', 'totalItems', 'items']): 1: Angels & Demons
# 308 9788495618771: dict_keys(['error']):
# 309 9780972859899: dict_keys(['error']):
# 310 9780307277671: dict_keys(['kind', 'totalItems', 'items']): 2: The Da Vinci Code
# 311 9780767926034: dict_keys(['error']):
# 312 9782266144346: dict_keys(['error']):
# 313 9781416524809: dict_keys(['kind', 'totalItems', 'items']): 1: Deception Point
# 314 9780552151764: dict_keys(['error']):
# 315 9780593055076: dict_keys(['kind', 'totalItems', 'items']): 1: Deception Point
# 316 9780786016068: dict_keys(['error']):
# 317 9780671015206: dict_keys(['error']):
# 318 9781585424337: dict_keys(['kind', 'totalItems', 'items']): 1: Think and Grow Rich
# 319 9781932429237: dict_keys(['kind', 'totalItems', 'items']): 1: Think and Grow Rich: The 21st-Century Edition
# 320 9780977616657: dict_keys(['error']):
# 321 9781563410901: dict_keys(['kind', 'totalItems', 'items']): 1: Read My Lips
# 322 9780345479174: dict_keys(['kind', 'totalItems', 'items']): 1: Trump
# 323 9780451205360: dict_keys(['kind', 'totalItems', 'items']): 1: The Richest Man in Babylon
# 324 9781419349997: dict_keys(['kind', 'totalItems']):
# 325 9781400098033: dict_keys(['kind', 'totalItems', 'items']): 1: Shibumi
# 326 9780743226721: dict_keys(['error']):
# 327 9780140481396: dict_keys(['error']):
# 328 9780226014906: dict_keys(['kind', 'totalItems', 'items']): 1: The Crescent Obscured
# 329 9781416500186: dict_keys(['error']):
# 330 9780310258971: dict_keys(['kind', 'totalItems']):
# 331 9780060838584: dict_keys(['kind', 'totalItems', 'items']): 1: Fast Food Nation
# 332 9780141006871: dict_keys(['kind', 'totalItems', 'items']): 1: Fast Food Nation
# 333 9780812968064: dict_keys(['error']):
# 334 9780385340540: dict_keys(['kind', 'totalItems', 'items']): 1: The Broker
# 335 9780394720241: dict_keys(['error']):
# 336 9780345480606: dict_keys(['kind', 'totalItems', 'items']): 1: The Power Broker
# 337 9780060193393: dict_keys(['kind', 'totalItems', 'items']): 1: Body For Life
# 338 9781579546014: dict_keys(['kind', 'totalItems', 'items']): 1: Body for Life for Women
# 339 9780972018418: dict_keys(['kind', 'totalItems', 'items']): 1: Eating for Life
# 340 9780471743675: dict_keys(['error']):
# 341 9780471430452: dict_keys(['error']):
# 342 9780805431575: dict_keys(['kind', 'totalItems', 'items']): 1: Monkey Business
# 343 9780679838869: dict_keys(['error']):
# 344 9780373250714: dict_keys(['error']):
# 345 9780140143454: dict_keys(['kind', 'totalItems', 'items']): 1: Liar's Poker
# 346 9780802732293: dict_keys(['kind', 'totalItems', 'items']): 1: Liar's Poker
# 347 694055000612: dict_keys(['error']):
# 348 9780307238276: dict_keys(['error']):
# 349 9781400052585: dict_keys(['kind', 'totalItems', 'items']): 1: Everyday Italian
# 350 9780307346582: dict_keys(['kind', 'totalItems', 'items']): 1: Everyday Pasta
# 351 9781400052387: dict_keys(['kind', 'totalItems', 'items']): 1: Tyler's Ultimate
# 352 9780609609972: dict_keys(['kind', 'totalItems', 'items']): 1: Tyler Florence's Real Kitchen
# 353 9781400052370: dict_keys(['error']):
# 354 9780061234002: dict_keys(['kind', 'totalItems', 'items']): 1: Freakonomics Rev Ed
# 355 9788466625128: dict_keys(['kind', 'totalItems', 'items']): 1: Freakonomics
# 356 9780061245138: dict_keys(['kind', 'totalItems', 'items']): 1: Freakonomics Rev Ed LP
# 357 9780399153594: dict_keys(['kind', 'totalItems', 'items']): 1: The Last Assassin
# 358 9780156030205: dict_keys(['kind', 'totalItems', 'items']): 1: Book Club
# 359 9780828808392: dict_keys(['kind', 'totalItems', 'items']): 1: Lexicon of Pasta, 1982
# 360 9780140285970: dict_keys(['error']):
# 361 9780307276902: dict_keys(['error']):
# 362 9781411677319: dict_keys(['kind', 'totalItems', 'items']): 1: A Million Little Pieces of Feces
# 363 9780061171468: dict_keys(['kind', 'totalItems', 'items']): 1: A Million Little Lies
# 364 9780787968335: dict_keys(['kind', 'totalItems', 'items']): 1: The Leadership Challenge
# 365 9780446394598: dict_keys(['error']):
# 366 9780131494848: dict_keys(['kind', 'totalItems', 'items']): 1: Leadership in Organizations
# 367 9780316861014: dict_keys(['kind', 'totalItems', 'items']): 1: Leadership
# 368 9780060574215: dict_keys(['kind', 'totalItems', 'items']): 1: Men Are from Mars, Women Are from Venus
# 369 9780060192778: dict_keys(['error']):
# 370 9780061232053: dict_keys(['kind', 'totalItems']):
# 371 9780735200302: dict_keys(['error']):
# 372 9780553381672: dict_keys(['error']):
# 373 9780517542026: dict_keys(['kind', 'totalItems', 'items']): 1: The Clan of the Cave Bear
# 374 9780393324815: dict_keys(['error']):
# 375 9780744005615: dict_keys(['kind', 'totalItems', 'items']): 1: Juiced
# 376 9780140280197: dict_keys(['kind', 'totalItems', 'items']): 1: The 48 Laws of Power
# 377 9780553383683: dict_keys(['kind', 'totalItems', 'items']): 1: Gates of Fire
# 378 9780553295412: dict_keys(['kind', 'totalItems', 'items']): 1: Fire Sea
# 379 9780812590104: dict_keys(['error']):
# 380 9780385516419: dict_keys(['kind', 'totalItems', 'items']): 1: The Afghan Campaign
# 381 9780553381399: dict_keys(['kind', 'totalItems', 'items']): 1: Tides of War
# 382 9780553382044: dict_keys(['error']):
# 383 9780446691437: dict_keys(['kind', 'totalItems', 'items']): 1: The War of Art
# 384 9780826413017: dict_keys(['kind', 'totalItems', 'items']): 1: Gita on the Green
# 385 9780811701648: dict_keys(['error']):
# 386 9780140442755: dict_keys(['kind', 'totalItems', 'items']): 1: Phaedrus
# 387 9780192802774: dict_keys(['kind', 'totalItems', 'items']): 1: Phaedrus
# 388 9780140449747: dict_keys(['error']):
# 389 9780879756321: dict_keys(['error']):
# 390 9781890318239: dict_keys(['error']):
# 391 9780872207882: dict_keys(['error']):
# 392 9780801435300: dict_keys(['kind', 'totalItems', 'items']): 1: "Gorgias" and "Phaedrus"
# 393 9780872204621: dict_keys(['error']):
# 394 9780140449044: dict_keys(['kind', 'totalItems', 'items']): 1: Gorgias
# 395 9780140449082: dict_keys(['kind', 'totalItems', 'items']): 1: The Histories
# 396 9780140446388: dict_keys(['kind', 'totalItems', 'items']): 1: The Histories
# 397 9780879757779: dict_keys(['error']):
# 398 9780192824257: dict_keys(['kind', 'totalItems', 'items']): 1: The Histories
# 399 9780140440348: dict_keys(['error']):
# 400 9780393959468: dict_keys(['error']):
# 401 9780375400612: dict_keys(['error']):
# 402 9780226327709: dict_keys(['error']):
# 403 9780140275360: dict_keys(['error']):
# 404 9780872203525: dict_keys(['kind', 'totalItems', 'items']): 1: Iliad
# 405 9780374529055: dict_keys(['kind', 'totalItems', 'items']): 1: The Iliad
# 406 9780147712554: dict_keys(['error']):
# 407 9780140447941: dict_keys(['kind', 'totalItems', 'items']): 1: The Iliad
# 408 9780451527370: dict_keys(['error']):
# 409 9780872205420: dict_keys(['error']):
# 410 9780143039952: dict_keys(['error']):
# 411 9780374525743: dict_keys(['kind', 'totalItems']):
# 412 9780060931957: dict_keys(['kind', 'totalItems', 'items']): 1: The Odyssey of Homer
# 413 9780140449112: dict_keys(['kind', 'totalItems', 'items']): 1: The Odyssey
# 414 9780451527363: dict_keys(['error']):
# 415 9780865165847: dict_keys(['error']):
# 416 9780674995833: dict_keys(['kind', 'totalItems', 'items']): 27: Eclogues. Georgics. Aeneid
# 417 9781891190230: dict_keys(['kind', 'totalItems', 'items']): 1: City Eclogue
# 418 9780192837684: dict_keys(['kind', 'totalItems', 'items']): 1: The Eclogues ; The Georgics
# 419 9781558321250: dict_keys(['kind', 'totalItems', 'items']): 1: Paul Kirk's Championship Barbecue Sauces
# 420 9780141000589: dict_keys(['kind', 'totalItems', 'items']): 2: The Complete Pelican Shakespeare
# 421 9780517092941: dict_keys(['kind', 'totalItems', 'items']): 1: William Shakespeare, the Complete Works
# 422 9780521618748: dict_keys(['kind', 'totalItems', 'items']): 1: Hamlet
# 423 9781557831576: dict_keys(['kind', 'totalItems', 'items']): 1: The Reduced Shakespeare Company's the Complete Works of William Shakespeare (abridged)
# 424 9780062512796: dict_keys(['kind', 'totalItems', 'items']): 1: The Pilgrimage
# 425 9780062513342: dict_keys(['kind', 'totalItems', 'items']): 1: The Valkyries
# 426 9780060527983: dict_keys(['kind', 'totalItems', 'items']): 1: Warrior of the Light
# 427 9780060832810: dict_keys(['kind', 'totalItems', 'items']): 1: The Zahir
# 428 9780061122095: dict_keys(['error']):
# 429 9780060930134: dict_keys(['kind', 'totalItems', 'items']): 1: The Fifth Mountain
# 430 9780061124266: dict_keys(['error']):
# 431 9780140714548: dict_keys(['kind', 'totalItems', 'items']): 2: The Tragical History of Hamlet Prince of Denmark
# 432 9780764586033: dict_keys(['kind', 'totalItems', 'items']): 2: CliffsNotes on Shakespeare's Hamlet
# 433 9780764585685: dict_keys(['error']):
# 434 9780879232153: dict_keys(['kind', 'totalItems', 'items']): 1: Hamlet's Mill
# 435 9780674991200: dict_keys(['kind', 'totalItems', 'items']): 4: Thucydides: Books VII and VIII
# 436 9780872201682: dict_keys(['error']):
# 437 9780674991224: dict_keys(['error']):
# 438 9780872203945: dict_keys(['kind', 'totalItems', 'items']): 1: The Peloponnesian War
# 439 9780393971675: dict_keys(['kind', 'totalItems', 'items']): 1: The Peloponnesian War
# 440 9780674991873: dict_keys(['error']):
# 441 9780929524351: dict_keys(['error']):
# 442 9780226307800: dict_keys(['error']):
# 443 9780226307848: dict_keys(['kind', 'totalItems', 'items']): 1: Euripides
# 444 9780226307831: dict_keys(['kind', 'totalItems', 'items']): 1: Euripides: Rhesus. The suppliant women. Orestes. Iphigenia in Aulis
# 445 9781590171806: dict_keys(['kind', 'totalItems', 'items']): 1: Grief Lessons
# 446 9780553213638: dict_keys(['kind', 'totalItems', 'items']): 1: Ten Plays by Euripides
# 447 9780226307824: dict_keys(['error']):
# 448 9780226307817: dict_keys(['error']):
# 449 9780140449297: dict_keys(['kind', 'totalItems', 'items']): 1: Medea and Other Plays
# 450 9780674995604: dict_keys(['kind', 'totalItems', 'items']): 29: Euripides
# 451 9780521643863: dict_keys(['kind', 'totalItems', 'items']): 1: Euripides: Medea
# 452 9780140447262: dict_keys(['error']):
# 453 9780195125986: dict_keys(['kind', 'totalItems', 'items']): 1: Bakkhai
# 454 9780413752802: dict_keys(['error']):
# 455 9780486424620: dict_keys(['kind', 'totalItems', 'items']): 1: The Trojan Women and Hippolytus
# 456 9780393325836: dict_keys(['error']):
# 457 9780192832603: dict_keys(['kind', 'totalItems', 'items']): 1: Orestes and Other Plays
# 458 9780674995338: dict_keys(['error']):
# 459 9780195061666: dict_keys(['error']):
# 460 9780674995666: dict_keys(['error']):
# 461 9780195145663: dict_keys(['kind', 'totalItems', 'items']): 1: Medea
# 462 9780715631874: dict_keys(['kind', 'totalItems', 'items']): 1: Euripides: Medea
# 463 9780822004240: dict_keys(['error']):
# 464 9780674995741: dict_keys(['kind', 'totalItems', 'items']): 1: Trojan Women
# 465 9780674996007: dict_keys(['kind', 'totalItems', 'items']): 1: Fragmenta
# 466 9780715629949: dict_keys(['error']):
# 467 9780226307664: dict_keys(['kind', 'totalItems', 'items']): 1: The Complete Greek Tragedies: Euripides
# 468 9780226307787: dict_keys(['kind', 'totalItems', 'items']): 4: Aeschylus I
# 469 9780226307947: dict_keys(['kind', 'totalItems', 'items']): 2: Aeschylus II
# 470 9780195135923: dict_keys(['kind', 'totalItems', 'items']): 1: The Oresteia
# 471 9780140443332: dict_keys(['error']):
# 472 9780872203907: dict_keys(['kind', 'totalItems', 'items']): 1: Oresteia
# 473 9780140441123: dict_keys(['error']):
# 474 9780374527051: dict_keys(['kind', 'totalItems', 'items']): 1: The Oresteia of Aeschylus
# 475 9780812216271: dict_keys(['kind', 'totalItems', 'items']): 2: Aeschylus, 1
# 476 9780226307640: dict_keys(['error']):
# 477 9780521539814: dict_keys(['kind', 'totalItems', 'items']): 1: Aeschylus: The Oresteia
# 478 9781400041923: dict_keys(['error']):
# 479 9780812216714: dict_keys(['kind', 'totalItems', 'items']): 1: Aeschylus, 2
# 480 9780486292427: dict_keys(['error']):
# 481 9781419150012: dict_keys(['kind', 'totalItems']):
# 482 9780226307862: dict_keys(['kind', 'totalItems', 'items']): 2: The Complete Greek Tragedies
# 483 9780452011670: dict_keys(['kind', 'totalItems', 'items']): 2: The Oedipus Plays of Sophocles
# 484 9780451527844: dict_keys(['error']):
# 485 9780156027649: dict_keys(['error']):
# 486 9780140444254: dict_keys(['error']):
# 487 9780872205857: dict_keys(['error']):
# 488 9780679431329: dict_keys(['error']):
# 489 9780140440287: dict_keys(['error']):
# 490 9780192835888: dict_keys(['kind', 'totalItems', 'items']): 1: Antigone ; Oedipus the King ; Electra
# 491 9781580495936: dict_keys(['error']):
# 492 9780451621603: dict_keys(['kind', 'totalItems', 'items']): 1: The Oedipus Plays of Sophocles
# 493 9780521617352: dict_keys(['kind', 'totalItems', 'items']): 1: Sophocles: Oedipus Rex
# 494 9781416500339: dict_keys(['error']):
# 495 9780452007178: dict_keys(['kind', 'totalItems', 'items']): 1: Four Plays by Aristophanes
# 496 9780415907446: dict_keys(['error']):
# 497 9780553213430: dict_keys(['error']):
# 498 9780812234565: dict_keys(['kind', 'totalItems', 'items']): 6: Aristophanes, 2
# 499 9780872203617: dict_keys(['kind', 'totalItems', 'items']): 1: Aristophanes 1
# 500 9780140448146: dict_keys(['kind', 'totalItems', 'items']): 1: Lysistrata and Other Plays
# 501 9781585100873: dict_keys(['error']):
# 502 9780199120093: dict_keys(['error']):
# 503 9780674995376: dict_keys(['error']):
# 504 9780140441529: dict_keys(['kind', 'totalItems', 'items']): 1: The Wasps
# 505 9780156027656: dict_keys(['kind', 'totalItems', 'items']): 1: Four Comedies
# 506 9780674995963: dict_keys(['kind', 'totalItems', 'items']): 2: Aristophanes: Frogs. Assemblywomen. Wealth
# 507 49086007763: dict_keys(['kind', 'totalItems']):
# 508 9780198721598: dict_keys(['error']):
# 509 9780451616227: dict_keys(['kind', 'totalItems', 'items']): 1: Lysistrata
# 510 9780198140818: dict_keys(['kind', 'totalItems', 'items']): 1: Aristophanes' Peace
# 511 9780872206038: dict_keys(['error']):
# 512 9780140443325: dict_keys(['kind', 'totalItems', 'items']): 1: The Knights, Peace, Wealth, The Birds, The Assemblywomen
# 513 9780521774338: dict_keys(['error']):
# 514 9781400032716: dict_keys(['error']):
# 515 9780316156509: dict_keys(['error']):
# 516 9780743482776: dict_keys(['kind', 'totalItems', 'items']): 1: Twelfth Night
# 517 9780743271325: dict_keys(['error']):
# 518 9780142000281: dict_keys(['kind', 'totalItems', 'items']): 1: Getting Things Done
# 519 9781576751725: dict_keys(['error']):
# 520 9788433924636: dict_keys(['error']):
# 521 9788433968777: dict_keys(['error']):
# 522 9781862076655: dict_keys(['error']):
# 523 9788433924711: dict_keys(['error']):
# 524 9788433924629: dict_keys(['error']):
# 525 9780321317100: dict_keys(['kind', 'totalItems', 'items']): 1: American Government
# 526 9780321365200: dict_keys(['kind', 'totalItems', 'items']): 1: Essentials of American and Texas Government 2006
# 527 9788432216428: dict_keys(['kind', 'totalItems']):
# 528 9781565480841: dict_keys(['error']):
# 529 9780679783190: dict_keys(['error']):
# 530 9781565481244: dict_keys(['error']):
# 531 9780520227576: dict_keys(['error']):
# 532 9780024021502: dict_keys(['error']):
# 533 9780872201866: dict_keys(['error']):
# 534 9780143035985: dict_keys(['error']):
# 535 9780192854520: dict_keys(['kind', 'totalItems', 'items']): 1: Augustine: A Very Short Introduction
# 536 9781565482012: dict_keys(['kind', 'totalItems', 'items']): 1: The Works of Saint Augustine
# 537 9780060934910: dict_keys(['error']):
# 538 9788466308953: dict_keys(['error']):
# 539 9780156001267: dict_keys(['kind', 'totalItems', 'items']): 1: The Metamorphoses of Ovid
# 540 9780140447897: dict_keys(['error']):
# 541 9780393058109: dict_keys(['kind', 'totalItems', 'items']): 1: Metamorphoses
# 542 9780806128948: dict_keys(['error']):
# 543 9780806114569: dict_keys(['kind', 'totalItems', 'items']): 2: Ovid's Metamorphoses
# 544 9780814317327: dict_keys(['error']):
# 545 9780674992559: dict_keys(['error']):
# 546 9780520242609: dict_keys(['kind', 'totalItems', 'items']): 1: The Poems of Exile
# 547 9780674990470: dict_keys(['error']):
# 548 9780674990463: dict_keys(['error']):
# 549 9780814326114: dict_keys(['error']):
# 550 9780806115603: dict_keys(['kind', 'totalItems', 'items']): 1: Tibullus
# 551 9780691015972: dict_keys(['error']):
# 552 9780195143102: dict_keys(['kind', 'totalItems', 'items']): 1: Antigone
# 553 9780195143737: dict_keys(['error']):
# 554 9780130158857: dict_keys(['error']):
# 555 9781857150605: dict_keys(['error']):
# 556 9780226301198: dict_keys(['error']):
# 557 9780521315791: dict_keys(['error']):
# 558 9780521011761: dict_keys(['error']):
# 559 9780521479349: dict_keys(['kind', 'totalItems', 'items']): 1: Foucault's Virginity
# 560 9781585424832: dict_keys(['kind', 'totalItems', 'items']): 1: 2012
# 561 9780767907439: dict_keys(['kind', 'totalItems', 'items']): 1: Breaking Open the Head
# 562 9780743233217: dict_keys(['error']):
# 563 9780743270601: dict_keys(['kind', 'totalItems', 'items']): 1: The Men who Stare at Goats
# 564 9780393061314: dict_keys(['error']):
# 565 9780865475090: dict_keys(['error']):
# 566 9780385486804: dict_keys(['kind', 'totalItems', 'items']): 2: Into the Wild
# 567 9780785268833: dict_keys(['error']):
# 568 9780743246989: dict_keys(['error']):
# 569 9780446579674: dict_keys(['error']):
# 570 9780515142396: dict_keys(['error']):
# 571 9780439227148: dict_keys(['error']):
# 572 9780375825385: dict_keys(['error']):
# 573 9781591583660: dict_keys(['error']):
# 574 9780805063899: dict_keys(['kind', 'totalItems', 'items']): 1: Nickel and Dimed
# 575 9780394417752: dict_keys(['error']):
# 576 9780140268683: dict_keys(['error']):
# 577 9780140137347: dict_keys(['error']):
# 578 9780140251579: dict_keys(['error']):
# 579 9780192802385: dict_keys(['error']):
# 580 9780143036234: dict_keys(['error']):
# 581 9780486440910: dict_keys(['kind', 'totalItems', 'items']): 1: Pride and Prejudice
# 582 9781593083243: dict_keys(['error']):
# 583 9781400032808: dict_keys(['kind', 'totalItems', 'items']): 1: Under the Banner of Heaven
# 584 9780375752674: dict_keys(['error']):
# 585 9780385494786: dict_keys(['error']):
# 586 9780679783619: dict_keys(['error']):
# 587 9780374292799: dict_keys(['error']):
# 588 9788427032224: dict_keys(['error']):
# 589 9780898868098: dict_keys(['kind', 'totalItems', 'items']): 1: The Avalanche Handbook
# 590 9780590422673: dict_keys(['kind', 'totalItems', 'items']): 1: Avalanche
# 591 9780451529305: dict_keys(['kind', 'totalItems', 'items']): 1: Little Women
# 592 9781402714580: dict_keys(['error']):
# 593 9780439101363: dict_keys(['error']):
# 594 9780517221167: dict_keys(['kind', 'totalItems', 'items']): 1: Little Women
# 595 9781931082730: dict_keys(['error']):
# 596 9781904633273: dict_keys(['kind', 'totalItems', 'items']): 1: Little Women
# 597 9780743487603: dict_keys(['kind', 'totalItems', 'items']): 1: A Tale of Two Cities
# 598 9781593081386: dict_keys(['error']):
# 599 9781586633523: dict_keys(['error']):
# 600 9781593080556: dict_keys(['kind', 'totalItems', 'items']): 2: A Tale of Two Cities
# 601 9781857151435: dict_keys(['kind', 'totalItems', 'items']): 1: A Tale of Two Cities
# 602 9780671792275: dict_keys(['error']):
# 603 9781405228183: dict_keys(['error']):
# 604 9780517093399: dict_keys(['error']):
# 605 9780375760051: dict_keys(['error']):
# 606 9780451530042: dict_keys(['kind', 'totalItems', 'items']): 1: David Copperfield
# 607 9780671882365: dict_keys(['error']):
# 608 9780670030774: dict_keys(['error']):
# 609 9780140436143: dict_keys(['kind', 'totalItems', 'items']): 1: Martin Chuzzlewit
# 610 9780465031269: dict_keys(['kind', 'totalItems', 'items']): 1: Why Is Sex Fun?
# 611 9780060183073: dict_keys(['error']):
# 612 9780822533894: dict_keys(['error']):
# 613 9780439321624: dict_keys(['error']):
# 614 9780826452320: dict_keys(['kind', 'totalItems', 'items']): 1: JK Rowling's Harry Potter Novels
# 615 9780747584667: dict_keys(['error']):
# 616 9780765342515: dict_keys(['error']):
# 617 9780765342539: dict_keys(['error']):
# 618 9780765342522: dict_keys(['error']):
# 619 9780413772787: dict_keys(['error']):
# 620 9781420926712: dict_keys(['error']):
# 621 9780198144960: dict_keys(['error']):
# 622 9780521834346: dict_keys(['kind', 'totalItems', 'items']): 1: Myths of the Underworld Journey
# 623 9781573921336: dict_keys(['kind', 'totalItems', 'items']): 1: Assembly of Women
# 624 9780198145042: dict_keys(['kind', 'totalItems', 'items']): 2: Comoediae
# 625 9781853991141: dict_keys(['kind', 'totalItems', 'items']): 1: Aristophanes and His Theatre of the Absurd
# 626 9781883011086: dict_keys(['error']):
# 627 9781883011079: dict_keys(['error']):
# 628 9780375415029: dict_keys(['kind', 'totalItems', 'items']): 1: The Lady in the Lake, The Little Sister, The Long Goodbye, Playback
# 629 9780394758268: dict_keys(['kind', 'totalItems', 'items']): 1: The High Window
# 630 9780394757650: dict_keys(['error']):
# 631 9780394758282: dict_keys(['error']):
# 632 9780394757681: dict_keys(['error']):
# 633 9780812970401: dict_keys(['kind', 'totalItems', 'items']): 1: An Evening of Long Goodbyes
# 634 9780452286870: dict_keys(['error']):
# 635 9781421501567: dict_keys(['kind', 'totalItems', 'items']): 1: Ghost In the Shell 2: Innocence (Novel-Hard Cover)
# 636 9780563524748: dict_keys(['error']):
# 637 9780670034727: dict_keys(['error']):
# 638 9780684824710: dict_keys(['kind', 'totalItems', 'items']): 1: Darwin's Dangerous Idea
# 639 9780142003848: dict_keys(['error']):
# 640 9780262540377: dict_keys(['error']):
# 641 9780465073511: dict_keys(['kind', 'totalItems', 'items']): 1: Kinds Of Minds
# 642 9780387987200: dict_keys(['error']):
# 643 9780262540421: dict_keys(['kind', 'totalItems', 'items']): 1: Elbow Room
# 644 9780553345841: dict_keys(['error']):
# 645 9780553103748: dict_keys(['error']):
# 646 9780553804362: dict_keys(['error']):
# 647 9780553802023: dict_keys(['error']):
# 648 9780762419227: dict_keys(['error']):
# 649 9780465081981: dict_keys(['error']):
# 650 9780393324464: dict_keys(['error']):
# 651 9780380707638: dict_keys(['kind', 'totalItems', 'items']): 1: Stephen Hawking's Universe
# 652 9780691050843: dict_keys(['error']):
# 653 9780060977108: dict_keys(['error']):
# 654 9780713484076: dict_keys(['kind', 'totalItems', 'items']): 1: Falconry and Hawking
# 655 9780316281331: dict_keys(['error']):
# 656 9780452282315: dict_keys(['kind', 'totalItems', 'items']): 1: The Art of Nonfiction
# 657 9780452278875: dict_keys(['error']):
# 658 9780451191151: dict_keys(['error']):
# 659 9780446618762: dict_keys(['kind', 'totalItems', 'items']): 1: The 36-Hour Day
# 660 9780060793197: dict_keys(['kind', 'totalItems', 'items']): 1: The 3-Hour Diet (TM) On the Go (Collins Gem)
# 661 9781400051571: dict_keys(['error']):
# 662 9780312425029: dict_keys(['error']):
# 663 9780312424084: dict_keys(['error']):
# 664 9780316172325: dict_keys(['error']):
# 665 9780849945113: dict_keys(['error']):
# 666 9780743422079: dict_keys(['error']):
# 667 9780517147689: dict_keys(['kind', 'totalItems', 'items']): 1: The Complete Novels
# 668 9780452286535: dict_keys(['error']):
# 669 9780517118290: dict_keys(['kind', 'totalItems', 'items']): 2: The Complete Novels
# 670 9780192832979: dict_keys(['kind', 'totalItems', 'items']): 1: Jane Austen's Letters
# 671 9780192802637: dict_keys(['error']):
# 672 9780972121798: dict_keys(['kind', 'totalItems', 'items']): 1: Tea with Jane Austen
# 673 9780743564366: dict_keys(['kind', 'totalItems']):
# 674 9780764586606: dict_keys(['error']):
# 675 9780679731368: dict_keys(['error']):
# 676 9780140435825: dict_keys(['error']):
# 677 9780192836229: dict_keys(['error']):
# 678 9780140448009: dict_keys(['error']):
# 679 9780140447972: dict_keys(['error']):
# 680 9780226735191: dict_keys(['kind', 'totalItems', 'items']): 1: The Family Idiot
# 681 9780312422158: dict_keys(['error']):
# 682 9780743270755: dict_keys(['error']):
# 683 9780743223133: dict_keys(['kind', 'totalItems', 'items']): 1: John Adams
# 684 9781574671322: dict_keys(['error']):
# 685 9780142437117: dict_keys(['kind', 'totalItems', 'items']): 1: The Letters of John and Abigail Adams
# 686 9780393311334: dict_keys(['error']):
# 687 9780142437780: dict_keys(['kind', 'totalItems', 'items']): 1: The Portable John Adams
# 688 9780764553028: dict_keys(['error']):
# 689 9780471773863: dict_keys(['error']):
# 690 9780452281325: dict_keys(['error']):
# ...
# 10836 9788448306991: dict_keys(['error']):
# 10837 9780349105307: dict_keys(['error']):
# 10838 9780345369079: dict_keys(['kind', 'totalItems', 'items']): 1: Silver Pigs
# 10839 9780312357771: dict_keys(['error']):
# 10840 9780563525691: dict_keys(['kind', 'totalItems']):
# 10841 9781904316343: dict_keys(['error']):
# 10842 9780394746234: dict_keys(['error']):
# 10843 9780679601708: dict_keys(['error']):
# 10844 9780679601128: dict_keys(['error']):
# 10845 9780060757403: dict_keys(['error']):
# 10846 9780679736042: dict_keys(['error']):
# 10847 9781586631987: dict_keys(['error']):
# 10848 9780393040586: dict_keys(['error']):
# 10849 9780385040204: dict_keys(['error']):
# 10850 9780060936662: dict_keys(['kind', 'totalItems', 'items']): 1: Smart Discipline(R)
# 10851 9780375700231: dict_keys(['error']):
# 10852 9780061122187: dict_keys(['error']):
# 10853 9781877058332: dict_keys(['error']):
# 10854 9780064407458: dict_keys(['error']):
# 10855 9780064408622: dict_keys(['error']):
# 10856 9780142405499: dict_keys(['error']):
# 10857 9780064470650: dict_keys(['error']):
# 10858 9780060594343: dict_keys(['kind', 'totalItems', 'items']): 1: Goat Girls
# 10859 9780060594350: dict_keys(['error']):
# 10860 9780060736255: dict_keys(['error']):
# 10861 9780310263456: dict_keys(['error']):
# 10862 9780385721912: dict_keys(['kind', 'totalItems', 'items']): 1: Man Walks Into a Room
# 10863 9780060927516: dict_keys(['error']):
# 10864 9780830819713: dict_keys(['error']):
# 10865 9780310210085: dict_keys(['error']):
# 10866 9780830832941: dict_keys(['error']):
# 10867 9780310257868: dict_keys(['error']):
# 10868 9780310243564: dict_keys(['kind', 'totalItems', 'items']): 1: "A" is for Abductive
# 10869 9780310252191: dict_keys(['error']):
# 10870 9780486429922: dict_keys(['error']):
# 10871 9780143039532: dict_keys(['error']):
# 10872 9780743211482: dict_keys(['error']):
# 10873 9780141182582: dict_keys(['error']):
# 10874 9780679643241: dict_keys(['error']):
# 10875 9780739309056: dict_keys(['error']):
# 10876 9781841580821: dict_keys(['error']):
# 10877 9781859737095: dict_keys(['kind', 'totalItems', 'items']): 1: Architecture and Tourism
# 10878 9780529123459: dict_keys(['error']):
# 10879 9780618705290: dict_keys(['error']):
# 10880 9780618586455: dict_keys(['error']):
# 10881 9780618582150: dict_keys(['error']):
# 10882 9780060815523: dict_keys(['error']):
# 10883 9780300095241: dict_keys(['error']):
# 10884 9780880291231: dict_keys(['error']):
# 10885 9780226134345: dict_keys(['error']):
# 10886 9780060582548: dict_keys(['kind', 'totalItems']):
# 10887 9780140018325: dict_keys(['error']):
# 10888 9780156001991: dict_keys(['kind', 'totalItems', 'items']): 1: Roald Dahl
# 10889 9780141805627: dict_keys(['error']):
# 10890 9780141805610: dict_keys(['error']):
# 10891 9780141805641: dict_keys(['error']):
# 10892 9781555834531: dict_keys(['error']):
# 10893 9780151012978: dict_keys(['error']):
# 10894 9780156032612: dict_keys(['error']):
# 10895 9780064407724: dict_keys(['error']):
# 10896 9780156032643: dict_keys(['error']):
# 10897 9781555837235: dict_keys(['error']):
# 10898 9780231109253: dict_keys(['error']):
# 10899 9780241136829: dict_keys(['error']):
# 10900 9781841190495: dict_keys(['error']):
# 10901 9780156007474: dict_keys(['error']):
# 10902 9781899791668: dict_keys(['error']):
# 10903 9780060997021: dict_keys(['kind', 'totalItems', 'items']): 1: Life Is Elsewhere
# 10904 9780307343123: dict_keys(['kind', 'totalItems', 'items']): 1: Todo está iluminado
# 10905 9780812521351: dict_keys(['error']):
# 10906 9780618554591: dict_keys(['error']):
# 10907 9780140818031: dict_keys(['error']):
# 10908 9780140274219: dict_keys(['error']):
# 10909 9780786704545: dict_keys(['error']):
# 10910 9780701125592: dict_keys(['error']):
# 10911 9780310330516: dict_keys(['kind', 'totalItems', 'items']): 1: The Complete Green Letters
# 10912 9781586212230: dict_keys(['error']):
# 10913 9780618446711: dict_keys(['error']):
# 10914 9780451190147: dict_keys(['error']):
# 10915 9780767922081: dict_keys(['error']):
# 10916 9780671792800: dict_keys(['error']):
# 10917 9781400083411: dict_keys(['kind', 'totalItems', 'items']): 1: Los 7 Hábitos de las Familias Altamente Efectivas
# 10918 9781590385814: dict_keys(['error']):
# 10919 9780552148085: dict_keys(['error']):
# 10920 9780552148108: dict_keys(['error']):
# 10921 9780886840495: dict_keys(['error']):
# 10922 9781421503196: dict_keys(['error']):
# 10923 9780881792065: dict_keys(['error']):
# 10924 9780618772452: dict_keys(['error']):
# 10925 9781401881542: dict_keys(['kind', 'totalItems', 'items']): 1: Graphic Design Solutions
# 10926 9780449210840: dict_keys(['kind', 'totalItems', 'items']): 1: The Mask of the Enchantress
# 10927 9780449212967: dict_keys(['kind', 'totalItems', 'items']): 1: Secret for a Nightingale
# 10928 9780449215487: dict_keys(['kind', 'totalItems', 'items']): 1: The Silk Vendetta
# 10929 9780449200681: dict_keys(['error']):
# 10930 9780440224044: dict_keys(['error']):
# 10931 9780802139702: dict_keys(['error']):
# 10932 9780451211576: dict_keys(['error']):
# 10933 9780679832690: dict_keys(['error']):
# 10934 9780964366565: dict_keys(['kind', 'totalItems', 'items']): 1: Lo Unico Queno Podras Hacer En El Cielo
# 10935 9780099284765: dict_keys(['kind', 'totalItems', 'items']): 1: The Moon and Sixpence
# 10936 9788484034346: dict_keys(['error']):
# 10937 9782035882134: dict_keys(['kind', 'totalItems', 'items']): 1: Un amour de Swann
# 10938 9780312288013: dict_keys(['error']):
# 10939 9780312977672: dict_keys(['error']):
# 10940 9780520234413: dict_keys(['error']):
# 10941 9780312643065: dict_keys(['error']):
# 10942 9781580012515: dict_keys(['error']):
# 10943 9780679729969: dict_keys(['error']):
# 10944 9781561587384: dict_keys(['error']):
# 10945 9781892395566: dict_keys(['error']):
# 10946 9780199203611: dict_keys(['error']):
# 10947 9780395051566: dict_keys(['kind', 'totalItems', 'items']): 1: Poetry and Prose of Alexander Pope
# 10948 9781401850685: dict_keys(['error']):
# 10949 9781423600763: dict_keys(['error']):
# 10950 9780385732598: dict_keys(['error']):
# 10951 9780735611313: dict_keys(['error']):
# 10952 9780974811826: dict_keys(['error']):
# 10953 9780571219315: dict_keys(['error']):
# 10954 9780060586904: dict_keys(['error']):
# 10955 9780517566091: dict_keys(['error']):
# 10956 9780802715401: dict_keys(['error']):
# 10957 9781590303160: dict_keys(['error']):
# 10958 9780451205148: dict_keys(['error']):
# 10959 9780735617223: dict_keys(['error']):
# 10960 76092025986: dict_keys(['error']):
# 10961 9780838814604: dict_keys(['kind', 'totalItems', 'items']): 1: Explode the Code
# 10962 9780553280814: dict_keys(['error']):
# 10963 9780385340359: dict_keys(['error']):
# 10964 9780500281338: dict_keys(['kind', 'totalItems']):
# 10965 9780201485677: dict_keys(['error']):
# 10966 9780767900959: dict_keys(['error']):
# 10967 9781593270032: dict_keys(['error']):
# 10968 9780804831901: dict_keys(['error']):
# 10969 9780465039135: dict_keys(['error']):
# 10970 9781902538341: dict_keys(['kind', 'totalItems', 'items']): 1: Landscape Within
# 10971 9780793536696: dict_keys(['error']):
# 10972 9780786229987: dict_keys(['error']):
# 10973 9780786168477: dict_keys(['error']):
# 10974 9780517091265: dict_keys(['error']):
# 10975 9780486445083: dict_keys(['kind', 'totalItems', 'items']): 1: Kim
# 10976 9780812971347: dict_keys(['error']):
# 10977 9781400078677: dict_keys(['error']):
# 10978 9780761545644: dict_keys(['error']):
# 10979 9780671877781: dict_keys(['kind', 'totalItems', 'items']): 1: The Free Bards
# 10980 9781574881721: dict_keys(['error']):
# 10981 9780425206867: dict_keys(['error']):
# 10982 9780800614287: dict_keys(['kind', 'totalItems', 'items']): 1: Liturgies of the Western Church
# 10983 9781416532828: dict_keys(['kind', 'totalItems', 'items']): 1: Bedlam's Bard
# 10984 9780192802644: dict_keys(['error']):
# 10985 9780896583214: dict_keys(['error']):
# 10986 9780375757815: dict_keys(['kind', 'totalItems', 'items']): 1: Mansfield Park
# 10987 9780755331475: dict_keys(['kind', 'totalItems', 'items']): 1: Mansfield Park
# 10988 9780140620665: dict_keys(['error']):
# 10989 9780762408283: dict_keys(['error']):
# 10990 9781561381487: dict_keys(['error']):
# 10991 9781406503258: dict_keys(['kind', 'totalItems', 'items']): 1: Stalky & Co
# 10992 9780393963328: dict_keys(['error']):
# 10993 9781841811109: dict_keys(['error']):
# 10994 9781593083236: dict_keys(['error']):
# 10995 9780006498865: dict_keys(['kind', 'totalItems', 'items']): 1: The Mad Ship
# 10996 9780553575651: dict_keys(['error']):
# 10997 9780060757632: dict_keys(['error']):
# 10998 9780553565690: dict_keys(['kind', 'totalItems', 'items']): 1: Assassin's Quest
# 10999 9783404283361: dict_keys(['kind', 'totalItems', 'items']): 1: Die zweiten Chroniken von Fitz dem Weitseher
# 11000 9780425199350: dict_keys(['error']):
# 11001 9780312956127: dict_keys(['kind', 'totalItems', 'items']): 1: The Scold's Bridle
# 11002 9780425214923: dict_keys(['error']):
# 11003 9780307264626: dict_keys(['kind', 'totalItems', 'items']): 1: The Devil's Feather
# 11004 9780515128826: dict_keys(['error']):
# 11005 9780515122565: dict_keys(['error']):
# 11006 9780099416159: dict_keys(['error']):
# 11007 9780670060238: dict_keys(['error']):
# 11008 9780061214967: dict_keys(['error']):
# 11009 9780316013949: dict_keys(['error']):
# 11010 9780140621624: dict_keys(['error']):
# 11011 9780140367355: dict_keys(['error']):
# 11012 9780143039150: dict_keys(['error']):
# 11013 9780140367430: dict_keys(['kind', 'totalItems', 'items']): 1: The Enchanted Castle
# 11014 9781402732980: dict_keys(['kind', 'totalItems', 'items']): 1: Off to Sea
# 11015 9781840460278: dict_keys(['error']):
# 11016 9780141441160: dict_keys(['error']):
# 11017 9780140274233: dict_keys(['error']):
# 11018 9780192833884: dict_keys(['error']):
# 11019 9780192833075: dict_keys(['kind', 'totalItems', 'items']): 1: Miss Or Mrs?
# 11020 9780140436075: dict_keys(['kind', 'totalItems', 'items']): 1: The Law and the Lady
# 11021 9781857150186: dict_keys(['kind', 'totalItems', 'items']): 1: The Woman in White
# 11022 9780192834676: dict_keys(['error']):
# 11023 9780451160317: dict_keys(['error']):
# 11024 9780451131362: dict_keys(['error']):
# 11025 9780671020828: dict_keys(['error']):
# 11026 9780812555240: dict_keys(['kind', 'totalItems', 'items']): 1: A Quantum Murder
# 11027 9780345461674: dict_keys(['error']):
# 11028 9780345461629: dict_keys(['kind', 'totalItems', 'items']): 1: Pandora's Star
# 11029 9780812590562: dict_keys(['error']):
# 11030 9780446605168: dict_keys(['error']):
# 11031 9780953284122: dict_keys(['error']):
# 11032 9781900826242: dict_keys(['error']):
# 11033 9788466616928: dict_keys(['error']):
# 11034 9780434008179: dict_keys(['error']):
# 11035 9788497930970: dict_keys(['error']):
# 11036 9780142437681: dict_keys(['kind', 'totalItems', 'items']): 1: The Portable Walt Whitman
# 11037 9780679767091: dict_keys(['kind', 'totalItems', 'items']): 1: Walt Whitman's America
# 11038 9780060535117: dict_keys(['error']):
# 11039 9780439357913: dict_keys(['kind', 'totalItems', 'items']): 1: Walt Whitman
# 11040 9784770028037: dict_keys(['error']):
# 11041 9781400096084: dict_keys(['error']):
# 11042 9781860469862: dict_keys(['error']):
# 11043 9784770015440: dict_keys(['kind', 'totalItems', 'items']): 1: Hard-boiled Wonderland and the End of the World
# 11044 9780679446699: dict_keys(['kind', 'totalItems', 'items']): 1: The Wind-up Bird Chronicle
# 11045 9780375413902: dict_keys(['error']):
# 11046 9781400043668: dict_keys(['kind', 'totalItems', 'items']): 1: Kafka on the Shore
# 11047 9780375411694: dict_keys(['error']):
# 11048 9783791329284: dict_keys(['error']):
# 11049 9780835608473: dict_keys(['error']):
# 11050 9781590171707: dict_keys(['kind', 'totalItems', 'items']): 1: Dime-store Alchemy
# 11051 9781933648279: dict_keys(['error']):
# 11052 9780812971453: dict_keys(['kind', 'totalItems', 'items']): 1: Rendezvous in Black
# 11053 9780689871313: dict_keys(['error']):
# 11054 9781581348767: dict_keys(['error']):
# 11055 9781844740444: dict_keys(['error']):
# 11056 9781581348095: dict_keys(['kind', 'totalItems', 'items']): 1: Suffering and the Sovereignty of God
# 11057 9781581346527: dict_keys(['error']):
# 11058 9781581348132: dict_keys(['error']):
# 11059 9781581342475: dict_keys(['kind', 'totalItems', 'items']): 1: The Hidden Smile of God
# 11060 9781581346084: dict_keys(['kind', 'totalItems', 'items']): 1: The Passion of Jesus Christ
# 11061 9781400097036: dict_keys(['error']):
# 11062 9780449001172: dict_keys(['error']):
# 11063 9780345440839: dict_keys(['kind', 'totalItems', 'items']): 1: Schmidt Delivered
# 11064 9780761327059: dict_keys(['error']):
# 11065 9780142003565: dict_keys(['kind', 'totalItems', 'items']): 1: The Classic Ten
# 11066 9780140097368: dict_keys(['kind', 'totalItems', 'items']): 1: The Locked Room
# 11067 9780852237519: dict_keys(['error']):
# 11068 9780786849604: dict_keys(['kind', 'totalItems', 'items']): 1: Half Moon Investigations
# 11069 9780786851492: dict_keys(['error']):
# 11070 9780439443364: dict_keys(['error']):
# 11071 9780786855032: dict_keys(['kind', 'totalItems', 'items']): 1: Eoin Colfer's Legend of the Worst Boy in the World
# 11072 9780786855018: dict_keys(['error']):
# 11073 9780307344670: dict_keys(['kind', 'totalItems', 'items']): 1: Artemis Fowl
# 11074 9780862786021: dict_keys(['error']):
# 11075 9783548603209: dict_keys(['kind', 'totalItems', 'items']): 1: Artemis Fowl
# 11076 9780307350053: dict_keys(['kind', 'totalItems', 'items']): 1: La Ultima Oportunidad
# 11077 9788497939201: dict_keys(['kind', 'totalItems', 'items']): 1: Artemis Fowl I-mundo Subterraneo
# 11078 9788484412472: dict_keys(['kind', 'totalItems', 'items']): 1: Artemis Fowl IV - La venganza de Opal
# 11079 9780307343109: dict_keys(['error']):
# 11080 9781400085910: dict_keys(['kind', 'totalItems', 'items']): 1: Artemis Fowl
# 11081 9780739336502: dict_keys(['error']):
# 11082 9780375846724: dict_keys(['error']):
# 11083 9780375846731: dict_keys(['error']):
# 11084 9780807210475: dict_keys(['kind', 'totalItems']):
# 11085 9780375847226: dict_keys(['error']):
# 11086 9788440699473: dict_keys(['error']):
# 11087 9780375947223: dict_keys(['error']):
# 11088 9780439994125: dict_keys(['error']):
# 11089 9780062511409: dict_keys(['kind', 'totalItems', 'items']): 1: El Alquimista
# 11090 9780307274113: dict_keys(['error']):
# 11091 9780061351341: dict_keys(['kind', 'totalItems', 'items']): 1: El Alquimista: Edicion Illustrada
# 11092 9781861974426: dict_keys(['kind', 'totalItems', 'items']): 1: Call of the Mall
# 11093 9780887309427: dict_keys(['error']):
# 11094 9781594860164: dict_keys(['error']):
# 11095 9780066619910: dict_keys(['kind', 'totalItems', 'items']): 1: The Die Broke Financial Problem Solver
# 11096 9780394729640: dict_keys(['error']):
# 11097 9780140137002: dict_keys(['error']):
# 11098 9782070323289: dict_keys(['error']):
# 11099 9780140054712: dict_keys(['error']):
# 11100 9780142437254: dict_keys(['error']):
# 11101 9780743477888: dict_keys(['error']):
# 11102 9781415918098: dict_keys(['error']):
# 11103 9780684833248: dict_keys(['error']):
# 11104 9781568520803: dict_keys(['error']):
# 11105 9789681907198: dict_keys(['error']):
# 11106 9780573051333: dict_keys(['kind', 'totalItems', 'items']): 1: Fantastic Mr Fox
# 11107 9781855495098: dict_keys(['error']):
# 11108 9781932394610: dict_keys(['error']):
# 11109 9788466318778: dict_keys(['error']):
# 11110 9788432217289: dict_keys(['error']):
# 11111 9788466302296: dict_keys(['error']):
# 11112 9788432203237: dict_keys(['error']):
# 11113 9789583006401: dict_keys(['error']):
# 11114 9780061199004: dict_keys(['error']):
# 11115 9789722331685: dict_keys(['error']):
# 11116 9789722332200: dict_keys(['error']):
# 11117 9789722330558: dict_keys(['error']):
# 11118 9789722329989: dict_keys(['error']):
# 11119 9789722331326: dict_keys(['error']):
# 11120 9789722330978: dict_keys(['error']):
# 11121 9780140231571: dict_keys(['error']):
# 11122 9781560254416: dict_keys(['kind', 'totalItems', 'items']): 1: Expelled from Eden
# 11123 9780140110876: dict_keys(['error']):
# 11124 9780140131963: dict_keys(['error']):
# 11125 9780060878825: dict_keys(['error']):
# 11126 9788497646987: dict_keys(['error']):

# %%
response_df
# Out:
#                                                   title  \
# 0               Harry Potter and the Chamber of Secrets
# 1              Harry Potter and the Prisoner of Azkaban
# 2                                          Harry Potter
# 3     Unauthorized Harry Potter and the Deathly Hall...
# 4                           The Harry Potter Collection
# ...                                                 ...
# 2756                  El Alquimista: Edicion Illustrada
# 2757                                   Call of the Mall
# 2758             The Die Broke Financial Problem Solver
# 2759                                   Fantastic Mr Fox
# 2760                                 Expelled from Eden
#
#                                                subtitle  \
# 0
# 1
# 2     5 Years of Magic, Adventure, and Mystery at Ho...
# 3     Harry Potter Book Seven and Half-Blood Prince ...
# 4     The First Six Spellbinding Adventures at Hogwarts
# ...                                                 ...
# 2756
# 2757                                        How We Shop
# 2758    Six Steps to Overcoming All Your Money Problems
# 2759
# 2760                       A William T. Vollmann Reader
#
#                                authors              publisher publishdate  \
# 0       [J. K. Rowling, Mary GrandPre]        Arthur a Levine        2003
# 1                      [J. K. Rowling]  Scholastic Paperbacks        2004
# 2                      [J. K. Rowling]                               2004
# 3             [W. Frederick Zimmerman]           Nimble Books     2005-04
# 4                      [J. K. Rowling]        Arthur a Levine  2005-10-01
# ...                                ...                    ...         ...
# 2756                    [Paulo Coelho]         Harper Collins  2007-04-10
# 2757                  [Paco Underhill]       Profile Business        2004
# 2758  [Stephen M. Pollan, Mark Levine]      Harper Paperbacks  2000-12-26
# 2759                      [David Wood]  Samuel French Limited        2003
# 2760                         [Perseus]         Carroll & Graf  2004-12-21
#
#                                             description        isbn_13  \
# 0     When the Chamber of Secrets is opened again at...  9780439554893
# 1     During his third year at Hogwarts School for W...  9780439655484
# 2                                                        9780439682589
# 3     Through the magic of print-on-demand technolog...  9780976540601
# 4     The first six years of Harry Potter magic are ...  9780439827607
# ...                                                 ...            ...
# 2756  Exuberante, evocativo y profundamente humano, ...  9780061351341
# 2757  Like Underhill's bestseller, Why We Buy, this ...  9781861974426
# 2758  If you're loosing sleep over your financial wo...  9780066619910
# 2759  Adaptation into a play of the Roald Dahl class...  9780573051333
# 2760  No stranger to living and writing on the edge,...  9781560254416
#
#      page_count         main_categories              categories  \
# 0           341      [Juvenile Fiction]      [Juvenile Fiction]
# 1           547      [Juvenile Fiction]      [Juvenile Fiction]
# 2             0
# 3           152               [Fiction]               [Fiction]
# 4                    [Juvenile Fiction]      [Juvenile Fiction]
# ...         ...                     ...                     ...
# 2756        200               [Fiction]               [Fiction]
# 2757        227     [Consumer behavior]     [Consumer behavior]
# 2758        272  [Business & Economics]  [Business & Economics]
# 2759         43                 [Drama]                 [Drama]
# 2760        479               [Fiction]               [Fiction]
#
#      average_rating ratings_count maturity_rating
# 0               4.5          2273      NOT_MATURE
# 1               4.5          2122      NOT_MATURE
# 2               4.5            13      NOT_MATURE
# 3               3.5            11      NOT_MATURE
# 4               4.5            16      NOT_MATURE
# ...             ...           ...             ...
# 2756              5             2      NOT_MATURE
# 2757                                   NOT_MATURE
# 2758                                   NOT_MATURE
# 2759              3             1      NOT_MATURE
# 2760              3             1      NOT_MATURE
#
# [2761 rows x 13 columns]

# %%
response_df.to_csv('isbn13_results.csv')

# %% [markdown]
# Using Google Books API to fix missing data in Kaggle Dataset

# %%
# get the faulty ISBN
isbn = isbn_13.loc[0]
print(isbn)

# url for the book
url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn}"

# get the book
response = requests.get(url)

# convert the HTTP Response object to a dict
json = response.json()

# get the keys for the dict
json.keys()

# %%
temp = temp

# %%
print(f'in_google: {in_google}\nnot_in_google: {not_in_google}')

# %%
json['items'][0]['volumeInfo']
