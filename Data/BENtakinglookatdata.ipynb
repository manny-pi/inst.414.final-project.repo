# %%
import pandas as pd

# %%
data = pd.read_csv('three_cols.csv')
data
# Out:
#              isbn  Main Category        Categories  \
# 0       439785960            NaN               NaN
# 1       439358078            NaN               NaN
# 2       439554896            NaN               NaN
# 3      043965548X            NaN  Juvenile Fiction
# 4       439682584            NaN               NaN
# ...           ...            ...               ...
# 11122  1560254416            NaN           Fiction
# 11123   140110879            NaN               NaN
# 11124   140131965            NaN               NaN
# 11125    60878827            NaN               NaN
# 11126  8497646983            NaN               NaN
#
#                                              Description
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      During his third year at Hogwarts School for W...
# 4                                                    NaN
# ...

# %%
data.loc[data['Description'].notnull()]
# Out:
#              isbn  Main Category        Categories  \
# 3      043965548X            NaN  Juvenile Fiction
# 33     1595962808            NaN           Fiction
# 55     1596670231            NaN         Education
# 95     1593081774            NaN          Adultery
# 116    1400032466            NaN           Fiction
# ...           ...            ...               ...
# 11018  019283388X            NaN           Fiction
# 11035  8497930975            NaN           Fiction
# 11054  1581348762            NaN          Religion
# 11118  9722329987            NaN          Children
# 11122  1560254416            NaN           Fiction
#
#                                              Description
# 3      During his third year at Hogwarts School for W...
# 33     A Changeling For All Seasons Ten unforgettable...
# 55     Presents cross-curricular teaching strategies ...
# 95     "Married to a powerful government minister, An...
# 116    After a brutal day investigating a quadruple h...
# ...
