# %% [markdown]
# ## This is a file to test methods on how to gather data using the "Original dataset" csv file that is in this Data folder.

# %%
import pandas as pd
import requests
import numpy as np

# %% [markdown]
# ## testing endpoint

# %%
book_id = "FBXRzgEACAAJ"
url = f"https://www.googleapis.com/books/v1/volumes/{book_id}"
response = requests.get(url)

if response.status_code == 200:
    book_data = response.json()
    # do something with the book data
else:
    print("Error:", response.status_code)

# %%
book_data["volumeInfo"]
# Out:
# {'title': 'Harry Potter and the Prisoner of Azkaban',
#  'authors': ['J. K. Rowling'],
#  'publisher': 'Scholastic, Incorporated',
#  'publishedDate': '2004',
#  'description': 'Harry Potter has to sneak back to Hogwarts, after accidentally inflating his horrible Aunt Petunia. But once there everyone is whispering about a prizoner who has escaped from the famous wizard prizon, Azkaban. His name is Sirius Black, and as a follower of Lord Voldemort he is determined to track Harry Potter down -- even if it means laying siege to the very walls of Hogwarts!',
#  'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '043965548X'},
#   {'type': 'ISBN_13', 'identifier': '9780439655484'}],
#  'readingModes': {'text': False, 'image': False},
#  'pageCount': 547,
#  'printedPageCount': 547,
#  'dimensions': {'height': '17.00 cm',
#   'width': '9.50 cm',
#   'thickness': '3.20 cm'},
#  'printType': 'BOOK',
#  'categories': ['Juvenile Fiction / Fantasy & Magic'],
#  'averageRating': 4.5,
#  'ratingsCount': 2122,
#  'maturityRating': 'NOT_MATURE',
#  'allowAnonLogging': False,
#  'contentVersion': 'preview-1.0.0',
#  'panelizationSummary': {'containsEpubBubbles': False,
#   'containsImageBubbles': False},
#  'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=FBXRzgEACAAJ&printsec=frontcover&img=1&zoom=5&imgtk=AFLRE70lctVEosfShp9vtNr3s0t8_KbPin09b2SZ4uyFQiV5qdL8HFYuTUzu1IQf4LM8klyiq6t-V59d1_UR2B2Y2qDhGYZeI57L7ad_T0orgVZwaVgVDLXkf46_byg57gTvaCmW9JRN&source=gbs_api',
#   'thumbnail': 'http://books.google.com/books/content?id=FBXRzgEACAAJ&printsec=frontcover&img=1&zoom=1&imgtk=AFLRE73PmgfqCG4XLFeMIYCFXrXC7qc7OQwh7u9JO3davRNNdF3flhrHRzAihgNsh6KQH2-eRxt_Jll-3oAJr-Yi4Vbfw6zpLp5_7a-d21awHCxBDflsv3hdGHY4aHblrjzDubHh4bDt&source=gbs_api'},
#  'language': 'en',
#  'previewLink': 'http://books.google.com/books?id=FBXRzgEACAAJ&hl=&source=gbs_api',
#  'infoLink': 'https://play.google.com/store/books/details?id=FBXRzgEACAAJ&source=gbs_api',
#  'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=FBXRzgEACAAJ'}

# %% [markdown]
# ## writing a function to pull book data form the google books api

# %%
def get_book_data(df, col_name):
    # create an empty list to store the book data
    book_data_list = []
    url_base = 'https://www.googleapis.com/books/v1/volumes?q=id:'

    # iterate over the book ids, and get the information we need using the Google Books API
    for i, book_id in enumerate(df[col_name]):

        # generate the URL for the Google Books API search 
        url = url_base + book_id

        # get the book data; convert it to a dictionary using .json()
        book_data = requests.get(url).json()

        print(f'{i} {book_id}: {book_data.keys()}', end=': ')

        if 'totalItems' in book_data and book_data['totalItems'] > 0:

            print(book_data['totalItems'], end=': ')
            print(book_data['items'][0]['volumeInfo']['title'], end='')
            # extract the relevant fields and create a new row in the DataFrame
            book = {
                'book_id': book_id,
                'average_rating': book_data['items'][0]['volumeInfo'].get('averageRating', np.nan),
                'ratings_count': book_data['items'][0]['volumeInfo'].get('ratingsCount', np.nan),
            }

            # append the new dictionary to the book_data_list
            book_data_list.append(book)
        else:

            # handle the case where no results were returned for the book id
            book = {
                'book_id': book_id,
                'average_rating': np.nan,
                'ratings_count': np.nan,
            }
            book_data_list.append(book)

        print()

    # convert the list of dictionaries to a DataFrame
    response_df = pd.DataFrame(book_data_list)
    return response_df

# %% [markdown]
# ## testing subset

# %%
subset = pd.read_csv("all_book_ids.csv")
subset = subset.head(5)
subset["book_id"]
# Out:
# 0    FBXRzgEACAAJ
# 1    yyxXzQEACAAJ
# 2    YjAnfhsAQ8wC
# 3    xb4wSmJLnhAC
# 4    Qq9nQgAACAAJ
# Name: book_id, dtype: object

# %%
test_data = get_book_data(subset, "book_id")
test_data
# Out:
# 0 FBXRzgEACAAJ: dict_keys(['kind', 'totalItems']):
# 1 yyxXzQEACAAJ: dict_keys(['kind', 'totalItems']):
# 2 YjAnfhsAQ8wC: dict_keys(['kind', 'totalItems', 'items']): 17: Rosalind Franklin and DNA
# 3 xb4wSmJLnhAC: dict_keys(['kind', 'totalItems']):
# 4 Qq9nQgAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Agile Web Development with Rails
#         book_id  average_rating  ratings_count
# 0  FBXRzgEACAAJ             NaN            NaN
# 1  yyxXzQEACAAJ             NaN            NaN
# 2  YjAnfhsAQ8wC             4.0            2.0
# 3  xb4wSmJLnhAC             NaN            NaN
# 4  Qq9nQgAACAAJ             4.0           46.0

# %% [markdown]
# Using Google Books API to fix missing data in Kaggle Dataset

# %% [markdown]
# ## Pulling all books

# %%
all_books = pd.read_csv("all_book_ids.csv")
all_data = get_book_data(all_books, "book_id")
all_data
# Out:
# 0 FBXRzgEACAAJ: dict_keys(['kind', 'totalItems']):
# 1 yyxXzQEACAAJ: dict_keys(['kind', 'totalItems']):
# 2 YjAnfhsAQ8wC: dict_keys(['kind', 'totalItems', 'items']): 17: Rosalind Franklin and DNA
# 3 xb4wSmJLnhAC: dict_keys(['kind', 'totalItems']):
# 4 Qq9nQgAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Agile Web Development with Rails
# 5 WO_cfDHDIYYC: dict_keys(['kind', 'totalItems', 'items']): 2: A Guide for Using Hatchet in the Classroom
# 6 Jtj9PAAACAAJ: dict_keys(['kind', 'totalItems']):
# 7 JIVSPgAACAAJ: dict_keys(['kind', 'totalItems']):
# 8 TpEoAQAACAAJ: dict_keys(['kind', 'totalItems']):
# 9 4jGQEAAAQBAJ: dict_keys(['kind', 'totalItems', 'items']): 1: The Changeling
# 10 1uJSPgAACAAJ: dict_keys(['kind', 'totalItems']):
# 11 9104ZLuR4Y0C: dict_keys(['kind', 'totalItems', 'items']): 3: Active Literacy Across the Curriculum
# 12 8jxkuQEACAAJ: dict_keys(['kind', 'totalItems']):
# 13 H-AMAQAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 2: Always Enough
# 14 8SBFuQEACAAJ: dict_keys(['kind', 'totalItems']):
# 15 khEua4UXieMC: dict_keys(['kind', 'totalItems']):
# 16 eNq_KlqjJdwC: dict_keys(['kind', 'totalItems']):
# 17 zyXMwAEACAAJ: dict_keys(['kind', 'totalItems']):
# 18 aV-kuQAACAAJ: dict_keys(['kind', 'totalItems']):
# 19 BpobAQAAMAAJ: dict_keys(['kind', 'totalItems']):
# 20 ilINAQAAMAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Kahlil Gibran, His Life and World
# 21 UUl7Zyj841QC: dict_keys(['kind', 'totalItems']):
# 22 fXSODQAAQBAJ: dict_keys(['kind', 'totalItems']):
# 23 cOpWAQAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: LogoLounge
# 24 lzQmUa-fnZUC: dict_keys(['kind', 'totalItems']):
# 25 BJCuAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 26 3AOsNwAACAAJ: dict_keys(['kind', 'totalItems']):
# 27 u8y_9XdJaEMC: dict_keys(['kind', 'totalItems', 'items']): 1: Harrington on Hold 'Em: the Workbook
# 28 nXeMuQAACAAJ: dict_keys(['kind', 'totalItems']):
# 29 JJWMEAAAQBAJ: dict_keys(['kind', 'totalItems', 'items']): 2: Digestive Intelligence
# 30 i-TjPgAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 2: Einsatzmöglichkeiten und Zukunftsperspektiven von Radio Frequency Identification (RFID) in der Supply Chain eines Handelsbetriebes
# 31 cGxOHgpsgX8C: dict_keys(['kind', 'totalItems']):
# 32 nF2PcyCJb0UC: dict_keys(['kind', 'totalItems']):
# 33 Q2CfLfseBzsC: dict_keys(['kind', 'totalItems', 'items']): 2: The Oedipus Cycle
# 34 pqA4ykE59JoC: dict_keys(['kind', 'totalItems', 'items']): 1: The Theban Plays
# 35 jn1bNT1eRbMC: dict_keys(['kind', 'totalItems']):
# 36 P2-PEAAAQBAJ: dict_keys(['kind', 'totalItems', 'items']): 73: The Prince of Frogtown
# 37 4rCumAEACAAJ: dict_keys(['kind', 'totalItems']):
# 38 5VZzSgAACAAJ: dict_keys(['kind', 'totalItems']):
# 39 d40p2M2ikJ8C: dict_keys(['kind', 'totalItems', 'items']): 1: Money to Burn
# 40 XE0MAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 41 iYOMEAAAQBAJ: dict_keys(['kind', 'totalItems']):
# 42 B_YEEAAAQBAJ: dict_keys(['kind', 'totalItems', 'items']): 2: Listen
# 43 pXxuwgEACAAJ: dict_keys(['kind', 'totalItems']):
# 44 hyqNEAAAQBAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Withstanding Vulnerability throughout Adult Life
# 45 ssBRUQiDk74C: dict_keys(['kind', 'totalItems']):
# 46 TilwuQAACAAJ: dict_keys(['kind', 'totalItems']):
# 47 xNHIpVJgcHgC: dict_keys(['kind', 'totalItems', 'items']): 1: Den of Thieves
# 48 Rty8AAAACAAJ: dict_keys(['kind', 'totalItems']):
# 49 FvRqtnpVotwC: dict_keys(['kind', 'totalItems']):
# 50 ryCLuAAACAAJ: dict_keys(['kind', 'totalItems']):
# 51 Jr0LmAz0gVQC: dict_keys(['kind', 'totalItems', 'items']): 1: The Ultimate Time Machine
# 52 hp-YSgAACAAJ: dict_keys(['kind', 'totalItems']):
# 53 9Lzerx2k-G4C: dict_keys(['kind', 'totalItems']):
# 54 rQidEk3MLnMC: dict_keys(['kind', 'totalItems']):
# 55 asGjNgAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: The Southern Mystique
# 56 vb4bAAAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Stat'i o filosofii i častjach eja iz Enciklopedii
# 57 GxBKzgEACAAJ: dict_keys(['kind', 'totalItems']):
# 58 HU0Qcw2GfK4C: dict_keys(['kind', 'totalItems']):
# 59 MHfeAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 60 Hi42AQAAIAAJ: dict_keys(['kind', 'totalItems']):
# 61 -2CgpwAACAAJ: dict_keys(['kind', 'totalItems']):
# 62 QIu5AAAAIAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Black Rednecks and White Liberals
# 63 MuQ2AQAACAAJ: dict_keys(['kind', 'totalItems']):
# 64 kgq8GwAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Sastra dalam wawasan pragmatis
# 65 FsK7mAEACAAJ: dict_keys(['kind', 'totalItems']):
# 66 VPwtDAAAQBAJ: dict_keys(['kind', 'totalItems']):
# 67 YMlFAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 68 kMRmPpDKdUgC: dict_keys(['kind', 'totalItems']):
# 69 kgfuSgAACAAJ: dict_keys(['kind', 'totalItems']):
# 70 ZIQiAQAAIAAJ: dict_keys(['kind', 'totalItems']):
# 71 _5zCoTAb2lYC: dict_keys(['kind', 'totalItems']):
# 72 aTbI5IWK0JEC: dict_keys(['kind', 'totalItems', 'items']): 4: Selected Poems of Herman Melville
# 73 3W9BPgAACAAJ: dict_keys(['kind', 'totalItems']):
# 74 Jh8vAAAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Aliens
# 75 q68EAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 76 yqbCQgAACAAJ: dict_keys(['kind', 'totalItems']):
# 77 z4V4PAAACAAJ: dict_keys(['kind', 'totalItems']):
# 78 xJ6U1VK3SRcC: dict_keys(['kind', 'totalItems', 'items']): 2: David Foster Wallace's Infinite Jest
# 79 omjwLQEACAAJ: dict_keys(['kind', 'totalItems']):
# 80 OJBNr7Qgx28C: dict_keys(['kind', 'totalItems']):
# 81 xLpMD-3PqmAC: dict_keys(['kind', 'totalItems', 'items']): 1: Hemingway & Bailey's Bartending Guide to Great American Writers
# 82 LBGnPwAACAAJ: dict_keys(['kind', 'totalItems']):
# 83 I2QZAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 84 qCVAngEACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: This Side of Paradise
# 85 StQNAAAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 2: Basic Mathematics for Electricity and Electronics
# 86 bWHZ4krDO1YC: dict_keys(['kind', 'totalItems', 'items']): 3: The Untouched Key
# 87 y-ZbPwAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 27: Heart of Darkness
# 88 ucF8nY4gdAUC: dict_keys(['kind', 'totalItems', 'items']): 2: You Shall Know Our Velocity
# 89 1sALAQAAMAAJ: dict_keys(['kind', 'totalItems']):
# 90 YbsDpgcQ9jYC: dict_keys(['kind', 'totalItems', 'items']): 1: A Man Without a Country
# 91 sOZAMsCiz44C: dict_keys(['kind', 'totalItems']):
# 92 EcA-RmEYPWAC: dict_keys(['kind', 'totalItems', 'items']): 1: Breath, Eyes, Memory
# 93 T9UyswEACAAJ: dict_keys(['kind', 'totalItems']):
# 94 yAqOAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 95 iKTgAAAAMAAJ: dict_keys(['kind', 'totalItems', 'items']): 2: American Doctoral Dissertations
# 96 CNCvqVQon9kC: dict_keys(['kind', 'totalItems']):
# 97 J1TJwAEACAAJ: dict_keys(['kind', 'totalItems']):
# 98 QR-0AAAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 9: The Christmas Imperative
# 99 49lEAAAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Come Away My Beloved Devotional Journal
# 100 w60zPQAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 2: Beloved Bride
# 101 j5QnAQAAMAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: International Journal on World Peace
# 102 U3ciAQAAIAAJ: dict_keys(['kind', 'totalItems']):
# 103 f3RHPfF7uCwC: dict_keys(['kind', 'totalItems', 'items']): 2: Howl’s Moving Castle
# 104 NJfZAAAAMAAJ: dict_keys(['kind', 'totalItems']):
# 105 5N4cCOjPjv8C: dict_keys(['kind', 'totalItems', 'items']): 5: Never Let Me Go
# 106 -9ZpAzouCPgC: dict_keys(['kind', 'totalItems']):
# 107 fqVqpPmRbz0C: dict_keys(['kind', 'totalItems']):
# 108 wRcMTL0cbAAC: dict_keys(['kind', 'totalItems']):
# 109 B3d2AAAAMAAJ: dict_keys(['kind', 'totalItems']):
# 110 2rzXAAAAMAAJ: dict_keys(['kind', 'totalItems']):
# 111 9GbH3006EvQC: dict_keys(['kind', 'totalItems']):
# 112 -xSMMJ19NjYC: dict_keys(['kind', 'totalItems', 'items']): 1: It's Not Easy Being Green
# 113 82_EngEACAAJ: dict_keys(['kind', 'totalItems']):
# 114 H2AEAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 115 UCWwQgAACAAJ: dict_keys(['kind', 'totalItems']):
# 116 8o_vPQAACAAJ: dict_keys(['kind', 'totalItems']):
# 117 wZc-0xsyJIsC: dict_keys(['kind', 'totalItems']):
# 118 MRT-Wf9x_qQC: dict_keys(['kind', 'totalItems']):
# 119 KvyLDQAAQBAJ: dict_keys(['kind', 'totalItems']):
# 120 TgsEAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 121 -1RQAAAAMAAJ: dict_keys(['kind', 'totalItems']):
# 122 4H8SfpY__OQC: dict_keys(['kind', 'totalItems']):
# 123 xOOgRlo5SgQC: dict_keys(['kind', 'totalItems']):
# 124 iuNtwgEACAAJ: dict_keys(['kind', 'totalItems']):
# 125 JH5JPgAACAAJ: dict_keys(['kind', 'totalItems']):
# 126 ZwNwDwAAQBAJ: dict_keys(['kind', 'totalItems']):
# 127 qk8ps8dtZgIC: dict_keys(['kind', 'totalItems']):
# 128 9RNLngEACAAJ: dict_keys(['kind', 'totalItems']):
# 129 FrlPEAAAQBAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Fatherland
# 130 FToaDLPB2jAC: dict_keys(['kind', 'totalItems', 'items']): 3: Southern Innovator Magazine Issue 4: Cities and Urbanization
# 131 4LfbAgAAQBAJ: dict_keys(['kind', 'totalItems']):
# 132 1NCFlAEACAAJ: dict_keys(['kind', 'totalItems']):
# 133 -ODhDwAAQBAJ: dict_keys(['kind', 'totalItems']):
# 134 kPuaGwAACAAJ: dict_keys(['kind', 'totalItems']):
# 135 vrAja1wLa5AC: dict_keys(['kind', 'totalItems']):
# 136 CFPdjwEACAAJ: dict_keys(['kind', 'totalItems']):
# 137 WsOwAAAAIAAJ: dict_keys(['kind', 'totalItems']):
# 138 hPv5r4hcM3EC: dict_keys(['kind', 'totalItems', 'items']): 1: The Second Sex
# 139 a7WmDAEACAAJ: dict_keys(['kind', 'totalItems']):
# 140 2cugvvYDIJsC: dict_keys(['kind', 'totalItems']):
# 141 3hWBPwAACAAJ: dict_keys(['kind', 'totalItems']):
# 142 vT4sAQAAIAAJ: dict_keys(['kind', 'totalItems']):
# 143 KKscoUF0OJsC: dict_keys(['kind', 'totalItems', 'items']): 1: Zorba the Greek
# 144 deSsPQAACAAJ: dict_keys(['kind', 'totalItems']):
# 145 7gGTSQAACAAJ: dict_keys(['kind', 'totalItems']):
# 146 KsixAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 147 johavgAACAAJ: dict_keys(['kind', 'totalItems']):
# 148 9z3nvyI6OSgC: dict_keys(['kind', 'totalItems']):
# 149 HhTVAAAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: The Idaho Hemingway
# 150 CzlXAAAAYAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Building Employment Brand Equity Effect of Firm Practices, Employee Outcomes and Organizational Outcomes
# 151 jZbHwEPpwFwC: dict_keys(['kind', 'totalItems']):
# 152 e1qAAlAlhuAC: dict_keys(['kind', 'totalItems']):
# 153 OAlCPgAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Archaeological Exploration in Sikkim
# 154 QQCG9mNU1eAC: dict_keys(['kind', 'totalItems', 'items']): 2: Shadow of the Almighty
# 155 XcdwPwAACAAJ: dict_keys(['kind', 'totalItems']):
# 156 ckdOAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 157 aCiQEAAAQBAJ: dict_keys(['kind', 'totalItems']):
# 158 9wP0fhm5mEYC: dict_keys(['kind', 'totalItems', 'items']): 1: Dogeaters
# 159 5-_nPAAACAAJ: dict_keys(['kind', 'totalItems']):
# 160 aCwNPQAACAAJ: dict_keys(['kind', 'totalItems']):
# 161 C-2nPwAACAAJ: dict_keys(['kind', 'totalItems']):
# 162 UoiIA-jWSo0C: dict_keys(['kind', 'totalItems']):
# 163 z-8HAAAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 2: Truman Capote
# 164 d6mBAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 165 YoPY1-njfTIC: dict_keys(['error']):
# 166 2Hw4KmShqzYC: dict_keys(['error']):
# 167 swNwDwAAQBAJ: dict_keys(['error']):
# 168 cDNRHs_f5P8C: dict_keys(['kind', 'totalItems', 'items']): 1: Not Your Mother's Slow Cooker Cookbook
# 169 51RhAAAACAAJ: dict_keys(['error']):
# 170 gxYl7saIT8IC: dict_keys(['error']):
# 171 Q9NCswEACAAJ: dict_keys(['error']):
# 172 CneVHzqEnb4C: dict_keys(['error']):
# 173 pP_Y5Sl_kV4C: dict_keys(['kind', 'totalItems']):
# 174 gp7FwAEACAAJ: dict_keys(['error']):
# 175 G7JvDwAAQBAJ: dict_keys(['error']):
# 176 i2JcAAAACAAJ: dict_keys(['error']):
# 177 MVGsbLjVyMgC: dict_keys(['kind', 'totalItems', 'items']): 1: Here is New York
# 178 uF0gGdZ91sIC: dict_keys(['error']):
# 179 hsSwAAAAIAAJ: dict_keys(['error']):
# 180 wgJlAAAAMAAJ: dict_keys(['error']):
# 181 5DUvSgAACAAJ: dict_keys(['kind', 'totalItems']):
# 182 rw5nPwAACAAJ: dict_keys(['kind', 'totalItems']):
# 183 3Hw6xWim3tEC: dict_keys(['kind', 'totalItems', 'items']): 2: The Sea, The Sea (Vintage Classics Murdoch Series)
# 184 uOOPEAAAQBAJ: dict_keys(['error']):
# 185 lnOPDQAAQBAJ: dict_keys(['error']):
# 186 G-mDjMwagG8C: dict_keys(['error']):
# 187 5awnXj68yHwC: dict_keys(['error']):
# 188 C7V1GwAACAAJ: dict_keys(['error']):
# 189 PjmwAAAAIAAJ: dict_keys(['error']):
# 190 -HqjPwAACAAJ: dict_keys(['kind', 'totalItems']):
# 191 DzpIuwAACAAJ: dict_keys(['error']):
# 192 nfxvDwAAQBAJ: dict_keys(['error']):
# 193 hInMPAAACAAJ: dict_keys(['error']):
# 194 1jgbhghk5QUC: dict_keys(['error']):
# 195 bFSpGwAACAAJ: dict_keys(['error']):
# 196 sQ1FAAAACAAJ: dict_keys(['error']):
# 197 c-JlAAAAMAAJ: dict_keys(['kind', 'totalItems', 'items']): 27: Written by Salim-Javed
# 198 1tYFMxP-B34C: dict_keys(['kind', 'totalItems', 'items']): 1: The Black Book
# 199 Ei5m7_T2G80C: dict_keys(['error']):
# 200 FHuvlwEACAAJ: dict_keys(['kind', 'totalItems']):
# 201 yOxWAAAAYAAJ: dict_keys(['error']):
# 202 SJ0RAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 203 jUZdAAAAMAAJ: dict_keys(['error']):
# 204 23H0nIJtLEkC: dict_keys(['error']):
# 205 JKuiPwAACAAJ: dict_keys(['error']):
# 206 iXmFAAAACAAJ: dict_keys(['error']):
# 207 zZrSSaq1FRUC: dict_keys(['kind', 'totalItems', 'items']): 1: The Complete Idiot's Guide to Precalculus
# 208 tlZoPwAACAAJ: dict_keys(['error']):
# 209 TRamGES_kn4C: dict_keys(['kind', 'totalItems']):
# 210 L4AQAQAAIAAJ: dict_keys(['error']):
# 211 pc5zQgAACAAJ: dict_keys(['error']):
# 212 QIlGPgAACAAJ: dict_keys(['error']):
# 213 q7qjPwAACAAJ: dict_keys(['kind', 'totalItems']):
# 214 VmdIAgAAQBAJ: dict_keys(['kind', 'totalItems']):
# 215 Lfe0W6fDwCMC: dict_keys(['error']):
# 216 b1VowgEACAAJ: dict_keys(['error']):
# 217 iuAQPwAACAAJ: dict_keys(['kind', 'totalItems']):
# 218 6dA9PgAACAAJ: dict_keys(['error']):
# 219 8T8gAQAAIAAJ: dict_keys(['error']):
# 220 nFnOMQAACAAJ: dict_keys(['error']):
# 221 OOlfAAAAMAAJ: dict_keys(['error']):
# 222 h0MnzgEACAAJ: dict_keys(['kind', 'totalItems']):
# 223 -iWypwAACAAJ: dict_keys(['error']):
# 224 Z2ErAAAAYAAJ: dict_keys(['error']):
# 225 IFIYPQAACAAJ: dict_keys(['error']):
# 226 vrzJAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 227 23_VPQAACAAJ: dict_keys(['error']):
# 228 c0mxAAAAIAAJ: dict_keys(['error']):
# 229 dW6noU_dumQC: dict_keys(['error']):
# 230 TOffOwAACAAJ: dict_keys(['error']):
# 231 PPT6PAAACAAJ: dict_keys(['kind', 'totalItems']):
# 232 ktoKPQAACAAJ: dict_keys(['kind', 'totalItems']):
# 233 9aPSOwAACAAJ: dict_keys(['error']):
# 234 1j3eOwAACAAJ: dict_keys(['error']):
# 235 hH5SYAAACAAJ: dict_keys(['error']):
# 236 uDnAnas3BBgC: dict_keys(['kind', 'totalItems']):
# 237 YQM7twEACAAJ: dict_keys(['error']):
# 238 5CrmygAACAAJ: dict_keys(['kind', 'totalItems']):
# 239 C4hBYAAACAAJ: dict_keys(['kind', 'totalItems']):
# 240 5w6_XwAACAAJ: dict_keys(['error']):
# 241 bxFnAAAACAAJ: dict_keys(['error']):
# 242 dhFnAAAACAAJ: dict_keys(['error']):
# 243 T_NXAAAAYAAJ: dict_keys(['error']):
# 244 PaS0xgEACAAJ: dict_keys(['kind', 'totalItems']):
# 245 FByROwAACAAJ: dict_keys(['error']):
# 246 AuyVPwAACAAJ: dict_keys(['error']):
# 247 DhjM7kxbrLAC: dict_keys(['error']):
# 248 PtDUMQEACAAJ: dict_keys(['error']):
# 249 wW1QAAAAMAAJ: dict_keys(['error']):
# 250 DzgscAAACAAJ: dict_keys(['kind', 'totalItems']):
# 251 zIhbAAAACAAJ: dict_keys(['error']):
# 252 ZBuglQEACAAJ: dict_keys(['error']):
# 253 L-QdAQAACAAJ: dict_keys(['kind', 'totalItems']):
# 254 YVdo5ogaggkC: dict_keys(['error']):
# 255 4HyfQgAACAAJ: dict_keys(['error']):
# 256 H378mSlbxAkC: dict_keys(['error']):
# 257 dhyQEAAAQBAJ: dict_keys(['error']):
# 258 kjiPPwAACAAJ: dict_keys(['error']):
# 259 7cSDAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 260 2RQzPwAACAAJ: dict_keys(['kind', 'totalItems']):
# 261 giKePQAACAAJ: dict_keys(['error']):
# 262 msVUPwAACAAJ: dict_keys(['kind', 'totalItems']):
# 263 B3KKDQAAQBAJ: dict_keys(['error']):
# 264 lvuLDQAAQBAJ: dict_keys(['error']):
# 265 fzgDt_cQ7lMC: dict_keys(['error']):
# 266 99gTAQAAIAAJ: dict_keys(['error']):
# 267 YIFSl1GH5gAC: dict_keys(['error']):
# 268 9o3WzwEACAAJ: dict_keys(['error']):
# 269 aLymPwAACAAJ: dict_keys(['error']):
# 270 pSwJAQAAMAAJ: dict_keys(['error']):
# 271 B-9YPwAACAAJ: dict_keys(['error']):
# 272 Yt0WAQAAMAAJ: dict_keys(['error']):
# 273 VPkAjwEACAAJ: dict_keys(['error']):
# 274 SDkDHAAACAAJ: dict_keys(['kind', 'totalItems']):
# 275 ExxtPQAACAAJ: dict_keys(['error']):
# 276 krKPuAAACAAJ: dict_keys(['error']):
# 277 3ZksSAAACAAJ: dict_keys(['error']):
# 278 KQlQnwEACAAJ: dict_keys(['error']):
# 279 Wp2vIgAACAAJ: dict_keys(['error']):
# 280 E4i_wAEACAAJ: dict_keys(['error']):
# 281 DihQXJzBNxwC: dict_keys(['error']):
# 282 2GZlm91NNEgC: dict_keys(['error']):
# 283 O7yBMgEACAAJ: dict_keys(['error']):
# 284 CoGAPwAACAAJ: dict_keys(['error']):
# 285 0WvqwAEACAAJ: dict_keys(['error']):
# 286 i855NwAACAAJ: dict_keys(['error']):
# 287 V3gaAQAAMAAJ: dict_keys(['error']):
# 288 q5OyAAAAIAAJ: dict_keys(['error']):
# 289 eEhcnQIzJ8QC: dict_keys(['error']):
# 290 J5Mdn4vqyrsC: dict_keys(['error']):
# 291 kq18PwAACAAJ: dict_keys(['kind', 'totalItems']):
# 292 i6YFAQAAIAAJ: dict_keys(['error']):
# 293 7GIPCVrT4HMC: dict_keys(['error']):
# 294 5TlRJ4X5pigC: dict_keys(['error']):
# 295 o1goAQAAIAAJ: dict_keys(['error']):
# 296 PymMQgAACAAJ: dict_keys(['error']):
# 297 98ouHQAACAAJ: dict_keys(['kind', 'totalItems']):
# 298 NXS8cwtMaGwC: dict_keys(['error']):
# 299 hB3MAQAACAAJ: dict_keys(['error']):
# 300 iWUcAQAAIAAJ: dict_keys(['kind', 'totalItems']):
# 301 OIk_WGE4UhkC: dict_keys(['error']):
# 302 QVCHKwAACAAJ: dict_keys(['error']):
# 303 WzWDrgEACAAJ: dict_keys(['kind', 'totalItems']):
# 304 _lkvAAAACAAJ: dict_keys(['error']):
# 305 WL83PQAACAAJ: dict_keys(['error']):
# 306 b2xpEpQGmAoC: dict_keys(['error']):
# 307 wGYsMGICMK8C: dict_keys(['error']):
# 308 NmSGPwAACAAJ: dict_keys(['error']):
# 309 PlJPmAEACAAJ: dict_keys(['kind', 'totalItems']):
# 310 yQPXAAAAMAAJ: dict_keys(['error']):
# 311 cfA8AAAACAAJ: dict_keys(['error']):
# 312 8tz2PQAACAAJ: dict_keys(['error']):
# 313 x3aPEAAAQBAJ: dict_keys(['error']):
# 314 2eOMDQAAQBAJ: dict_keys(['error']):
# 315 c3DuwAEACAAJ: dict_keys(['error']):
# 316 hcgeejmsoFkC: dict_keys(['error']):
# 317 RUemtAEACAAJ: dict_keys(['error']):
# 318 B30-PgAACAAJ: dict_keys(['error']):
# 319 fBFmAAAAMAAJ: dict_keys(['error']):
# 320 BEJwAQAACAAJ: dict_keys(['kind', 'totalItems']):
# 321 OnkwAAAACAAJ: dict_keys(['error']):
# 322 AOWDkQEACAAJ: dict_keys(['error']):
# 323 wksN1qnkooAC: dict_keys(['kind', 'totalItems', 'items']): 1: Citizen of the Galaxy
# 324 L1KxAAAAIAAJ: dict_keys(['kind', 'totalItems']):
# 325 5XnXOAAACAAJ: dict_keys(['kind', 'totalItems']):
# 326 Q0xkC5CEhHQC: dict_keys(['error']):
# 327 EZZYHAAACAAJ: dict_keys(['kind', 'totalItems']):
# 328 b21bAAAAMAAJ: dict_keys(['error']):
# 329 mvh6NNl0XzoC: dict_keys(['kind', 'totalItems']):
# 330 l0CtGwAACAAJ: dict_keys(['error']):
# 331 xrtXvgAACAAJ: dict_keys(['kind', 'totalItems']):
# 332 0Z7BAAAACAAJ: dict_keys(['error']):
# 333 CFOozwEACAAJ: dict_keys(['error']):
# 334 bDSnAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 335 mqIDAAAACAAJ: dict_keys(['error']):
# 336 fI46PwAACAAJ: dict_keys(['kind', 'totalItems']):
# 337 2LBXDFxpG2kC: dict_keys(['error']):
# 338 t2-KDQAAQBAJ: dict_keys(['error']):
# 339 Fr40AQAAIAAJ: dict_keys(['kind', 'totalItems']):
# 340 hOvRX2VklxEC: dict_keys(['error']):
# 341 1JU8PgAACAAJ: dict_keys(['error']):
# 342 9Y6MEAAAQBAJ: dict_keys(['error']):
# 343 IxidPwAACAAJ: dict_keys(['error']):
# 344 O_lCPgAACAAJ: dict_keys(['error']):
# 345 DHxffxqPBgwC: dict_keys(['error']):
# 346 UlpfXTEnDNQC: dict_keys(['error']):
# 347 Dg9rAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 348 p4c-TNkH12QC: dict_keys(['error']):
# 349 qkNaAAAAYAAJ: dict_keys(['error']):
# 350 jxamngEACAAJ: dict_keys(['error']):
# 351 8VqNDQAAQBAJ: dict_keys(['error']):
# 352 1b2NEAAAQBAJ: dict_keys(['error']):
# 353 tVzUwAEACAAJ: dict_keys(['error']):
# 354 htyrPAAACAAJ: dict_keys(['error']):
# 355 Ba-BAAAAIAAJ: dict_keys(['kind', 'totalItems', 'items']): 2: Arabia and the Isles
# 356 eUBwAAAACAAJ: dict_keys(['error']):
# 357 UbkvmQEACAAJ: dict_keys(['error']):
# 358 sD-hswEACAAJ: dict_keys(['error']):
# 359 EHtdAAAAMAAJ: dict_keys(['error']):
# 360 l1cOwJzNzRwC: dict_keys(['error']):
# 361 TQV0PwAACAAJ: dict_keys(['error']):
# 362 7zRbPwAACAAJ: dict_keys(['error']):
# 363 6xsGAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 364 5aneAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 365 BUZwyAEACAAJ: dict_keys(['error']):
# 366 v4GwAAAACAAJ: dict_keys(['error']):
# 367 3YGfPwAACAAJ: dict_keys(['error']):
# 368 cscGBgAAQBAJ: dict_keys(['error']):
# 369 jYdqQ4YdccYC: dict_keys(['error']):
# 370 5l27QgAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 11: War and Peace
# 371 YPjvwAEACAAJ: dict_keys(['kind', 'totalItems']):
# 372 NnzqAAAAMAAJ: dict_keys(['error']):
# 373 3vZTmQEACAAJ: dict_keys(['kind', 'totalItems']):
# 374 qzcSTHoNdSsC: dict_keys(['kind', 'totalItems']):
# 375 YCvDPAAACAAJ: dict_keys(['error']):
# 376 pJH2OsroXCcC: dict_keys(['error']):
# 377 zb8Bqft2wuQC: dict_keys(['error']):
# 378 X2-fil65OT4C: dict_keys(['kind', 'totalItems']):
# 379 DSPp9BTIMqIC: dict_keys(['error']):
# 380 AGRBvgAACAAJ: dict_keys(['error']):
# 381 EpkPuSZb7FsC: dict_keys(['error']):
# 382 DxhhgrjR7cEC: dict_keys(['error']):
# 383 RadZAAAAYAAJ: dict_keys(['error']):
# 384 g8JTvQEACAAJ: dict_keys(['error']):
# 385 COT8nZsi6zYC: dict_keys(['error']):
# 386 gzxbAAAAMAAJ: dict_keys(['error']):
# 387 NBPbiXwwsGQC: dict_keys(['error']):
# 388 XODSKAczkz4C: dict_keys(['kind', 'totalItems']):
# 389 PCdTKwAACAAJ: dict_keys(['error']):
# 390 zkyiAAAACAAJ: dict_keys(['error']):
# 391 Zv9FPgAACAAJ: dict_keys(['error']):
# 392 D2uQtkxjD9UC: dict_keys(['error']):
# 393 NTGDz-HBRBYC: dict_keys(['error']):
# 394 jCLaAAAAMAAJ: dict_keys(['error']):
# 395 v3gfSbMtnHQC: dict_keys(['error']):
# 396 TWcmAS2h3YMC: dict_keys(['error']):
# 397 2dUWAQAAMAAJ: dict_keys(['error']):
# 398 J0HhZE6jxRMC: dict_keys(['error']):
# 399 1yqHOwAACAAJ: dict_keys(['error']):
# 400 wuymEj8Mjq8C: dict_keys(['error']):
# 401 9R6NEAAAQBAJ: dict_keys(['error']):
# 402 ltfuAAAACAAJ: dict_keys(['error']):
# 403 1S8WPAAACAAJ: dict_keys(['error']):
# 404 6dDWkQEACAAJ: dict_keys(['error']):
# 405 ajlbAAAAMAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Through a Brazen Mirror
# 406 B15lGwAACAAJ: dict_keys(['error']):
# 407 rsd_mAEACAAJ: dict_keys(['error']):
# 408 y2plAAAACAAJ: dict_keys(['error']):
# 409 XCNQ0jRHtKIC: dict_keys(['error']):
# 410 Ob6cAAAAMAAJ: dict_keys(['kind', 'totalItems']):
# 411 yeWEAAAAIAAJ: dict_keys(['error']):
# 412 d_N0AAAACAAJ: dict_keys(['error']):
# 413 yWDPwAEACAAJ: dict_keys(['error']):
# 414 v59bAAAAMAAJ: dict_keys(['error']):
# 415 51NIzwEACAAJ: dict_keys(['kind', 'totalItems']):
# 416 Fb_wOwAACAAJ: dict_keys(['error']):
# 417 cSQT4aQ7r10C: dict_keys(['error']):
# 418 BJvGPAAACAAJ: dict_keys(['error']):
# 419 tjVTGwAACAAJ: dict_keys(['error']):
# 420 VqrUX4kZZE8C: dict_keys(['error']):
# 421 FifMwAEACAAJ: dict_keys(['kind', 'totalItems']):
# 422 KaAyuAAACAAJ: dict_keys(['error']):
# 423 _9URQoEdKYcC: dict_keys(['error']):
# 424 Ac1hAAAACAAJ: dict_keys(['error']):
# 425 OOT8TdiYYPIC: dict_keys(['error']):
# 426 3vGMDQAAQBAJ: dict_keys(['error']):
# 427 oX7V3fb2i4gC: dict_keys(['error']):
# 428 gbuVAAAACAAJ: dict_keys(['error']):
# 429 59R4AAAACAAJ: dict_keys(['error']):
# 430 2uFDPgAACAAJ: dict_keys(['error']):
# 431 Q4vhAAAACAAJ: dict_keys(['error']):
# 432 naVJPgAACAAJ: dict_keys(['error']):
# 433 XGpQAAAAMAAJ: dict_keys(['kind', 'totalItems']):
# 434 RE3BQgAACAAJ: dict_keys(['kind', 'totalItems']):
# 435 _BKYTHMBLj8C: dict_keys(['kind', 'totalItems']):
# 436 C6d-PwAACAAJ: dict_keys(['kind', 'totalItems']):
# 437 ms64zwEACAAJ: dict_keys(['kind', 'totalItems']):
# 438 HmpQAAAAMAAJ: dict_keys(['error']):
# 439 YwNwDwAAQBAJ: dict_keys(['error']):
# 440 UlogimSLtuAC: dict_keys(['error']):
# 441 510mSgAACAAJ: dict_keys(['error']):
# 442 9WHbAAAAMAAJ: dict_keys(['error']):
# 443 iiTfCwAAQBAJ: dict_keys(['error']):
# 444 3z0DtAEACAAJ: dict_keys(['error']):
# 445 Xv6KDQAAQBAJ: dict_keys(['kind', 'totalItems']):
# 446 0k0IQAAACAAJ: dict_keys(['kind', 'totalItems']):
# 447 819DygAACAAJ: dict_keys(['error']):
# 448 uboVagoLxbwC: dict_keys(['error']):
# 449 M1dQAAAAMAAJ: dict_keys(['error']):
# 450 -CpgQgAACAAJ: dict_keys(['error']):
# 451 LcAIAAAACAAJ: dict_keys(['error']):
# 452 EwV8nQAACAAJ: dict_keys(['error']):
# 453 0JN_GQAACAAJ: dict_keys(['error']):
# 454 nhxHPAAACAAJ: dict_keys(['error']):
# 455 c7g6i1DvUUgC: dict_keys(['error']):
# 456 fW3lPAAACAAJ: dict_keys(['error']):
# 457 K-V6QgAACAAJ: dict_keys(['error']):
# 458 zz1mjgEACAAJ: dict_keys(['kind', 'totalItems']):
# 459 4yZOGQAACAAJ: dict_keys(['kind', 'totalItems']):
# 460 NiOpPwAACAAJ: dict_keys(['error']):
# 461 38BybabXrW8C: dict_keys(['kind', 'totalItems']):
# 462 Q0JKwLYu3GMC: dict_keys(['kind', 'totalItems']):
# 463 epiClAEACAAJ: dict_keys(['kind', 'totalItems']):
# 464 UJzuwAEACAAJ: dict_keys(['error']):
# 465 ahrE0Prmge0C: dict_keys(['kind', 'totalItems']):
# 466 ufxvDwAAQBAJ: dict_keys(['kind', 'totalItems', 'items']): 61: You Shall Know Our Velocity
# 467 9LK2AAAACAAJ: dict_keys(['error']):
# 468 itpJAAAACAAJ: dict_keys(['error']):
# 469 7ygJAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 470 xX_SK7IkBgIC: dict_keys(['error']):
# 471 5RyCPwAACAAJ: dict_keys(['error']):
# 472 UXKKDQAAQBAJ: dict_keys(['kind', 'totalItems']):
# 473 80q85zg9bCEC: dict_keys(['kind', 'totalItems', 'items']): 1: The Stuffed Owl
# 474 rfSrfzfNelcC: dict_keys(['kind', 'totalItems']):
# 475 fIgRtAEACAAJ: dict_keys(['error']):
# 476 JtKuQgAACAAJ: dict_keys(['kind', 'totalItems']):
# 477 cYEKAQAAMAAJ: dict_keys(['kind', 'totalItems']):
# 478 _bKx7lnyciEC: dict_keys(['kind', 'totalItems']):
# 479 0FV3JwAACAAJ: dict_keys(['kind', 'totalItems']):
# 480 zIvzT2k1mvkC: dict_keys(['error']):
# 481 -ndjtDlVIKsC: dict_keys(['kind', 'totalItems']):
# 482 aEhrPwAACAAJ: dict_keys(['error']):
# 483 0p8IrgEACAAJ: dict_keys(['error']):
# 484 P1ypAAAACAAJ: dict_keys(['error']):
# 485 SqMNAQAAMAAJ: dict_keys(['kind', 'totalItems']):
# 486 uh7TswEACAAJ: dict_keys(['error']):
# 487 OGOfAAAAMAAJ: dict_keys(['error']):
# 488 LA_zAAAAMAAJ: dict_keys(['error']):
# 489 dgtJPgAACAAJ: dict_keys(['kind', 'totalItems']):
# 490 c4eg2MhmszAC: dict_keys(['kind', 'totalItems', 'items']): 1: When I Whistle
# 491 myvCAQAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 2: LetterLogic Family Album
# 492 1I1SvwEACAAJ: dict_keys(['kind', 'totalItems']):
# 493 oG2GmyFXJC0C: dict_keys(['error']):
# 494 2NdiAAAAMAAJ: dict_keys(['error']):
# 495 8nz6PAAACAAJ: dict_keys(['error']):
# 496 KC6NJgAACAAJ: dict_keys(['kind', 'totalItems']):
# 497 mM5h90mXKsUC: dict_keys(['error']):
# 498 3_djQaQ0BEkC: dict_keys(['kind', 'totalItems', 'items']): 1: The Journey to the East
# 499 dCmgAAAACAAJ: dict_keys(['error']):
# 500 HYDIAAAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Idas und Marpissa
# 501 JYxIDwAAQBAJ: dict_keys(['kind', 'totalItems']):
# 502 VsoliwGIMZUC: dict_keys(['error']):
# 503 0ZIrAAAAYAAJ: dict_keys(['kind', 'totalItems']):
# 504 c3PDO7jKTJMC: dict_keys(['kind', 'totalItems']):
# 505 w7xvDwAAQBAJ: dict_keys(['error']):
# 506 DA_lAAAAMAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Journal of the Annual Encampment
# 507 HaTxNwAACAAJ: dict_keys(['kind', 'totalItems']):
# 508 Zu2ezgEACAAJ: dict_keys(['kind', 'totalItems']):
# 509 lGLAK2CW0WIC: dict_keys(['kind', 'totalItems', 'items']): 1: Kokopelli
# 510 6qfVCQAAQBAJ: dict_keys(['kind', 'totalItems']):
# 511 kHoaOQAACAAJ: dict_keys(['kind', 'totalItems']):
# 512 LchZPgAACAAJ: dict_keys(['kind', 'totalItems']):
# 513 NpGmPQAACAAJ: dict_keys(['kind', 'totalItems']):
# 514 OSWNEAAAQBAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Das Dogma von der Menschwerdung Gottes
# 515 qmw18yCjLFsC: dict_keys(['error']):
# 516 gK1iQgAACAAJ: dict_keys(['error']):
# 517 xqEIdLQrZHwC: dict_keys(['kind', 'totalItems']):
# 518 5NbOt8YUT5kC: dict_keys(['error']):
# 519 h6icnOdHfhoC: dict_keys(['kind', 'totalItems']):
# 520 rzMAAAAACAAJ: dict_keys(['error']):
# 521 y_9vDwAAQBAJ: dict_keys(['kind', 'totalItems']):
# 522 gXdNNwAACAAJ: dict_keys(['error']):
# 523 JBfQmUDiTRYC: dict_keys(['kind', 'totalItems']):
# 524 cfIjrV1A6xwC: dict_keys(['kind', 'totalItems', 'items']): 1: The Cross from a Distance
# 525 nntDAAAACAAJ: dict_keys(['error']):
# 526 ypO4GQAACAAJ: dict_keys(['error']):
# 527 6hb5HAAACAAJ: dict_keys(['kind', 'totalItems']):
# 528 -B3AHAAACAAJ: dict_keys(['error']):
# 529 I6cEBUW1pgYC: dict_keys(['kind', 'totalItems', 'items']): 2: A Void
# 530 Ia9-dneCWcwC: dict_keys(['error']):
# 531 m9cZAAAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Come Over to My House
# 532 sz6A0oZ_KaAC: dict_keys(['kind', 'totalItems', 'items']): 3: Witch Grass
# 533 qJHiAQAACAAJ: dict_keys(['kind', 'totalItems']):
# 534 -tqBPwAACAAJ: dict_keys(['error']):
# 535 zGWTEAAAQBAJ: dict_keys(['kind', 'totalItems']):
# 536 HSBVg7oofw0C: dict_keys(['error']):
# 537 EyZ4PwAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Immortality
# 538 6qMHAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 539 TwvxPQAACAAJ: dict_keys(['kind', 'totalItems']):
# 540 xYJOPgAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 2: The Happy Hocky Family
# 541 eUerJgAACAAJ: dict_keys(['kind', 'totalItems']):
# 542 Ht9jAAAACAAJ: dict_keys(['error']):
# 543 b9fDUyzHRtoC: dict_keys(['kind', 'totalItems', 'items']): 1: You Can Never Go Home Again
# 544 03BIrNldt1YC: dict_keys(['error']):
# 545 l9rXPQAACAAJ: dict_keys(['kind', 'totalItems']):
# 546 XgUwHQAACAAJ: dict_keys(['error']):
# 547 nBb5GwAACAAJ: dict_keys(['error']):
# 548 lNJXAAAAYAAJ: dict_keys(['error']):
# 549 D9GMDQAAQBAJ: dict_keys(['error']):
# 550 VTUF8oX1tl0C: dict_keys(['error']):
# 551 b0XtswEACAAJ: dict_keys(['error']):
# 552 ucLkzRU09WMC: dict_keys(['error']):
# 553 nKJEngEACAAJ: dict_keys(['kind', 'totalItems']):
# 554 eh5cAAAAMAAJ: dict_keys(['kind', 'totalItems']):
# 555 q5h91ZZemK0C: dict_keys(['kind', 'totalItems', 'items']): 1: The Coen Brothers
# 556 e0XPPQAACAAJ: dict_keys(['error']):
# 557 HaJNEAAAQBAJ: dict_keys(['kind', 'totalItems']):
# 558 XwOkQgAACAAJ: dict_keys(['kind', 'totalItems']):
# 559 9d_nwAEACAAJ: dict_keys(['error']):
# 560 r30qAAAAYAAJ: dict_keys(['error']):
# 561 Fo8RPwAACAAJ: dict_keys(['error']):
# 562 RcPGAAAACAAJ: dict_keys(['error']):
# 563 dnPGswEACAAJ: dict_keys(['error']):
# 564 HCjiAAAACAAJ: dict_keys(['error']):
# 565 KPBrkQEACAAJ: dict_keys(['error']):
# 566 ACZviVoW2WkC: dict_keys(['kind', 'totalItems', 'items']): 4: A Secret Splendor
# 567 C2xVHuhz6TQC: dict_keys(['kind', 'totalItems']):
# 568 r1qffvSlxdIC: dict_keys(['kind', 'totalItems']):
# 569 KP639MoNBMMC: dict_keys(['error']):
# 570 08sbAAAACAAJ: dict_keys(['error']):
# 571 MFaW0YdVOZQC: dict_keys(['error']):
# 572 ELbCQgAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 2: Colonialism and Neocolonialism
# 573 PNZaAAAAMAAJ: dict_keys(['error']):
# 574 S6OePwAACAAJ: dict_keys(['error']):
# 575 PoNPEAAAQBAJ: dict_keys(['error']):
# 576 MmQEAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 577 Sg6hPwAACAAJ: dict_keys(['error']):
# 578 H927wAEACAAJ: dict_keys(['error']):
# 579 BLFa_q6D9DgC: dict_keys(['error']):
# 580 l5AxDwAAQBAJ: dict_keys(['kind', 'totalItems']):
# 581 dB5v9fqEp6QC: dict_keys(['error']):
# 582 rOtyNgAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 4: Bad Guys
# 583 f-EEAQAAIAAJ: dict_keys(['error']):
# 584 JnCKDQAAQBAJ: dict_keys(['error']):
# 585 MANkuHZNmgkC: dict_keys(['error']):
# 586 wLdRCwAAQBAJ: dict_keys(['kind', 'totalItems']):
# 587 tTKc8Aw-GFUC: dict_keys(['error']):
# 588 48ZEPgAACAAJ: dict_keys(['error']):
# 589 G3_DKH4sX-4C: dict_keys(['error']):
# 590 ZurXYqoRNf8C: dict_keys(['error']):
# 591 S87FdJuQJaAC: dict_keys(['error']):
# 592 7S9cPwAACAAJ: dict_keys(['error']):
# 593 9946PwAACAAJ: dict_keys(['error']):
# 594 QgVmKEDNkrsC: dict_keys(['error']):
# 595 aLc26Y6HjnMC: dict_keys(['error']):
# 596 NxC5f-kM1_QC: dict_keys(['error']):
# 597 MybhQQAACAAJ: dict_keys(['error']):
# 598 Dg6eQgAACAAJ: dict_keys(['error']):
# 599 JQBlGfyS9PUC: dict_keys(['error']):
# 600 OX8qAAAAYAAJ: dict_keys(['error']):
# 601 Id38wAEACAAJ: dict_keys(['kind', 'totalItems']):
# 602 1PkcPQAACAAJ: dict_keys(['kind', 'totalItems']):
# 603 SlPdPAAACAAJ: dict_keys(['error']):
# 604 GhKREAAAQBAJ: dict_keys(['error']):
# 605 pn1cAAAAMAAJ: dict_keys(['error']):
# 606 kLRKDwAAQBAJ: dict_keys(['error']):
# 607 OfaUQQAACAAJ: dict_keys(['kind', 'totalItems']):
# 608 odJlAAAAMAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Brown Girl, Brownstones
# 609 d-klQAAACAAJ: dict_keys(['error']):
# 610 TbKI59zLMU0C: dict_keys(['kind', 'totalItems', 'items']): 1: War and the Iliad
# 611 u_aVPwAACAAJ: dict_keys(['error']):
# 612 VjkbAQAAIAAJ: dict_keys(['error']):
# 613 aBYMAAAACAAJ: dict_keys(['error']):
# 614 b8EuOgAACAAJ: dict_keys(['error']):
# 615 urMhEAAAQBAJ: dict_keys(['error']):
# 616 rIG9ciCJjHsC: dict_keys(['kind', 'totalItems', 'items']): 2: New Rules
# 617 XHoBAAAACAAJ: dict_keys(['error']):
# 618 JKing7OygDMC: dict_keys(['error']):
# 619 92zcXiTN3CkC: dict_keys(['kind', 'totalItems']):
# 620 dRpNjFKr-iAC: dict_keys(['kind', 'totalItems']):
# 621 fDIrzgEACAAJ: dict_keys(['kind', 'totalItems']):
# 622 3G-KDQAAQBAJ: dict_keys(['error']):
# 623 5DtSTKa7bO4C: dict_keys(['error']):
# 624 xUNYAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 625 659r23-K96sC: dict_keys(['error']):
# 626 SQxaAAAAYAAJ: dict_keys(['error']):
# 627 y7ftbozCHIoC: dict_keys(['error']):
# 628 wRhEmQEACAAJ: dict_keys(['kind', 'totalItems']):
# 629 Z3_UAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 630 gDP6HAAACAAJ: dict_keys(['error']):
# 631 -BdrQgAACAAJ: dict_keys(['error']):
# 632 LkMK-3L6hPQC: dict_keys(['error']):
# 633 etKX2s6JgAkC: dict_keys(['kind', 'totalItems', 'items']): 3: Bully for Brontosaurus: Reflections in Natural History
# 634 s28MAgAACAAJ: dict_keys(['kind', 'totalItems']):
# 635 g3BQAAAAMAAJ: dict_keys(['error']):
# 636 -DwmSQAACAAJ: dict_keys(['error']):
# 637 MQf3ZQ22ZGEC: dict_keys(['kind', 'totalItems']):
# 638 oidcAAAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 2: The Illustrated Guide to Crystals
# 639 5FauPQAACAAJ: dict_keys(['kind', 'totalItems']):
# 640 kNZHPwAACAAJ: dict_keys(['error']):
# 641 1Z8KJQAACAAJ: dict_keys(['kind', 'totalItems']):
# 642 _PFyysVnTaQC: dict_keys(['error']):
# 643 AbvGwAEACAAJ: dict_keys(['error']):
# 644 lCaRUdo-rtcC: dict_keys(['error']):
# 645 jqVsAAAACAAJ: dict_keys(['error']):
# 646 5-IWAAAACAAJ: dict_keys(['error']):
# 647 rNSlPwAACAAJ: dict_keys(['kind', 'totalItems']):
# 648 dudGtAEACAAJ: dict_keys(['error']):
# 649 09FkZqu_YcMC: dict_keys(['error']):
# 650 nAeqPgAACAAJ: dict_keys(['kind', 'totalItems']):
# 651 j6M7PgAACAAJ: dict_keys(['error']):
# 652 URJlAAAAMAAJ: dict_keys(['kind', 'totalItems', 'items']): 3: Jimmy Stewart
# 653 R4fYzwEACAAJ: dict_keys(['error']):
# 654 ykeCPwAACAAJ: dict_keys(['error']):
# 655 srJgAAAACAAJ: dict_keys(['error']):
# 656 06EPzgEACAAJ: dict_keys(['error']):
# 657 EhtSNwAACAAJ: dict_keys(['kind', 'totalItems']):
# 658 uKSFbwAACAAJ: dict_keys(['error']):
# 659 KXcrkgAACAAJ: dict_keys(['error']):
# 660 OWdqt29UDGYC: dict_keys(['kind', 'totalItems', 'items']): 19: Myths of Light
# 661 CkrzQgAACAAJ: dict_keys(['kind', 'totalItems']):
# 662 MnWYKwAACAAJ: dict_keys(['error']):
# 663 3QTo2UTFdS0C: dict_keys(['error']):
# 664 Hci2wAEACAAJ: dict_keys(['error']):
# 665 cWtglGzhPPEC: dict_keys(['error']):
# 666 bML4PAAACAAJ: dict_keys(['error']):
# 667 l8fhPQAACAAJ: dict_keys(['error']):
# 668 265d7u5NCXAC: dict_keys(['kind', 'totalItems']):
# 669 JVlQAAAAMAAJ: dict_keys(['error']):
# 670 gwlVAgAAQBAJ: dict_keys(['kind', 'totalItems']):
# 671 irNPEAAAQBAJ: dict_keys(['error']):
# 672 gJbGPQAACAAJ: dict_keys(['kind', 'totalItems']):
# 673 J1lWBDui73EC: dict_keys(['kind', 'totalItems']):
# 674 aZokkgAACAAJ: dict_keys(['error']):
# 675 qzf3DfX06w4C: dict_keys(['error']):
# 676 CD8MAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 677 3r4gAQAAIAAJ: dict_keys(['error']):
# 678 AUg1fPViARQC: dict_keys(['error']):
# 679 VOKMyAEACAAJ: dict_keys(['error']):
# 680 YwvePwAACAAJ: dict_keys(['error']):
# 681 uKeezwEACAAJ: dict_keys(['error']):
# 682 lnWREAAAQBAJ: dict_keys(['error']):
# 683 5yQLAAAACAAJ: dict_keys(['error']):
# 684 UqzTS5BpprEC: dict_keys(['error']):
# 685 dUUPoukT5yUC: dict_keys(['kind', 'totalItems']):
# 686 wmRRxZRWfnAC: dict_keys(['error']):
# 687 Z26PEAAAQBAJ: dict_keys(['error']):
# 688 LhmyuQAACAAJ: dict_keys(['kind', 'totalItems']):
# 689 5oGTAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 690 pPtFlQEACAAJ: dict_keys(['error']):
# 691 A2BVoA4ky_YC: dict_keys(['kind', 'totalItems', 'items']): 2: Collected Poems
# 692 UHxnDwAAQBAJ: dict_keys(['kind', 'totalItems']):
# 693 QlvbMgEACAAJ: dict_keys(['error']):
# 694 r6JNEAAAQBAJ: dict_keys(['error']):
# 695 fJWTEAAAQBAJ: dict_keys(['error']):
# 696 9Wk8AQAAQBAJ: dict_keys(['error']):
# 697 W_g-PwAACAAJ: dict_keys(['error']):
# 698 YBfKjwEACAAJ: dict_keys(['error']):
# 699 SNeHkMXHcd8C: dict_keys(['error']):
# 700 UwRwDwAAQBAJ: dict_keys(['kind', 'totalItems']):
# 701 _UfHQQAACAAJ: dict_keys(['error']):
# 702 j7NV2wa2ixoC: dict_keys(['kind', 'totalItems']):
# 703 L9x8ZuQBIR0C: dict_keys(['error']):
# 704 h3ENAAAACAAJ: dict_keys(['error']):
# 705 78qiuQAACAAJ: dict_keys(['kind', 'totalItems']):
# 706 1H1AAAAAYAAJ: dict_keys(['error']):
# 707 R7y1PEKjVc0C: dict_keys(['kind', 'totalItems']):
# 708 Xw0PAQAAMAAJ: dict_keys(['error']):
# 709 baEJAAAACAAJ: dict_keys(['error']):
# 710 _NZ0L8dzvtMC: dict_keys(['error']):
# 711 HMuDmAEACAAJ: dict_keys(['kind', 'totalItems']):
# 712 cLOax2a40x8C: dict_keys(['kind', 'totalItems']):
# 713 DOQwAAAACAAJ: dict_keys(['error']):
# 714 GdxARgAACAAJ: dict_keys(['error']):
# 715 S8IHAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 716 NqsRzXYI61gC: dict_keys(['kind', 'totalItems']):
# 717 fvdouQEACAAJ: dict_keys(['error']):
# 718 0IZTAAAAMAAJ: dict_keys(['error']):
# 719 sD6mAAAACAAJ: dict_keys(['error']):
# 720 6A2G8lZaD5IC: dict_keys(['error']):
# 721 6-1mPgAACAAJ: dict_keys(['error']):
# 722 X1g0AAAACAAJ: dict_keys(['kind', 'totalItems']):
# 723 rp4wfvuZ3QoC: dict_keys(['error']):
# 724 xGvlys8IlDkC: dict_keys(['error']):
# 725 DAttPgAACAAJ: dict_keys(['error']):
# 726 ASCIvgEACAAJ: dict_keys(['error']):
# 727 6AZhvgEACAAJ: dict_keys(['error']):
# 728 m5HoCAAAQBAJ: dict_keys(['error']):
# 729 h10V8jGmgn8C: dict_keys(['error']):
# 730 Hss8hg6xUYUC: dict_keys(['error']):
# 731 -Dh9AAAACAAJ: dict_keys(['error']):
# 732 lGO7GQAACAAJ: dict_keys(['error']):
# 733 Y5YMzpFJlo4C: dict_keys(['error']):
# 734 3fwiA3jsFfwC: dict_keys(['error']):
# 735 CenskNHUV38C: dict_keys(['error']):
# 736 mIxUTxblX6kC: dict_keys(['error']):
# 737 -fJgAAAAMAAJ: dict_keys(['kind', 'totalItems', 'items']): 2: Artaud the Mômo
# 738 vLBrgzwYFkMC: dict_keys(['error']):
# 739 4cY-vgAACAAJ: dict_keys(['kind', 'totalItems']):
# 740 S4k-DwAAQBAJ: dict_keys(['error']):
# 741 aPEfnSNCURwC: dict_keys(['error']):
# 742 6edCMwEACAAJ: dict_keys(['error']):
# 743 RH-NwwEACAAJ: dict_keys(['error']):
# 744 KlmafZWx5ckC: dict_keys(['error']):
# 745 C1zJPAAACAAJ: dict_keys(['kind', 'totalItems']):
# 746 lWN0AAAACAAJ: dict_keys(['kind', 'totalItems']):
# 747 YvVVmu9aKQ4C: dict_keys(['error']):
# 748 -GatmAEACAAJ: dict_keys(['error']):
# 749 z0iIPwAACAAJ: dict_keys(['kind', 'totalItems']):
# 750 XacBfFOLijMC: dict_keys(['error']):
# 751 q3LslgQ72XkC: dict_keys(['error']):
# 752 kT9AAQAAIAAJ: dict_keys(['error']):
# 753 OyVFPgAACAAJ: dict_keys(['error']):
# 754 yJIDzQEACAAJ: dict_keys(['error']):
# 755 MBtQAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 756 YyaxjgEACAAJ: dict_keys(['error']):
# 757 jMP4hcF7iDIC: dict_keys(['error']):
# 758 wItnFpuHr60C: dict_keys(['error']):
# 759 eZ2FPwAACAAJ: dict_keys(['error']):
# 760 zd7bAAAAMAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Tim Gunn
# 761 -ZVoVtwCMz0C: dict_keys(['error']):
# 762 hVq4K3px5_kC: dict_keys(['kind', 'totalItems']):
# 763 nrQAAAAACAAJ: dict_keys(['error']):
# 764 X1khAQAAMAAJ: dict_keys(['error']):
# 765 q1KQAAAAMAAJ: dict_keys(['error']):
# 766 2CHuAAAAMAAJ: dict_keys(['error']):
# 767 4oLf1WnMxGMC: dict_keys(['error']):
# 768 aSHuAAAAMAAJ: dict_keys(['error']):
# 769 K07cOwAACAAJ: dict_keys(['error']):
# 770 Pf92tcixPqMC: dict_keys(['error']):
# 771 htnPvgEACAAJ: dict_keys(['kind', 'totalItems']):
# 772 R-opvQpluHwC: dict_keys(['error']):
# 773 VggiHAAACAAJ: dict_keys(['error']):
# 774 7SddAAAACAAJ: dict_keys(['error']):
# 775 3_CW0gsgDvsC: dict_keys(['error']):
# 776 Yts9PgAACAAJ: dict_keys(['error']):
# 777 USBJPwAACAAJ: dict_keys(['error']):
# 778 aT1SAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 779 c2iJPgAACAAJ: dict_keys(['error']):
# 780 tfP4UND566AC: dict_keys(['error']):
# 781 AjUlAAAACAAJ: dict_keys(['error']):
# 782 jl6iDrN4ARwC: dict_keys(['error']):
# 783 jSzoTA69sMgC: dict_keys(['error']):
# 784 SCvxNwAACAAJ: dict_keys(['error']):
# 785 vSY8fGIsJTsC: dict_keys(['error']):
# 786 6WdfQgAACAAJ: dict_keys(['kind', 'totalItems']):
# 787 yykeAQAAIAAJ: dict_keys(['error']):
# 788 8DJq3GXqGP8C: dict_keys(['error']):
# 789 XRTuAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 790 yp6BAAAAIAAJ: dict_keys(['error']):
# 791 EodFAAAACAAJ: dict_keys(['error']):
# 792 vtQgLN0Aq8YC: dict_keys(['error']):
# 793 5eLRwAEACAAJ: dict_keys(['error']):
# 794 98-cPQAACAAJ: dict_keys(['kind', 'totalItems']):
# 795 RZbQPAAACAAJ: dict_keys(['error']):
# 796 4tuEuAAACAAJ: dict_keys(['error']):
# 797 dmqguAAACAAJ: dict_keys(['kind', 'totalItems']):
# 798 DiJVzwEACAAJ: dict_keys(['error']):
# 799 h2Y-PgAACAAJ: dict_keys(['error']):
# 800 DAAAAAAACAAJ: dict_keys(['error']):
# 801 LH5C9q83T6wC: dict_keys(['error']):
# 802 62CEzQEACAAJ: dict_keys(['error']):
# 803 joXgAAAAMAAJ: dict_keys(['error']):
# 804 4m0Qj9xKksYC: dict_keys(['error']):
# 805 oL1lAAAAMAAJ: dict_keys(['kind', 'totalItems']):
# 806 yfSOEAAAQBAJ: dict_keys(['error']):
# 807 nRduHUeIzvAC: dict_keys(['error']):
# 808 7ZELqUsksIwC: dict_keys(['error']):
# 809 3139wFo58H4C: dict_keys(['error']):
# 810 SCY034COjXkC: dict_keys(['error']):
# 811 rTXB680gLl8C: dict_keys(['error']):
# 812 QZJPdsV-SyAC: dict_keys(['kind', 'totalItems', 'items']): 3: The Mother Tongue
# 813 XBaNEAAAQBAJ: dict_keys(['error']):
# 814 GuLZAAAAMAAJ: dict_keys(['error']):
# 815 JZ5UFcsMaKAC: dict_keys(['kind', 'totalItems']):
# 816 -pnzzgEACAAJ: dict_keys(['error']):
# 817 Wu8x5MNS1rAC: dict_keys(['error']):
# 818 7_IRAAAACAAJ: dict_keys(['error']):
# 819 EP8_zwEACAAJ: dict_keys(['error']):
# 820 aTaKNb1spQ8C: dict_keys(['error']):
# 821 0Ng2AAAACAAJ: dict_keys(['error']):
# 822 H4uMEAAAQBAJ: dict_keys(['error']):
# 823 5jE316OI8qgC: dict_keys(['error']):
# 824 NE-vsBpIuQ0C: dict_keys(['error']):
# 825 KBc3sv6Fo5gC: dict_keys(['error']):
# 826 QLw2sjBuF9oC: dict_keys(['error']):
# 827 uOSPZhoDIuMC: dict_keys(['kind', 'totalItems', 'items']): 1: Uncommon Carriers
# 828 kNp33i-AIq0C: dict_keys(['kind', 'totalItems']):
# 829 p1qKQgAACAAJ: dict_keys(['error']):
# 830 e0mlGwAACAAJ: dict_keys(['error']):
# 831 ds3uJRhlOB0C: dict_keys(['error']):
# 832 Xx0IHQAACAAJ: dict_keys(['error']):
# 833 kplYAAAAYAAJ: dict_keys(['error']):
# 834 z1XLUAwU1sIC: dict_keys(['error']):
# 835 sn1CGv9Rq5sC: dict_keys(['error']):
# 836 oPYCNFCUbGwC: dict_keys(['error']):
# 837 3Mx4QgAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Chaos and Order
# 838 PZiwQwAACAAJ: dict_keys(['kind', 'totalItems']):
# 839 FWNuQgAACAAJ: dict_keys(['error']):
# 840 5IZbGQGhEXAC: dict_keys(['error']):
# 841 a6NbAAAACAAJ: dict_keys(['error']):
# 842 ryot4Ag2GGQC: dict_keys(['error']):
# 843 0TRmtSOxcUAC: dict_keys(['error']):
# 844 MsuOzwEACAAJ: dict_keys(['error']):
# 845 xuB8SD2tVqkC: dict_keys(['error']):
# 846 zN4nV3d5ydMC: dict_keys(['error']):
# 847 0ZKAkX0W4A4C: dict_keys(['error']):
# 848 js_tNwAACAAJ: dict_keys(['error']):
# 849 aYZYAAAAYAAJ: dict_keys(['error']):
# 850 L_FGsSyk2PkC: dict_keys(['error']):
# 851 idPQNAEACAAJ: dict_keys(['error']):
# 852 pZlZAAAAMAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Teresa of Avila
# 853 9VIhmAEACAAJ: dict_keys(['kind', 'totalItems']):
# 854 XgvYmAEACAAJ: dict_keys(['error']):
# 855 2oFsAAAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Starting an eBay Business For Dummies
# 856 fkfOAAAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Perimbangan keuangan antara pemerintah pusat dan daerah
# 857 dX_UngEACAAJ: dict_keys(['error']):
# 858 Q6G3NAEACAAJ: dict_keys(['error']):
# 859 E_KMa5Zab0MC: dict_keys(['error']):
# 860 bVf9SQKUumgC: dict_keys(['error']):
# 861 vyLjg5nCSl4C: dict_keys(['error']):
# 862 nnbhmAEACAAJ: dict_keys(['error']):
# 863 pHpsUvO5tGoC: dict_keys(['kind', 'totalItems']):
# 864 kceNEAAAQBAJ: dict_keys(['kind', 'totalItems']):
# 865 14OMEAAAQBAJ: dict_keys(['error']):
# 866 Jv-m1SfwQzAC: dict_keys(['error']):
# 867 6UsNAAAAQBAJ: dict_keys(['kind', 'totalItems']):
# 868 tDDuAAAAMAAJ: dict_keys(['kind', 'totalItems', 'items']): 26: Water-supply Paper
# 869 eOrv5wGPnTgC: dict_keys(['kind', 'totalItems']):
# 870 OsenoMTnbyIC: dict_keys(['kind', 'totalItems']):
# 871 jj8obybCRasC: dict_keys(['error']):
# 872 k9hfQgAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Untouchables
# 873 LOZtAAAAMAAJ: dict_keys(['error']):
# 874 JDsr2Oxn-3YC: dict_keys(['error']):
# 875 A9pb6_Lug5sC: dict_keys(['error']):
# 876 v5_EPwAACAAJ: dict_keys(['error']):
# 877 2PMkHAAACAAJ: dict_keys(['kind', 'totalItems']):
# 878 MyganwEACAAJ: dict_keys(['error']):
# 879 ySFdxL31nlUC: dict_keys(['error']):
# 880 waZvwh9Ha3YC: dict_keys(['error']):
# 881 cml6AAAACAAJ: dict_keys(['error']):
# 882 _kEnozNXib4C: dict_keys(['kind', 'totalItems']):
# 883 pzSgm88YFCYC: dict_keys(['error']):
# 884 oK7U5DbFA3gC: dict_keys(['kind', 'totalItems']):
# 885 D_zizAEACAAJ: dict_keys(['kind', 'totalItems']):
# 886 jAEY3Kbnj3oC: dict_keys(['error']):
# 887 l_1xed01BsQC: dict_keys(['error']):
# 888 D4NcAAAAMAAJ: dict_keys(['kind', 'totalItems']):
# 889 YtSMDQAAQBAJ: dict_keys(['error']):
# 890 sP1yAQAACAAJ: dict_keys(['kind', 'totalItems']):
# 891 JwRUPwAACAAJ: dict_keys(['kind', 'totalItems']):
# 892 0ihknQqDFDwC: dict_keys(['error']):
# 893 8pT7wAEACAAJ: dict_keys(['error']):
# 894 wy5lDwAAQBAJ: dict_keys(['kind', 'totalItems']):
# 895 h7pjdEPBeGUC: dict_keys(['kind', 'totalItems']):
# 896 Me4-AAAACAAJ: dict_keys(['error']):
# 897 gm3bFIChXowC: dict_keys(['kind', 'totalItems', 'items']): 1: The Phantom Tollbooth
# 898 Lxn6PSnbD30C: dict_keys(['error']):
# 899 4_ocfLBdl2kC: dict_keys(['error']):
# 900 7KcOAQAAMAAJ: dict_keys(['kind', 'totalItems']):
# 901 zUYOEp5uXYYC: dict_keys(['error']):
# 902 eQR81OfUJdEC: dict_keys(['error']):
# 903 OZKLDQAAQBAJ: dict_keys(['error']):
# 904 DMDjrDjBYZgC: dict_keys(['error']):
# 905 XpQr6OaPdcgC: dict_keys(['kind', 'totalItems']):
# 906 __I3zjJtRrMC: dict_keys(['kind', 'totalItems']):
# 907 _pgrUFe9Fh8C: dict_keys(['error']):
# 908 xtTskZh4sKEC: dict_keys(['error']):
# 909 UkF0qUme5H4C: dict_keys(['error']):
# 910 fhY_BAAAQBAJ: dict_keys(['error']):
# 911 GcY0EAAAQBAJ: dict_keys(['kind', 'totalItems']):
# 912 SE8eAQAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 3: The Montauk Project - Experiments in Time
# 913 Opf3yeQixwQC: dict_keys(['error']):
# 914 6MzR9BfSXhMC: dict_keys(['kind', 'totalItems']):
# 915 LoNPEAAAQBAJ: dict_keys(['error']):
# 916 Re7WYDC4URQC: dict_keys(['error']):
# 917 8E4aPAAACAAJ: dict_keys(['kind', 'totalItems']):
# 918 YdW5wSPJXIoC: dict_keys(['kind', 'totalItems', 'items']): 17: The Collapse of Complex Societies
# 919 rd2ibodep7UC: dict_keys(['error']):
# 920 qZOMswEACAAJ: dict_keys(['kind', 'totalItems']):
# 921 h2DTNDFcC14C: dict_keys(['error']):
# 922 kFFWipanqsoC: dict_keys(['error']):
# 923 rwekkS3oD0EC: dict_keys(['error']):
# 924 zf0RDAEACAAJ: dict_keys(['kind', 'totalItems']):
# 925 wX9jQgAACAAJ: dict_keys(['error']):
# 926 F0MjQEGCLxQC: dict_keys(['kind', 'totalItems', 'items']): 1: CliffsNotes on Golding's Lord of the Flies
# 927 v7q94Nxje8MC: dict_keys(['kind', 'totalItems', 'items']): 1: A War Like No Other
# 928 X_RVAAAACAAJ: dict_keys(['error']):
# 929 QealPwAACAAJ: dict_keys(['error']):
# 930 VANbAAAAMAAJ: dict_keys(['kind', 'totalItems']):
# 931 6qhhSAAACAAJ: dict_keys(['error']):
# 932 z4yLQwAACAAJ: dict_keys(['error']):
# 933 1di6Vv1mtPQC: dict_keys(['error']):
# 934 MfpvDwAAQBAJ: dict_keys(['kind', 'totalItems', 'items']): 1: BEST OF THE BEST POCKET KAMUS KOREA
# 935 KMRReyLPyXMC: dict_keys(['error']):
# 936 9-fBHAAACAAJ: dict_keys(['error']):
# 937 N-In587uw_EC: dict_keys(['error']):
# 938 1aBkQgAACAAJ: dict_keys(['error']):
# 939 9nxfsPujsYoC: dict_keys(['kind', 'totalItems']):
# 940 UTw1AwAAQBAJ: dict_keys(['error']):
# 941 KiiTEAAAQBAJ: dict_keys(['kind', 'totalItems', 'items']): 1: A Cultural History of School Uniform
# 942 07CNEAAAQBAJ: dict_keys(['kind', 'totalItems']):
# 943 iy7uAAAAMAAJ: dict_keys(['error']):
# 944 RYAbzwEACAAJ: dict_keys(['kind', 'totalItems']):
# 945 Z2s-PgAACAAJ: dict_keys(['error']):
# 946 Ilp2NQEACAAJ: dict_keys(['error']):
# ...
# 2964 -chcOQAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: The Death Shift
# 2965 f-oLAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 2966 8V9GAAAAYAAJ: dict_keys(['error']):
# 2967 wxmrNlobwtIC: dict_keys(['error']):
# 2968 tRW9ycK8kyAC: dict_keys(['error']):
# 2969 y2h3qz-tuogC: dict_keys(['error']):
# 2970 cI1QAAAAMAAJ: dict_keys(['error']):
# 2971 ZYPdHJaE6yMC: dict_keys(['error']):
# 2972 UIBwQgAACAAJ: dict_keys(['error']):
# 2973 gQqONAAACAAJ: dict_keys(['error']):
# 2974 YX5mQgAACAAJ: dict_keys(['error']):
# 2975 kzuSuZj03P8C: dict_keys(['error']):
# 2976 ptJWAAAAMAAJ: dict_keys(['error']):
# 2977 El1QAAAAMAAJ: dict_keys(['error']):
# 2978 9d-JpKu-2u0C: dict_keys(['error']):
# 2979 UedePwAACAAJ: dict_keys(['error']):
# 2980 vd2JDQAAQBAJ: dict_keys(['error']):
# 2981 jWnxX6StvS0C: dict_keys(['kind', 'totalItems', 'items']): 3: Women
# 2982 _XqvyK3pTwsC: dict_keys(['error']):
# 2983 c_c7ZtrXbDYC: dict_keys(['error']):
# 2984 g0hQ2Nj2ti0C: dict_keys(['error']):
# 2985 21UKAAAACAAJ: dict_keys(['error']):
# 2986 S2_u4ZiQzrEC: dict_keys(['error']):
# 2987 w3xcngEACAAJ: dict_keys(['error']):
# 2988 AqLwAAAACAAJ: dict_keys(['error']):
# 2989 BEYkPQAACAAJ: dict_keys(['error']):
# 2990 2bS5AAAACAAJ: dict_keys(['error']):
# 2991 6JL1hPQ9HN4C: dict_keys(['error']):
# 2992 uQJRYS6oN7YC: dict_keys(['kind', 'totalItems']):
# 2993 JogBtAEACAAJ: dict_keys(['error']):
# 2994 keeuuQAACAAJ: dict_keys(['error']):
# 2995 Z0FiHAAACAAJ: dict_keys(['error']):
# 2996 HB7ctwEACAAJ: dict_keys(['kind', 'totalItems']):
# 2997 Lcklm__RnqUC: dict_keys(['error']):
# 2998 qLcluQOceyIC: dict_keys(['error']):
# 2999 Ik73H7d4x8gC: dict_keys(['error']):
# 3000 6j9YAAAAcAAJ: dict_keys(['error']):
# 3001 v2qEQgAACAAJ: dict_keys(['error']):
# 3002 U4XxAAAACAAJ: dict_keys(['error']):
# 3003 oLD8JwAACAAJ: dict_keys(['error']):
# 3004 WXeMzgEACAAJ: dict_keys(['error']):
# 3005 cUeXrwgToScC: dict_keys(['error']):
# 3006 9lghcQodq5UC: dict_keys(['error']):
# 3007 c-TSwAEACAAJ: dict_keys(['error']):
# 3008 vLPTtgAACAAJ: dict_keys(['error']):
# 3009 pW4FAAAACAAJ: dict_keys(['error']):
# 3010 0-eODQAAQBAJ: dict_keys(['kind', 'totalItems']):
# 3011 0n72xz2ecNYC: dict_keys(['error']):
# 3012 n_7-8NXgl3EC: dict_keys(['error']):
# 3013 GRfSV_71yHkC: dict_keys(['error']):
# 3014 2pWnHAAACAAJ: dict_keys(['error']):
# 3015 Tw7HenIekbMC: dict_keys(['error']):
# 3016 i7CJAAAACAAJ: dict_keys(['error']):
# 3017 e1CoxZhUcTMC: dict_keys(['error']):
# 3018 23uWDAEACAAJ: dict_keys(['error']):
# 3019 iFoKAAAACAAJ: dict_keys(['error']):
# 3020 7s_DAAAACAAJ: dict_keys(['error']):
# 3021 Ty1yMgAACAAJ: dict_keys(['error']):
# 3022 QxJXjwEACAAJ: dict_keys(['kind', 'totalItems']):
# 3023 n-WKlAEACAAJ: dict_keys(['error']):
# 3024 migamAEACAAJ: dict_keys(['error']):
# 3025 MGGBfPjVRo0C: dict_keys(['kind', 'totalItems']):
# 3026 Mm0AAAAACAAJ: dict_keys(['error']):
# 3027 nXF4PgAACAAJ: dict_keys(['error']):
# 3028 0Fa7jwEACAAJ: dict_keys(['error']):
# 3029 VAzkSUmzGswC: dict_keys(['error']):
# 3030 y4luAAAAMAAJ: dict_keys(['error']):
# 3031 uBoJAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 3032 L_7nlwEACAAJ: dict_keys(['error']):
# 3033 1P-FcgE0pcMC: dict_keys(['error']):
# 3034 KEDl0N7Rj_MC: dict_keys(['error']):
# 3035 o942_R-7sCAC: dict_keys(['error']):
# 3036 UXsNlwEACAAJ: dict_keys(['error']):
# 3037 7MyFAAAACAAJ: dict_keys(['error']):
# 3038 sFXndEyaZJEC: dict_keys(['error']):
# 3039 F-b-Vo5hpYoC: dict_keys(['error']):
# 3040 exf-tx-M-NIC: dict_keys(['kind', 'totalItems', 'items']): 1820: Independent Component Analysis
# 3041 tON3GwAACAAJ: dict_keys(['error']):
# 3042 dHnwGwAACAAJ: dict_keys(['error']):
# 3043 gYAsPAAACAAJ: dict_keys(['error']):
# 3044 b92U_McN4FUC: dict_keys(['kind', 'totalItems']):
# 3045 0o_YlgEACAAJ: dict_keys(['error']):
# 3046 YCiAYZFYKU0C: dict_keys(['error']):
# 3047 lq6KDQAAQBAJ: dict_keys(['error']):
# 3048 rSE4j-kKv7oC: dict_keys(['kind', 'totalItems', 'items']): 5: Matilda
# 3049 WmQiAQAAIAAJ: dict_keys(['error']):
# 3050 7zEJAAAACAAJ: dict_keys(['error']):
# 3051 1niOf6PUf1wC: dict_keys(['error']):
# 3052 1hfFjwEACAAJ: dict_keys(['kind', 'totalItems']):
# 3053 syQwAQAAIAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: John Hammond on Record
# 3054 PUzhAAAAMAAJ: dict_keys(['error']):
# 3055 396sPAAACAAJ: dict_keys(['error']):
# 3056 6oyODQAAQBAJ: dict_keys(['error']):
# 3057 2gsvPwAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 2: The Meanest Doll in the World
# 3058 ZcVHPwAACAAJ: dict_keys(['error']):
# 3059 roHf588GZJYC: dict_keys(['error']):
# 3060 iltaAAAAMAAJ: dict_keys(['error']):
# 3061 6wMmEAAAQBAJ: dict_keys(['error']):
# 3062 6ZSlyD17STsC: dict_keys(['error']):
# 3063 kRzxwAEACAAJ: dict_keys(['error']):
# 3064 c3CaKi39-F0C: dict_keys(['error']):
# 3065 ElvYlgEACAAJ: dict_keys(['error']):
# 3066 h45lAAAAMAAJ: dict_keys(['error']):
# 3067 8KKnlwEACAAJ: dict_keys(['error']):
# 3068 HOWXw3Y5dCcC: dict_keys(['error']):
# 3069 oEPl84FQpxgC: dict_keys(['kind', 'totalItems']):
# 3070 VIUi2IWwuLsC: dict_keys(['error']):
# 3071 JPiiHAAACAAJ: dict_keys(['error']):
# 3072 rK2WmAEACAAJ: dict_keys(['kind', 'totalItems']):
# 3073 OozdwAEACAAJ: dict_keys(['error']):
# 3074 DppT-OV4Np8C: dict_keys(['error']):
# 3075 hvxrHQAACAAJ: dict_keys(['error']):
# 3076 sVG-AAAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 119: A Complete Manual of Amateur Astronomy
# 3077 eK3sAQAACAAJ: dict_keys(['kind', 'totalItems']):
# 3078 xv2L3JymUSQC: dict_keys(['kind', 'totalItems', 'items']): 2: Memory's Nation
# 3079 2wDmAAAACAAJ: dict_keys(['error']):
# 3080 EcGGDwAAQBAJ: dict_keys(['kind', 'totalItems']):
# 3081 LJxhvgEACAAJ: dict_keys(['error']):
# 3082 0bKNEAAAQBAJ: dict_keys(['kind', 'totalItems']):
# 3083 3OwAnoLeneMC: dict_keys(['error']):
# 3084 TNhZAAAAMAAJ: dict_keys(['error']):
# 3085 p_ZU6j0S6noC: dict_keys(['error']):
# 3086 tkSTEAAAQBAJ: dict_keys(['error']):
# 3087 8TWrQgAACAAJ: dict_keys(['error']):
# 3088 tmu_wAEACAAJ: dict_keys(['error']):
# 3089 eJWjES159ocC: dict_keys(['kind', 'totalItems']):
# 3090 Q1HxjgEACAAJ: dict_keys(['kind', 'totalItems']):
# 3091 eC7T1ZJW_SAC: dict_keys(['kind', 'totalItems']):
# 3092 xilff6LAWAcC: dict_keys(['error']):
# 3093 Yr5NEAAAQBAJ: dict_keys(['error']):
# 3094 ket2brEYGIwC: dict_keys(['kind', 'totalItems']):
# 3095 oXCpw48yj0EC: dict_keys(['kind', 'totalItems', 'items']): 2: The Turtle and the Monkey
# 3096 kRsHlPD3bcgC: dict_keys(['error']):
# 3097 E1qNDQAAQBAJ: dict_keys(['error']):
# 3098 96qdmAEACAAJ: dict_keys(['kind', 'totalItems']):
# 3099 ZxPmYfLkjb0C: dict_keys(['kind', 'totalItems']):
# 3100 cAkUAQAAMAAJ: dict_keys(['error']):
# 3101 v7tAPgAACAAJ: dict_keys(['error']):
# 3102 N4KRAAAAIAAJ: dict_keys(['error']):
# 3103 Weg9NwAACAAJ: dict_keys(['error']):
# 3104 v3wiAQAAMAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: The Culture of Fear
# 3105 EBMRAQAAIAAJ: dict_keys(['kind', 'totalItems']):
# 3106 vH2MEAAAQBAJ: dict_keys(['error']):
# 3107 AB0gAQAAIAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Ernest Rutherford
# 3108 c5DcXFV6Xm4C: dict_keys(['error']):
# 3109 WmkbAQAAMAAJ: dict_keys(['error']):
# 3110 AJHilwEACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Joe's Diner
# 3111 hdF6HTBvK30C: dict_keys(['error']):
# 3112 xYB2TYqEdQEC: dict_keys(['kind', 'totalItems']):
# 3113 9orUvwEACAAJ: dict_keys(['error']):
# 3114 7geB74r4AcoC: dict_keys(['kind', 'totalItems', 'items']): 3: Boy Who Turned Into a TV Set
# 3115 p-R1NQEACAAJ: dict_keys(['error']):
# 3116 VCUgAQAAIAAJ: dict_keys(['kind', 'totalItems']):
# 3117 xadHAgAACAAJ: dict_keys(['error']):
# 3118 shU0A7v8fnIC: dict_keys(['error']):
# 3119 K1Byb0FCifMC: dict_keys(['kind', 'totalItems']):
# 3120 Zx6xAAAACAAJ: dict_keys(['error']):
# 3121 2yU4AQAAIAAJ: dict_keys(['error']):
# 3122 0ntXkgEACAAJ: dict_keys(['error']):
# 3123 YAuuzOLoScIC: dict_keys(['error']):
# 3124 9d8eGgAACAAJ: dict_keys(['error']):
# 3125 8ClIPwAACAAJ: dict_keys(['error']):
# 3126 IG_WAAAAMAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Asimov's Guide to the Bible
# 3127 E8TKAAAACAAJ: dict_keys(['kind', 'totalItems']):
# 3128 Nag2IhmPS3gC: dict_keys(['error']):
# 3129 Kt2qHwAACAAJ: dict_keys(['error']):
# 3130 e7kmzwEACAAJ: dict_keys(['error']):
# 3131 8nfZHAAACAAJ: dict_keys(['error']):
# 3132 oRBdGwAACAAJ: dict_keys(['error']):
# 3133 sAV5QgAACAAJ: dict_keys(['error']):
# 3134 tUNMGwAACAAJ: dict_keys(['error']):
# 3135 mSeeR6eVaa8C: dict_keys(['error']):
# 3136 eGpP36O6JskC: dict_keys(['error']):
# 3137 Fzk5BAOo_jsC: dict_keys(['kind', 'totalItems', 'items']): 1: The Shakespeare Stealer
# 3138 pxvc3ufQddIC: dict_keys(['error']):
# 3139 b46DX3ASh6AC: dict_keys(['error']):
# 3140 8u19X3rYdp0C: dict_keys(['error']):
# 3141 Hd6aDgAAQBAJ: dict_keys(['error']):
# 3142 39uMGQAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 2: Big Girls Don't Cry
# 3143 clMSAAAACAAJ: dict_keys(['error']):
# 3144 herrly9O22EC: dict_keys(['error']):
# 3145 AnZ8AAAACAAJ: dict_keys(['kind', 'totalItems']):
# 3146 rj-NEAAAQBAJ: dict_keys(['error']):
# 3147 UOFfewAACAAJ: dict_keys(['error']):
# 3148 XzqZAAAACAAJ: dict_keys(['error']):
# 3149 6TBr9lMlh-QC: dict_keys(['kind', 'totalItems']):
# 3150 tJzgQQAACAAJ: dict_keys(['error']):
# 3151 pdpUPwAACAAJ: dict_keys(['kind', 'totalItems']):
# 3152 oBaI6MnPHxcC: dict_keys(['error']):
# 3153 Y7eZWQbDfdEC: dict_keys(['error']):
# 3154 NLntAAAAMAAJ: dict_keys(['error']):
# 3155 lS0bxG4vsZUC: dict_keys(['error']):
# 3156 H1oIAAAACAAJ: dict_keys(['error']):
# 3157 HvannQEACAAJ: dict_keys(['error']):
# 3158 PkyPGQAACAAJ: dict_keys(['kind', 'totalItems']):
# 3159 K1mKDQAAQBAJ: dict_keys(['error']):
# 3160 setWPgAACAAJ: dict_keys(['error']):
# 3161 6hkExFYAvMEC: dict_keys(['error']):
# 3162 -6VTPgAACAAJ: dict_keys(['error']):
# 3163 uxUHmAEACAAJ: dict_keys(['error']):
# 3164 gTTf1bX9ECAC: dict_keys(['error']):
# 3165 ZSQJy2tF2UAC: dict_keys(['kind', 'totalItems']):
# 3166 nLiacLHmhOsC: dict_keys(['error']):
# 3167 XMUsAwAAQBAJ: dict_keys(['error']):
# 3168 zOgJAQAAMAAJ: dict_keys(['error']):
# 3169 __FNjgEACAAJ: dict_keys(['error']):
# 3170 DpMXCO27HUYC: dict_keys(['error']):
# 3171 gOfHHAAACAAJ: dict_keys(['error']):
# 3172 -CiJDAAAQBAJ: dict_keys(['error']):
# 3173 vgFUlbSbJ3kC: dict_keys(['error']):
# 3174 53_gTwjRTvYC: dict_keys(['error']):
# 3175 rEBaAAAAYAAJ: dict_keys(['error']):
# 3176 fZzUlwEACAAJ: dict_keys(['error']):
# 3177 3-XRo-PSwsQC: dict_keys(['error']):
# 3178 S1EOmQEACAAJ: dict_keys(['error']):
# 3179 dKL48e_c6kIC: dict_keys(['kind', 'totalItems']):
# 3180 YUiPy-MH1AMC: dict_keys(['error']):
# 3181 2LXIPoESG9kC: dict_keys(['error']):
# 3182 c3BvPwAACAAJ: dict_keys(['error']):
# 3183 VGSztGHC914C: dict_keys(['kind', 'totalItems']):
# 3184 Dt8lTI6Q4h0C: dict_keys(['error']):
# 3185 uVNpAAAAMAAJ: dict_keys(['kind', 'totalItems']):
# 3186 _tPXPAAACAAJ: dict_keys(['error']):
# 3187 -OgN5Xezh8QC: dict_keys(['error']):
# 3188 bPcEAQAACAAJ: dict_keys(['kind', 'totalItems']):
# 3189 eHWREAAAQBAJ: dict_keys(['error']):
# 3190 3r9uPwAACAAJ: dict_keys(['error']):
# 3191 T_Tc8tBl4goC: dict_keys(['kind', 'totalItems']):
# 3192 pLPvnQEACAAJ: dict_keys(['kind', 'totalItems']):
# 3193 XUlBDQEACAAJ: dict_keys(['error']):
# 3194 zfc8vgAACAAJ: dict_keys(['error']):
# 3195 PL3Boa71_iQC: dict_keys(['kind', 'totalItems']):
# 3196 DfiH7n--DBMC: dict_keys(['error']):
# 3197 5VQnxV6y0PIC: dict_keys(['kind', 'totalItems']):
# 3198 FLVFBAldATIC: dict_keys(['kind', 'totalItems']):
# 3199 J51bOQAACAAJ: dict_keys(['kind', 'totalItems']):
# 3200 vqTZPAAACAAJ: dict_keys(['error']):
# 3201 ruZyomCSppUC: dict_keys(['error']):
# 3202 nj11AAAAIAAJ: dict_keys(['kind', 'totalItems']):
# 3203 WzsFCAAAQBAJ: dict_keys(['kind', 'totalItems']):
# 3204 BWUaOQAACAAJ: dict_keys(['error']):
# 3205 zbqzAAAAIAAJ: dict_keys(['error']):
# 3206 ZKSliwlcWp4C: dict_keys(['error']):
# 3207 JoI6wGaVslUC: dict_keys(['error']):
# 3208 3NPxAAAAMAAJ: dict_keys(['error']):
# 3209 bfn9oj5Y7J0C: dict_keys(['error']):
# 3210 jGZtHAAACAAJ: dict_keys(['error']):
# 3211 JIsrAQAAMAAJ: dict_keys(['error']):
# 3212 JMRcoWAp_ewC: dict_keys(['kind', 'totalItems', 'items']): 1: Rash
# 3213 YlTVmAEACAAJ: dict_keys(['kind', 'totalItems']):
# 3214 gkgagay9Ng4C: dict_keys(['error']):
# 3215 RXSKvgEACAAJ: dict_keys(['error']):
# 3216 sPqLHAAACAAJ: dict_keys(['error']):
# 3217 7zHuAAAAMAAJ: dict_keys(['error']):
# 3218 yHn8zAEACAAJ: dict_keys(['error']):
# 3219 coAEAAAACAAJ: dict_keys(['error']):
# 3220 5gNeNgAACAAJ: dict_keys(['error']):
# 3221 stxpQgAACAAJ: dict_keys(['kind', 'totalItems']):
# 3222 Bpo2r2iKcKsC: dict_keys(['error']):
# 3223 VH5KrT-aGZoC: dict_keys(['error']):
# 3224 JQEO96zHEzQC: dict_keys(['error']):
# 3225 HIdajxSJf64C: dict_keys(['error']):
# 3226 3eDtzgEACAAJ: dict_keys(['kind', 'totalItems']):
# 3227 BKpMb0zylnMC: dict_keys(['kind', 'totalItems', 'items']): 1: The Church on the Other Side
# 3228 U72awDmOvxcC: dict_keys(['error']):
# 3229 W7VZAAAAMAAJ: dict_keys(['kind', 'totalItems']):
# 3230 Ec5HlwEACAAJ: dict_keys(['error']):
# 3231 l2lJH0BD77AC: dict_keys(['kind', 'totalItems', 'items']): 1: Kiss Kiss
# 3232 020FAAAACAAJ: dict_keys(['error']):
# 3233 lTGaAAAAIAAJ: dict_keys(['error']):
# 3234 xDHuAAAAMAAJ: dict_keys(['error']):
# 3235 mXtRwgEACAAJ: dict_keys(['error']):
# 3236 hqHJmAEACAAJ: dict_keys(['error']):
# 3237 aLkGAAAACAAJ: dict_keys(['error']):
# 3238 vtmUPwAACAAJ: dict_keys(['error']):
# 3239 HjE3_chaYM4C: dict_keys(['error']):
# 3240 9PEZW1uAjAkC: dict_keys(['kind', 'totalItems']):
# 3241 8Cog5PvSTG0C: dict_keys(['error']):
# 3242 mX4IAgAACAAJ: dict_keys(['kind', 'totalItems']):
# 3243 52d1PwAACAAJ: dict_keys(['error']):
# 3244 mF4yPQAACAAJ: dict_keys(['error']):
# 3245 8TLuAAAAMAAJ: dict_keys(['error']):
# 3246 1kEJzgEACAAJ: dict_keys(['error']):
# 3247 DgSl4_tFfR8C: dict_keys(['error']):
# 3248 Ufj7vvPLiIgC: dict_keys(['error']):
# 3249 Z2GIPwAACAAJ: dict_keys(['kind', 'totalItems']):
# 3250 3U3B7XPxU2sC: dict_keys(['error']):
# 3251 fzsFCAAAQBAJ: dict_keys(['error']):
# 3252 k_KOEAAAQBAJ: dict_keys(['kind', 'totalItems', 'items']): 1: Strategi Meningkatkan Kepuasan Nasabah Analisis Kasus melalui Riset di Industri Asuransi Jiwa
# 3253 2oSJDQAAQBAJ: dict_keys(['kind', 'totalItems', 'items']): 2: The Island at the Center of the World
# 3254 eqzsQ6yRZf0C: dict_keys(['kind', 'totalItems']):
# 3255 K3NDPgAACAAJ: dict_keys(['kind', 'totalItems']):
# 3256 GBZjQgAACAAJ: dict_keys(['error']):
# 3257 oLOwuQAACAAJ: dict_keys(['error']):
# 3258 dezaCwAAQBAJ: dict_keys(['error']):
# 3259 5iZhHAAACAAJ: dict_keys(['error']):
# 3260 7E8XAAAACAAJ: dict_keys(['error']):
# 3261 kU6FPwAACAAJ: dict_keys(['error']):
# 3262 I7TCQgAACAAJ: dict_keys(['kind', 'totalItems', 'items']): 1: No Name
# 3263 GKeGDDgp9oYC: dict_keys(['error']):
# 3264 OczMHlWYU34C: dict_keys(['error']):
# 3265 0UikyhzrKSsC: dict_keys(['kind', 'totalItems']):
# 3266 KnO8AAAACAAJ: dict_keys(['error']):
# 3267 dI2LDQAAQBAJ: dict_keys(['error']):
# 3268 cd3IwAEACAAJ: dict_keys(['error']):
# 3269 yxN88pY_ko8C: dict_keys(['error']):
# 3270 V-aLDQAAQBAJ: dict_keys(['error']):
# 3271 n3OODQAAQBAJ: dict_keys(['kind', 'totalItems']):
# 3272 eW_PqCF_kJQC: dict_keys(['error']):
# 3273 t1Rvp9MtRt0C: dict_keys(['error']):
# 3274 KWVrvgEACAAJ: dict_keys(['error']):
# 3275 bt2gcQAACAAJ: dict_keys(['error']):
# 3276 E7QsMowvmt0C: dict_keys(['error']):
# 3277 4w1vQRkAVxYC: dict_keys(['error']):
# 3278 dHcqAAAAYAAJ: dict_keys(['error']):
# 3279 z4LeIK16FGwC: dict_keys(['error']):
# 3280 UUhdAQAACAAJ: dict_keys(['kind', 'totalItems']):
# 3281 bWVppN7mdA0C: dict_keys(['error']):
# 3282 tcWMPAAACAAJ: dict_keys(['error']):
# 3283 O2JfAAAAMAAJ: dict_keys(['error']):
# 3284 y4kgSgAACAAJ: dict_keys(['error']):
# 3285 TaQZzgEACAAJ: dict_keys(['error']):
# 3286 d0buAAAAMAAJ: dict_keys(['error']):
#            book_id  average_rating  ratings_count
# 0     FBXRzgEACAAJ             NaN            NaN
# 1     yyxXzQEACAAJ             NaN            NaN
# 2     YjAnfhsAQ8wC             4.0            2.0
# 3     xb4wSmJLnhAC             NaN            NaN
# 4     Qq9nQgAACAAJ             4.0           46.0
# ...            ...             ...            ...
# 3282  tcWMPAAACAAJ             NaN            NaN
# 3283  O2JfAAAAMAAJ             NaN            NaN
# 3284  y4kgSgAACAAJ             NaN            NaN
# 3285  TaQZzgEACAAJ             NaN            NaN
# 3286  d0buAAAAMAAJ             NaN            NaN
#
# [3287 rows x 3 columns]

# %%
# Exporting isbn_book_df so i dont accidentally erase the data
all_data.to_csv('all_books_ratings.csv', index=False)
