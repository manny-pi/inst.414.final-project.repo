# %%
import pandas as pd

# %%
df = pd.read_csv('isbn13_results.csv')
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0            Harry Potter and the Chamber of Secrets
# 1           1           Harry Potter and the Prisoner of Azkaban
# 2           2                                       Harry Potter
# 3           3  Unauthorized Harry Potter and the Deathly Hall...
# 4           4                        The Harry Potter Collection
#
#                                             subtitle  \
# 0                                                NaN
# 1                                                NaN
# 2  5 Years of Magic, Adventure, and Mystery at Ho...
# 3  Harry Potter Book Seven and Half-Blood Prince ...
# 4  The First Six Spellbinding Adventures at Hogwarts
#
#                               authors              publisher publishdate  \
# 0  ['J. K. Rowling', 'Mary GrandPre']        Arthur a Levine        2003
# 1                   ['J. K. Rowling']  Scholastic Paperbacks        2004
# 2                   ['J. K. Rowling']                    NaN        2004
# 3          ['W. Frederick Zimmerman']           Nimble Books     2005-04
# 4                   ['J. K. Rowling']        Arthur a Levine  2005-10-01
#
#                                          description        isbn_13  \
# 0  When the Chamber of Secrets is opened again at...  9780439554893
# 1  During his third year at Hogwarts School for W...  9780439655484
# 2                                                NaN  9780439682589
# 3  Through the magic of print-on-demand technolog...  9780976540601
# 4  The first six years of Harry Potter magic are ...  9780439827607
#
#    page_count       main_categories            categories  average_rating  \
# 0       341.0  ['Juvenile Fiction']  ['Juvenile Fiction']             4.5
# 1       547.0  ['Juvenile Fiction']  ['Juvenile Fiction']             4.5
# 2         0.0                   NaN                   NaN             4.5
# 3       152.0           ['Fiction']           ['Fiction']             3.5
# 4         NaN  ['Juvenile Fiction']  ['Juvenile Fiction']             4.5
#
#    ratings_count maturity_rating
# 0         2273.0      NOT_MATURE
# 1         2122.0      NOT_MATURE
# 2           13.0      NOT_MATURE
# 3           11.0      NOT_MATURE
# 4           16.0      NOT_MATURE

# %%
df2 = pd.read_csv('books.csv')
df2.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       3  Harry Potter and the Chamber of Secrets (Harry...
# 3       4  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       5  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        authors average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPrÃ©           4.57   439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPrÃ©           4.49   439358078  9780439358071
# 2                 J.K. Rowling           4.42   439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPrÃ©           4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPrÃ©           4.78   439682584  9780439682589
#
#   language_code   num_pages  ratings_count  text_reviews_count  \
# 0           eng         652        2095690               27591
# 1           eng         870        2153167               29221
# 2           eng         352           6333                 244
# 3           eng         435        2339585               36325
# 4           eng        2690          41428                 164
#
#   publication_date        publisher
# 0        9/16/2006  Scholastic Inc.
# 1         9/1/2004  Scholastic Inc.
# 2        11/1/2003       Scholastic
# 3         5/1/2004  Scholastic Inc.
# 4        9/13/2004       Scholastic

# %%
import pandas as pd
import requests
import json

# %%
kaggle_data = pd.read_csv("books.csv")  # read the Kaggle books dataset
isbn_13 = kaggle_data['isbn13']         # extract the ISBN-13 column

isbn_13.shape
# Out:
# (11127,)

# %%
isbn_13.head(5)
# Out:
# 0    9780439785969
# 1    9780439358071
# 2    9780439554893
# 3    9780439655484
# 4    9780439682589
# Name: isbn13, dtype: object

# %%
# create an empty list to store the book data
book_data_list = []
url_base = 'https://www.googleapis.com/books/v1/volumes?q=isbn:'

# iterate over the ISBN 13 numbers, and get the information we need using the Google Books API
for i, isbn in enumerate(isbn_13):

    # generate the URL for the Google Books API search 
    url = url_base + isbn

    # get the book data; convert it to a dictionary using .json()
    book_data = requests.get(url).json()

    #print(f'{i} {isbn}: {book_data.keys()}', end=': ')
    
    if 'totalItems' in book_data and book_data['totalItems'] > 0:

        #print(book_data['totalItems'], end=': ')
        #print(book_data['items'][0]['volumeInfo']['title'], end='')
        # extract the relevant fields and create a new row in the DataFrame
        book = {
            'title': book_data['items'][0]['volumeInfo'].get('title', ''),
            'subtitle': book_data['items'][0]['volumeInfo'].get('subtitle', ''),
            'authors': book_data['items'][0]['volumeInfo'].get('authors', ''),
            'publisher': book_data['items'][0]['volumeInfo'].get('publisher', ''),
            'publishdate': book_data['items'][0]['volumeInfo'].get('publishedDate', ''),
            'description': book_data['items'][0]['volumeInfo'].get('description', ''),
            'isbn_13': isbn,
            'page_count': book_data['items'][0]['volumeInfo'].get('pageCount', ''),
            'main_categories': book_data['items'][0]['volumeInfo'].get('mainCategory', ''),
            'categories': book_data['items'][0]['volumeInfo'].get('categories', ''),
            'average_rating': book_data['items'][0]['volumeInfo'].get('averageRating', ''),
            'ratings_count': book_data['items'][0]['volumeInfo'].get('ratingsCount', ''),
            'maturity_rating': book_data['items'][0]['volumeInfo'].get('maturityRating', '')
        }

        # append the new dictionary to the book_data_list
        book_data_list.append(book)
    else:

        # handle the case where no results were returned for the ISBN-13 number
        # print(f"No results found for ISBN-13 {isbn}")
        pass
    
    #print()

# convert the list of dictionaries to a DataFrame
response_df = pd.DataFrame(book_data_list)

# %%
response_df.head(6)
# Out:
#                                                title  \
# 0            Harry Potter and the Chamber of Secrets
# 1           Harry Potter and the Prisoner of Azkaban
# 2                                       Harry Potter
# 3  Unauthorized Harry Potter and the Deathly Hall...
# 4                        The Harry Potter Collection
# 5                    The Ultimate Hitchhiker's Guide
#
#                                             subtitle  \
# 0
# 1
# 2  5 Years of Magic, Adventure, and Mystery at Ho...
# 3  Harry Potter Book Seven and Half-Blood Prince ...
# 4  The First Six Spellbinding Adventures at Hogwarts
# 5                 Five Complete Novels and One Story
#
#                           authors              publisher publishdate  \
# 0  [J. K. Rowling, Mary GrandPre]        Arthur a Levine        2003
# 1                 [J. K. Rowling]  Scholastic Paperbacks        2004
# 2                 [J. K. Rowling]                               2004
# 3        [W. Frederick Zimmerman]           Nimble Books     2005-04
# 4                 [J. K. Rowling]        Arthur a Levine  2005-10-01
# 5                 [Douglas Adams]               Gramercy        2005
#
#                                          description        isbn_13  \
# 0  When the Chamber of Secrets is opened again at...  9780439554893
# 1  During his third year at Hogwarts School for W...  9780439655484
# 2                                                     9780439682589
# 3  Through the magic of print-on-demand technolog...  9780976540601
# 4  The first six years of Harry Potter magic are ...  9780439827607
# 5                         6 Science fiction-romaner.  9780517226957
#
#   page_count main_categories                             categories  \
# 0        341                                     [Juvenile Fiction]
# 1        547                                     [Juvenile Fiction]
# 2          0
# 3        152                                              [Fiction]
# 4                                                [Juvenile Fiction]
# 5        844                  [Dent, Arthur (Fictitious character)]
#
#   average_rating ratings_count maturity_rating
# 0            4.5          2273      NOT_MATURE
# 1            4.5          2122      NOT_MATURE
# 2            4.5            13      NOT_MATURE
# 3            3.5            11      NOT_MATURE
# 4            4.5            16      NOT_MATURE
# 5            4.5            35      NOT_MATURE

# %%
mainCats = []
cats = []

for item in response_df['categories']:
    if len(item) == 1:
        catss = item[0].split(',')
        mainCats.append(catss[0])
        cats.append(catss[1:])
    else:
        pass

subs = []
for i in cats:
    if i == []:
        pass
    else:
        subs.append(i)

subs
# Out:
# [[' Arthur (Fictitious character)'],
#  [' Arthur (Fictitious character)'],
#  [' English'],
#  [' American'],
#  [' Paul (Fictitious character)'],
#  [' Mind & Spirit'],
#  [' Latin'],
#  [' Latin'],
#  [' Mind & Spirit'],
#  [' Elizabeth (Fictitious character)'],
#  [' English'],
#  [' English'],
#  [' Norse'],
#  [' French'],
#  [' strips', ' etc'],
#  [' Huckleberry (Fictitious character)'],
#  [' Ancient'],
#  [' James (Fictitious character)'],
#  [' Adam (Fictitious character)'],
#  [' Mind & Spirit'],
#  [' American'],
#  [' Spanish'],
#  [' American'],
#  [' British'],
#  [' Mind & Spirit'],
#  [' English'],
#  [' Chilean'],
#  [' Mind & Spirit'],
#  [' English'],
#  [' Italian'],
#  [' American'],
#  [' English'],
#  [' the far side of the world'],
#  [' American'],
#  [' strips', ' etc'],
#  [' Becky (Fictitious character)'],
#  [' English'],
#  [' American'],
#  [' Harry (Fictitious character)'],
#  [' JOSEPH.'],
#  [' American'],
#  [' Ancient'],
#  [' strips', ' etc'],
#  [' strips', ' etc'],
#  [' strips', ' etc'],
#  [' strips', ' etc'],
#  [' American'],
#  [' strips', ' etc'],
#  [' Mind & Spirit'],
#  [' English'],
#  [' English'],
#  [' strips', ' etc'],
#  [' American'],
#  [' English'],
#  [' English'],
#  [' Richard (Fictitious character)'],
#  [' strips', ' etc'],
#  [' Royal'],
#  [' Jack (Fictitious character)'],
#  [' 1800-1815'],
#  [' American'],
#  [' American'],
#  [' American'],
#  [' American'],
#  [' American'],
#  [' Russian'],
#  [' James (Fictitious character)'],
#  [' American'],
#  [' American'],
#  [' strips', ' etc'],
#  [' French'],
#  [' strips', ' etc'],
#  [' strips', ' etc'],
#  [' strips', ' etc'],
#  [' strips', ' etc'],
#  [' American'],
#  [' English'],
#  [' English'],
#  [' strips', ' etc'],
#  [' Norse'],
#  [' English'],
#  [' strips', ' etc'],
#  [' Modern'],
#  [' 1870-1871'],
#  [' N.Y.)'],
#  [' Polish'],
#  [' American'],
#  [' English'],
#  [' Adam (Fictitious character)'],
#  [' Mind & Spirit'],
#  [' Carol (Fictitious character)'],
#  [' Mind & Spirit'],
#  [' Anita (Fictitious character)'],
#  [' strips', ' etc'],
#  [' Anita (Fictitious character)'],
#  [' French'],
#  [' American'],
#  [' English'],
#  [' strips', ' etc'],
#  [' strips', ' etc'],
#  [' American'],
#  [' Mind & Spirit'],
#  [' American'],
#  [' 1973'],
#  [' Joseph (Fictitious character)'],
#  [' Mind & Spirit'],
#  [' Obi-Wan (Fictitious character)'],
#  [' Mythical', ' in art'],
#  [' French'],
#  [' 1961-1975 - États-Unis'],
#  [' American'],
#  [' strips', ' etc'],
#  [' strips', ' etc'],
#  [' strips', ' etc'],
#  [' Gaia (Fictitious character)'],
#  [' American'],
#  [' Max (Fictitious character)'],
#  [' Italian'],
#  [' American'],
#  [' American'],
#  [' Pacific'],
#  [' English'],
#  [' English'],
#  [' Jimi', ' 1942-1970'],
#  [' 1939-1945'],
#  [' Count (Fictitious character)'],
#  [' Modern'],
#  [' Edward X. (Fictitious character)'],
#  [' strips', ' etc'],
#  [' Belgian'],
#  [' Battle of', ' Gettysburg', ' Pa.', ' 1863'],
#  [' gothic'],
#  [' Japanese'],
#  [' Personal'],
#  [' American']]

# %%
book_data_list = []
url_base = 'https://www.googleapis.com/books/v1/volumes?q=isbn:'

# iterate over the ISBN 13 numbers, and get the information we need using the Google Books API
for i, isbn in enumerate(isbn_13):

    # generate the URL for the Google Books API search 
    url = url_base + isbn

    # get the book data; convert it to a dictionary using .json()
    book_data = requests.get(url).json()

    #print(f'{i} {isbn}: {book_data.keys()}', end=': ')
    
    if 'totalItems' in book_data and book_data['totalItems'] > 0:

        if len(book_data['items'][0]['volumeInfo'].get('categories', '')) > 1:
            print('Yes')
        
        
        #print(book_data['totalItems'], end=': ')
        #print(book_data['items'][0]['volumeInfo']['title'], end='')
        # extract the relevant fields and create a new row in the DataFrame
        
        #book = {
        #    'title': book_data['items'][0]['volumeInfo'].get('title', ''),
        #    'subtitle': book_data['items'][0]['volumeInfo'].get('subtitle', ''),
        #    'authors': book_data['items'][0]['volumeInfo'].get('authors', ''),
        #    'publisher': book_data['items'][0]['volumeInfo'].get('publisher', ''),
        #    'publishdate': book_data['items'][0]['volumeInfo'].get('publishedDate', ''),
        #    'description': book_data['items'][0]['volumeInfo'].get('description', ''),
        #    'isbn_13': isbn,
        #    'page_count': book_data['items'][0]['volumeInfo'].get('pageCount', ''),
        #    'main_categories': book_data['items'][0]['volumeInfo'].get('mainCategory', ''),
        #    'categories': book_data['items'][0]['volumeInfo'].get('categories', ''),
        #    'average_rating': book_data['items'][0]['volumeInfo'].get('averageRating', ''),
        #    'ratings_count': book_data['items'][0]['volumeInfo'].get('ratingsCount', ''),
        #    'maturity_rating': book_data['items'][0]['volumeInfo'].get('maturityRating', '')
        #}

        # append the new dictionary to the book_data_list
        #book_data_list.append(book)
    else:

        # handle the case where no results were returned for the ISBN-13 number
        # print(f"No results found for ISBN-13 {isbn}")
        pass
    
    #print()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 11
#       8 url = url_base + isbn
#      10 # get the book data; convert it to a dictionary using .json()
# ---> 11 book_data = requests.get(url).json()
#      13 #print(f'{i} {isbn}: {book_data.keys()}', end=': ')
#      15 if 'totalItems' in book_data and book_data['totalItems'] > 0:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
url_base = 'https://www.googleapis.com/books/v1/volumes?q=isbn:'

# iterate over the ISBN 13 numbers, and get the information we need using the Google Books API


for i, isbn in enumerate(isbn_13):
        
    # generate the URL for the Google Books API search 
    url = url_base + isbn

    # get the book data; convert it to a dictionary using .json()
    book_data = requests.get(url).json()
    
    if 'totalItems' in book_data and book_data['totalItems'] > 0:    
        print(book_data['items'][0]['volumeInfo'])
# Out:
# {'title': 'Harry Potter and the Chamber of Secrets', 'authors': ['J. K. Rowling', 'Mary GrandPre'], 'publisher': 'Arthur a Levine', 'publishedDate': '2003', 'description': 'When the Chamber of Secrets is opened again at the Hogwarts School for Witchcraft and Wizardry, second-year student Harry Potter finds himself in danger from a dark power that has once more been released on the school.', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0439554896'}, {'type': 'ISBN_13', 'identifier': '9780439554893'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 341, 'printType': 'BOOK', 'categories': ['Juvenile Fiction'], 'averageRating': 4.5, 'ratingsCount': 2273, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': 'preview-1.0.0', 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=h2Y-PgAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=h2Y-PgAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=h2Y-PgAACAAJ&dq=isbn:9780439554893&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.com/books?id=h2Y-PgAACAAJ&dq=isbn:9780439554893&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/Harry_Potter_and_the_Chamber_of_Secrets.html?hl=&id=h2Y-PgAACAAJ'}
# {'title': 'Harry Potter and the Prisoner of Azkaban', 'authors': ['J. K. Rowling'], 'publisher': 'Scholastic Paperbacks', 'publishedDate': '2004', 'description': "During his third year at Hogwarts School for Witchcraft and Wizardry, Harry Potter must confront the devious and dangerous wizard responsible for his parents' deaths.", 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '043965548X'}, {'type': 'ISBN_13', 'identifier': '9780439655484'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 547, 'printType': 'BOOK', 'categories': ['Juvenile Fiction'], 'averageRating': 4.5, 'ratingsCount': 2122, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': 'preview-1.0.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=FBXRzgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=FBXRzgEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=FBXRzgEACAAJ&dq=isbn:9780439655484&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.com/books?id=FBXRzgEACAAJ&dq=isbn:9780439655484&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/Harry_Potter_and_the_Prisoner_of_Azkaban.html?hl=&id=FBXRzgEACAAJ'}
# {'title': 'Harry Potter', 'subtitle': '5 Years of Magic, Adventure, and Mystery at Hogwarts', 'authors': ['J. K. Rowling'], 'publishedDate': '2004', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0439682584'}, {'type': 'ISBN_13', 'identifier': '9780439682589'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 0, 'printType': 'BOOK', 'averageRating': 4.5, 'ratingsCount': 13, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': 'preview-1.0.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=DAAAAAAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=DAAAAAAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=DAAAAAAACAAJ&dq=isbn:9780439682589&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.com/books?id=DAAAAAAACAAJ&dq=isbn:9780439682589&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/Harry_Potter.html?hl=&id=DAAAAAAACAAJ'}
# {'title': 'Unauthorized Harry Potter and the Deathly Hallows News', 'subtitle': 'Harry Potter Book Seven and Half-Blood Prince Analysis', 'authors': ['W. Frederick Zimmerman'], 'publisher': 'Nimble Books', 'publishedDate': '2005-04', 'description': 'Through the magic of print-on-demand technology, this "nimble" guide to the work of best-selling author J. K. Rowling provides the latest news about the author and her works, updated whenever there are significant developments. Unlike a conventional book, for which editions are printed in quantity every couple of years, this "living book" goes through frequent "mini-editions" and is printed fresh whenever customers place an order. Purchasers are entitled to free PDF updates! An entirely new section of analysis with more than 75 new pages will be added shortly after the release of "Harry Potter and the Half-Blood Prince" on July 16, 2005.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780976540601'}, {'type': 'ISBN_10', 'identifier': '0976540606'}], 'readingModes': {'text': True, 'image': False}, 'pageCount': 152, 'printType': 'BOOK', 'categories': ['Fiction'], 'averageRating': 3.5, 'ratingsCount': 11, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': '0.1.1.0.preview.2', 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=LH5C9q83T6wC&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=LH5C9q83T6wC&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=LH5C9q83T6wC&dq=isbn:9780976540601&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.com/books?id=LH5C9q83T6wC&dq=isbn:9780976540601&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/Unauthorized_Harry_Potter_and_the_Deathl.html?hl=&id=LH5C9q83T6wC'}
# {'title': 'The Harry Potter Collection', 'subtitle': 'The First Six Spellbinding Adventures at Hogwarts', 'authors': ['J. K. Rowling'], 'publisher': 'Arthur a Levine', 'publishedDate': '2005-10-01', 'description': "The first six years of Harry Potter magic are captured in a boxed set which includes The Sorcerer's Stone, The Chamber of Secrets, The Prisoner of Azkaban, The Goblet of Fire, The Order of the Phoenix, and The Half-Blood Prince.", 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '
hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/In_a_Sunburned_Country.html?hl=&id=7ZELqUsksIwC'}
# {'title': "I'm a Stranger Here Myself", 'subtitle': 'Notes on Returning to America After 20 Years Away', 'authors': ['Bill Bryson'], 'publisher': 'Crown', 'publishedDate': '1999', 'description': 'A classic from the New York Times bestselling author of A Walk in the Woods and The Body. After living in Britain for two decades, Bill Bryson recently moved back to the United States with his English wife and four children (he had read somewhere that nearly 3 million Americans believed they had been abducted by aliens—as he later put it, "it was clear my people needed me"). They were greeted by a new and improved America that boasts microwave pancakes, twenty-four-hour dental-floss hotlines, and the staunch conviction that ice is not a luxury item. Delivering the brilliant comic musings that are a Bryson hallmark, I\'m a Stranger Here Myself recounts his sometimes disconcerting reunion with the land of his birth. The result is a book filled with hysterical scenes of one man\'s attempt to reacquaint himself with his own country, but it is also an extended if at times bemused love letter to the homeland he has returned to after twenty years away.', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '076790382X'}, {'type': 'ISBN_13', 'identifier': '9780767903820'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 308, 'printType': 'BOOK', 'categories': ['Biography & Autobiography'], 'averageRating': 3.5, 'ratingsCount': 121, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': '2.2.3.0.preview.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=xb4wSmJLnhAC&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=xb4wSmJLnhAC&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=xb4wSmJLnhAC&dq=isbn:9780767903820&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.com/books?id=xb4wSmJLnhAC&dq=isbn:9780767903820&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/I_m_a_Stranger_Here_Myself.html?hl=&id=xb4wSmJLnhAC'}
# {'title': 'The Lost Continent', 'subtitle': 'Travels in Small Town America', 'authors': ['Bill Bryson'], 'publisher': 'Harper Collins', 'publishedDate': '1990-08-03', 'description': "An unsparing and hilarious account of one man's rediscovery of America and his search for the perfect small town.", 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780060920081'}, {'type': 'ISBN_10', 'identifier': '0060920084'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 324, 'printType': 'BOOK', 'categories': ['Travel'], 'averageRating': 3, 'ratingsCount': 2418, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': '0.2.1.0.preview.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=3139wFo58H4C&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=3139wFo58H4C&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=3139wFo58H4C&printsec=frontcover&dq=isbn:9780060920081&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.com/books?id=3139wFo58H4C&dq=isbn:9780060920081&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/The_Lost_Continent.html?hl=&id=3139wFo58H4C'}
# {'title': 'Neither Here Nor There:', 'subtitle': 'Travels in Europe', 'authors': ['Bill Bryson'], 'publisher': 'Harper Collins', 'publishedDate': '1993-03-01', 'description': "Like many of his generation, Bill Bryson backpacked across Europe in the early seventies -- in search of enlightenment, beer, and women. Twenty years later he decided to retrace the journey he undertook in the halcyon days of his youth. The result is Neither Here Nor There, an affectionate and riotously funny pilgrimage from the frozen wastes of Scandinavia to the chaotic tumult of Istanbul, with stops along the way in Europe's most diverting and historic locales. Like many of his generation, Bill Bryson backpacked across Europe in the early seventies--in search of enlightenment, beer, and women. Twenty years later he decided to retrace the journey he undertook in the halcyon days of his youth. The result is Neither Here Nor There, an affectionate and riotously funny pilgrimage from the frozen wastes of Scandinavia to the chaotic tumult of Istanbul, with stops along the way in Europe's most diverting and historic locales.", 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780380713806'}, {'type': 'ISBN_10', 'identifier': '0380713802'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 258, 'printType': 'BOOK', 'categories': ['Travel'], 'averageRating': 3, 'ratingsCount': 2201, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': '0.1.0.0.preview.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=SCY034COjXkC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=SCY034COjXkC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id
', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0618391002'}, {'type': 'ISBN_13', 'identifier': '9780618391004'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 218, 'printType': 'BOOK', 'categories': ['Literary Criticism'], 'averageRating': 4, 'ratingsCount': 5, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': '0.0.1.0.preview.0', 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=Wu8x5MNS1rAC&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=Wu8x5MNS1rAC&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=Wu8x5MNS1rAC&dq=isbn:9780618391004&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.com/books?id=Wu8x5MNS1rAC&dq=isbn:9780618391004&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/The_Lord_of_the_Rings.html?hl=&id=Wu8x5MNS1rAC'}
# {'title': 'The Lord of the Rings Complete Visual Companion', 'authors': ['Jude Fisher'], 'publisher': 'Mariner Books', 'publishedDate': '2004', 'description': 'Photographs, screenshots, and images from all three films provide a visual compendium of the film trilogy "The Lord of the Rings," documenting the varied characters and locales as seen through Peter Jackson\'s vision of Middle-earth.', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0618510826'}, {'type': 'ISBN_13', 'identifier': '9780618510825'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 0, 'printType': 'BOOK', 'categories': ['Performing Arts'], 'averageRating': 5, 'ratingsCount': 1, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': 'preview-1.0.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=7_IRAAAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=7_IRAAAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=7_IRAAAACAAJ&dq=isbn:9780618510825&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.com/books?id=7_IRAAAACAAJ&dq=isbn:9780618510825&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/The_Lord_of_the_Rings_Complete_Visual_Co.html?hl=&id=7_IRAAAACAAJ'}
# {'title': 'Agile Web Development with Rails', 'subtitle': 'A Pragmatic Guide', 'authors': ['David Thomas', 'David Heinemeier Hansson', 'Leon Breedt'], 'publishedDate': '2005', 'description': 'Provides information on creating Web-based applications', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '097669400X'}, {'type': 'ISBN_13', 'identifier': '9780976694007'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 0, 'printType': 'BOOK', 'categories': ['Agile software development'], 'averageRating': 3.5, 'ratingsCount': 9, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': 'preview-1.0.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=Qq9nQgAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=Qq9nQgAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=Qq9nQgAACAAJ&dq=isbn:9780976694007&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.com/books?id=Qq9nQgAACAAJ&dq=isbn:9780976694007&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/Agile_Web_Development_with_Rails.html?hl=&id=Qq9nQgAACAAJ'}
# ...
# {'title': 'The Changeling', 'subtitle': 'A Novel', 'authors': ['Kate Horsley'], 'publisher': 'National Geographic Books', 'publishedDate': '2005-04-12', 'description': 'Here, the author of the acclaimed Confessions of a Pagan Nun takes us to fourteenth-century Ireland for a strange and luminous tale of the elusive nature of identity and of triumph in adversity. The Changeling is the story of Grey, a peasant girl who is raised as a boy, and who, until adolescence, never doubts herself to be male. The revelation of her womanhood marks the beginning of her journey through a succession of changing identities—including son, wife, warrior, and mother—each of which brings its own special wisdom, but none of which, she discovers, can ultimately define her. In the course of her adventurous life, Grey deals with all the challenges of her tumultuous age—from political oppression to corrupt Church hierarchy to the horrors of the Black Death—ultimately finding peace and a kind of redemption by embracing the beautifully impermanent quality of identity that her unusual life has enabled her to understand. (Previously published in hardcover as The Changeling of Finnistuath .)', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781590301944'}, {'type': 'ISBN_10', 'identifier': '1590301943'}], 'readingModes': {'text': True, 'image': False}, 'pageCount': 0, 'printType': 'BOOK', 'categories': ['Fiction'], 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': 'preview-1.0.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=4jGQEAAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=4jGQEAAAQBAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=4jGQEAAAQBAJ&dq=isbn:9781590301944&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.com/books?id=4jGQEAAAQBAJ&dq=isbn:9781590301944&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/The_Changeling.html?hl=&id=4jGQEAAAQBAJ'}
# {'title': 'The Changeling', 'authors': ['Philippa Carr'], 'publisher': 'Ivy Books', 'publishedDate': '1990-08-28', 'description': 'FICTION-ROMANCE/GOTHIC', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0449146979'}, {'type': 'ISBN_13', 'identifier': '9780449146972'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 369, 'printType': 'BOOK', 'categories': ['Fiction'], 'averageRating': 3.5, 'ratingsCount': 2, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': '1.2.2.0.preview.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=5jE316OI8qgC&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=5jE316OI8qgC&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=5jE316OI8qgC&dq=isbn:9780449146972&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.com/books?id=5jE316OI8qgC&dq=isbn:9780449146972&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/The_Changeling.html?hl=&id=5jE316OI8qgC'}
# {'title': 'The Known World', 'authors': ['Edward P. Jones'], 'publisher': 'Harper Collins', 'publishedDate': '2006-08-29', 'description': "One of the most acclaimed novels in recent memory, The Known World is a daring and ambitious work by Pulitzer Prize winner Edward P. Jones. The Known World tells the story of Henry Townsend, a black farmer and former slave who falls under the tutelage of William Robbins, the most powerful man in Manchester County, Virginia. Making certain he never circumvents the law, Townsend runs his affairs with unusual discipline. But when death takes him unexpectedly, his widow, Caldonia, can't uphold the estate's order, and chaos ensues. Jones has woven a footnote of history into an epic that takes an unflinching look at slavery in all its moral complexities.", 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780061159176'}, {'type': 'ISBN_10', 'identifier': '0061159174'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 437, 'printType': 'BOOK', 'categories': ['Fiction'], 'averageRating': 3.5, 'ratingsCount': 90, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': '0.1.2.0.preview.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=NE-vsBpIuQ0C&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=NE-vsBpIuQ0C&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=NE-vsBpIuQ0C&printsec=frontcover&dq=isbn:9780061159176&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.com/books?id=NE-vsBpIuQ0C&dq=isbn:9780061159176&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/The_Known_World.html?hl=&id=NE-vsBpIuQ0C'}
# {'title': 'The Known World LP', 'authors': ['Edward P. Jones'], 'publisher': 'Harper Collins', 'publishedDate': '2004-06-15', 'description': "In one of the most acclaimed novels in recent memory, Edward P. Jones, two-time National Book Award finalist, tells the story of Henry Townsend, a black farmer and former slave who falls under the tutelage of William Robbins, the most powerful man in Manchester County, Virginia. Making certain he never circumvents the law, Townsend runs his affairs with unusual discipline. But when death takes him unexpectedly, his widow, Caldonia, can't uphold the estate's order and chaos ensues. In a daring and ambitious novel, Jones has woven a footnote of history into an epic that takes an unflinching look at slavery in all of its moral complexities.", 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0060749911'}, {'type': 'ISBN_13', 'identifier': '9780060749910'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 580, 'printType': 'BOOK', 'categories': ['Fiction'], 'averageRating': 3.5, 'ratingsCount': 99, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': '0.3.4.0.preview.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=KBc3sv6Fo5gC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=KBc3sv6Fo5gC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=KBc3sv6Fo5gC&printsec=frontcover&dq=isbn:9780060749910&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.com/books?id=KBc3sv6Fo5gC&dq=isbn:9780060749910&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/The_Known_World_LP.html?hl=&id=KBc3sv6Fo5gC'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 12
#       9 url = url_base + isbn
#      11 # get the book data; convert it to a dictionary using .json()
# ---> 12 book_data = requests.get(url).json()
#      14 if 'totalItems' in book_data and book_data['totalItems'] > 0:
#      15     print(book_data['items'][0]['volumeInfo'])
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:
