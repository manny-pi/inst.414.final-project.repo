# %% [markdown]
# ## This is a file to test methods on how to gather data using the "Original dataset" csv file that is in this Data folder.

# %%
import pandas as pd

# %%
df = pd.read_csv("Original dataset.csv")
df2 = df.head()
df2
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors average_rating        isbn       isbn13  \
# 0  J.K. Rowling/Mary GrandPré           4.57   439785960  9.78044E+12
# 1  J.K. Rowling/Mary GrandPré           4.49   439358078  9.78044E+12
# 2                J.K. Rowling           4.42   439554896  9.78044E+12
# 3  J.K. Rowling/Mary GrandPré           4.56  043965548X  9.78044E+12
# 4  J.K. Rowling/Mary GrandPré           4.78   439682584  9.78044E+12
#
#   language_code   num_pages  ratings_count  text_reviews_count  \
# 0           eng         652        2095690               27591
# 1           eng         870        2153167               29221
# 2           eng         352           6333                 244
# 3           eng         435        2339585               36325
# 4           eng        2690          41428                 164
#
#   publication_date        publisher Unnamed: 12
# 0        9/16/2006  Scholastic Inc.         NaN
# 1         9/1/2004  Scholastic Inc.         NaN
# 2        11/1/2003       Scholastic         NaN
# 3         5/1/2004  Scholastic Inc.         NaN
# 4        9/13/2004       Scholastic         NaN

# %%
for isbn in df2['isbn13']:
    print(isbn) #print each ISBN from each row
# Out:
# 9.78044E+12
# 9.78044E+12
# 9.78044E+12
# 9.78044E+12
# 9.78044E+12

# %% [markdown]
# ## To this point I can read in a CSV and select a specific column and its contents

# %% [markdown]
# ### Set up requests

# %%
import requests

# %%
# Define a function to call the Google Books API and extract the page count and description
def get_book_info(isbn):
    url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn}"
    response = requests.get(url)
    data = response.json()
    if 'totalItems' in data and data['totalItems'] > 0:
        book_info = data['items'][0]['volumeInfo']
        if 'description' in book_info:
            description = book_info['description']
        else:
            description = None
        if 'mainCategory' in book_info:
            main_category = book_info['mainCategory']
        else:
            main_category = None
        if 'categories' in book_info:
            categories = ', '.join(book_info['categories'])
        else:
            categories = None
        return description, main_category, categories
    else:
        return None, None, None

# Create a new dataframe to store the book info
descriptions = []
main_categories = []
categories_list = []
for isbn in df['isbn']:
    description, main_category, categories = get_book_info(isbn)
    descriptions.append(description)
    main_categories.append(main_category)
    categories_list.append(categories)

results_df = pd.DataFrame({
    'Main Category': main_categories,
    'Categories': categories_list,
    'Description': descriptions
}, index=df['isbn'])

# Print the first few rows of the results dataframe
print(results_df.head())
# Out:
#            Main Category        Categories  \
# isbn
# 439785960           None              None
# 439358078           None              None
# 439554896           None              None
# 043965548X          None  Juvenile Fiction
# 439682584           None              None
#
#                                                   Description
# isbn
# 439785960                                                None
# 439358078                                                None
# 439554896                                                None
# 043965548X  During his third year at Hogwarts School for W...
# 439682584                                                None

# %%
results_df
# Out:
#            Main Category                  Categories  \
# isbn
# 043965548X          None            Juvenile Fiction
# 1400052920          None                     Fiction
# 076790818X          None                     History
# 076790382X          None   Biography & Autobiography
# 097669400X          None  Agile software development
# ...                  ...                         ...
# 1581348134          None                    Religion
# 9681907191          None                     Farmers
# 843221728X          None                    Children
# 8466302298          None                     Fiction
# 1560254416          None                     Fiction
#
#                                                   Description
# isbn
# 043965548X  During his third year at Hogwarts School for W...
# 1400052920  NEW YORK TIMES BESTSELLER • “Extremely funny ....
# 076790818X  One of the world’s most beloved writers and Ne...
# 076790382X  A classic from the New York Times bestselling ...
# 097669400X  Provides information on creating Web-based app...
# ...                                                       ...
# 1581348134  The lives of Augustine, Luther, and Calvin rev...
# 9681907191  Había una vez un valle, y en el valle, tres gr...
# 843221728X  La historia de la infancia, vivida y soñada, d...
# 8466302298  La relacion amorosa del joven escritor Varguit...
# 1560254416  No stranger to living and writing on the edge,...
#
# [646 rows x 3 columns]

# %%
temp = results_df
temp
# Out:
#            Main Category                  Categories  \
# isbn
# 043965548X          None            Juvenile Fiction
# 1400052920          None                     Fiction
# 076790818X          None                     History
# 076790382X          None   Biography & Autobiography
# 097669400X          None  Agile software development
# ...                  ...                         ...
# 1581348134          None                    Religion
# 9681907191          None                     Farmers
# 843221728X          None                    Children
# 8466302298          None                     Fiction
# 1560254416          None                     Fiction
#
#                                                   Description
# isbn
# 043965548X  During his third year at Hogwarts School for W...
# 1400052920  NEW YORK TIMES BESTSELLER • “Extremely funny ....
# 076790818X  One of the world’s most beloved writers and Ne...
# 076790382X  A classic from the New York Times bestselling ...
# 097669400X  Provides information on creating Web-based app...
# ...                                                       ...
# 1581348134  The lives of Augustine, Luther, and Calvin rev...
# 9681907191  Había una vez un valle, y en el valle, tres gr...
# 843221728X  La historia de la infancia, vivida y soñada, d...
# 8466302298  La relacion amorosa del joven escritor Varguit...
# 1560254416  No stranger to living and writing on the edge,...
#
# [646 rows x 3 columns]

# %%
temp.dropna(subset=['Description'], inplace=True)
temp
# Out:
#            Main Category                  Categories  \
# isbn
# 043965548X          None            Juvenile Fiction
# 1400052920          None                     Fiction
# 076790818X          None                     History
# 076790382X          None   Biography & Autobiography
# 097669400X          None  Agile software development
# ...                  ...                         ...
# 1581348134          None                    Religion
# 9681907191          None                     Farmers
# 843221728X          None                    Children
# 8466302298          None                     Fiction
# 1560254416          None                     Fiction
#
#                                                   Description
# isbn
# 043965548X  During his third year at Hogwarts School for W...
# 1400052920  NEW YORK TIMES BESTSELLER • “Extremely funny ....
# 076790818X  One of the world’s most beloved writers and Ne...
# 076790382X  A classic from the New York Times bestselling ...
# 097669400X  Provides information on creating Web-based app...
# ...                                                       ...
# 1581348134  The lives of Augustine, Luther, and Calvin rev...
# 9681907191  Había una vez un valle, y en el valle, tres gr...
# 843221728X  La historia de la infancia, vivida y soñada, d...
# 8466302298  La relacion amorosa del joven escritor Varguit...
# 1560254416  No stranger to living and writing on the edge,...
#
# [646 rows x 3 columns]

# %%
temp_df = pd.merge(df,
                 results_df,
                 on='isbn', how='right')
temp_df
# Out:
#      bookID                                              title  \
# 0         5  Harry Potter and the Prisoner of Azkaban (Harr...
# 1        14  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 2        21               A Short History of Nearly Everything
# 3        25  I'm a Stranger Here Myself: Notes on Returning...
# 4        45  Agile Web Development with Rails: A Pragmatic ...
# ..      ...                                                ...
# 641   45354  The Legacy of Sovereign Joy: God's Triumphant ...
# 642   45568                                      El Superzorro
# 643   45585                                     Bella y oscura
# 644   45592                       La tía Julia y el escribidor
# 645   45631   Expelled from Eden: A William T. Vollmann Reader
#
#                                                authors average_rating  \
# 0                           J.K. Rowling/Mary GrandPré           4.56
# 1                                        Douglas Adams           4.22
# 2                                          Bill Bryson           4.21
# 3                                          Bill Bryson            3.9
# 4    Dave Thomas/David Heinemeier Hansson/Leon Bree...           3.84
# ..                                                 ...            ...
# 641                                         John Piper           4.27
# 642                           Roald Dahl/Horacio Elena           4.05
# 643                                       Rosa Montero           3.66
# 644                                 Mario Vargas Llosa           3.92
# 645  William T. Vollmann/Larry McCaffery/Michael He...           4.06
#
#            isbn       isbn13 language_code   num_pages  ratings_count  \
# 0    043965548X  9.78044E+12           eng         435        2339585
# 1    1400052920   9.7814E+12           eng         215           4930
# 2    076790818X  9.78077E+12           eng         544         248558
# 3    076790382X  9.78077E+12           eng         304          49240
# 4    097669400X  9.78098E+12           eng         558           1430
# ..          ...          ...           ...         ...            ...
# 641  1581348134  9.78158E+12           eng         158            839
# 642  9681907191  9.78968E+12           spa          96            174
# 643  843221728X  9.78843E+12           spa         204            293
# 644  8466302298  9.78847E+12           spa         566            162
# 645  1560254416  9.78156E+12           eng         512            156
#
#      text_reviews_count publication_date            publisher Unnamed: 12  \
# 0                 36325         5/1/2004      Scholastic Inc.         NaN
# 1                   460         8/3/2004                Crown         NaN
# 2                  9396        9/14/2004       Broadway Books         NaN
# 3                  2211        6/28/2000       Broadway Books         NaN
# 4                    59        7/28/2005  Pragmatic Bookshelf         NaN
# ..                  ...              ...                  ...         ...
# 641                  65        8/11/2006       Crossway Books         NaN
# 642                  20         6/1/2000   Alfaguara Infantil         NaN
# 643                  31         3/1/2006   Planeta Publishing         NaN
# 644                  10         3/1/2001                 Suma         NaN
# 645                  20       12/21/2004        Da Capo Press         NaN
#
#     Main Category                  Categories  \
# 0            None            Juvenile Fiction
# 1            None                     Fiction
# 2            None                     History
# 3            None   Biography & Autobiography
# 4            None  Agile software development
# ..            ...                         ...
# 641          None                    Religion
# 642          None                     Farmers
# 643          None                    Children
# 644          None                     Fiction
# 645          None                     Fiction
#
#                                            Description
# 0    During his third year at Hogwarts School for W...
# 1    NEW YORK TIMES BESTSELLER • “Extremely funny ....
# 2    One of the world’s most beloved writers and Ne...
# 3    A classic from the New York Times bestselling ...
# 4    Provides information on creating Web-based app...
# ..                                                 ...
# 641  The lives of Augustine, Luther, and Calvin rev...
# 642  Había una vez un valle, y en el valle, tres gr...
# 643  La historia de la infancia, vivida y soñada, d...
# 644  La relacion amorosa del joven escritor Varguit...
# 645  No stranger to living and writing on the edge,...
#
# [646 rows x 16 columns]

# %% [markdown]
# ## testing other api

# %%
isbn = "" # Example ISBN

# Send a request to the Open Library API to retrieve the book information
response = requests.get(f"https://openlibrary.org/isbn/{isbn}.json")

# Check if the request was successful
if response.status_code == 200:
    # Parse the response JSON to extract the book information
    book_data = response.json()
    
    # Extract the book description and categories
    description = book_data.get("description", {}).get("value")
    categories = book_data.get("subjects")
    
    # Print the book description and categories
    print("Description:", description)
    print("Categories:", categories)
else:
    # Print an error message if the request failed
    print("Error:", response.json()["error"])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 3 column 1 (char 2)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[90], line 20
#      17     print("Categories:", categories)
#      18 else:
#      19     # Print an error message if the request failed
# ---> 20     print("Error:", response.json()["error"])
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 3 column 1 (char 2)
