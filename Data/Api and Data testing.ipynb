# %% [markdown]
# ## This is a file to test methods on how to gather data using the "Original dataset" csv file that is in this Data folder.

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# # Read Kaggle dataset, and extract the ISBN 13 for all the books

# %%
kaggle_data = pd.read_csv("books.csv")  # read the Kaggle books dataset
isbn_13 = kaggle_data['isbn13']         # extract the ISBN-13 column

isbn_13.shape
# Out:
# (11127,)

# %%
isbn_13.head(5)
# Out:
# 0    9780439785969
# 1    9780439358071
# 2    9780439554893
# 3    9780439655484
# 4    9780439682589
# Name: isbn13, dtype: object

# %% [markdown]
# # Get the books from the Google Books API using the ISNB-13s

# %%
# create an empty list to store the book data
book_data_list = []
url_base = 'https://www.googleapis.com/books/v1/volumes?q=isbn:'

# iterate over the ISBN 13 numbers, and get the information we need using the Google Books API
for i, isbn in enumerate(isbn_13):
    print(i, ' ', isbn, end=': ')

    # generate the URL for the Google Books API search 
    url = url_base + isbn

    # get the book data; convert it to a dictionary using .json()
    book_data = requests.get(url).json()

    print(book_data.keys(), end=': ')
    
    if 'totalItems' in book_data and book_data['totalItems'] > 0:

        print(book_data['totalItems'], end=': ')
        print(book_data['items'][0]['volumeInfo']['title'], end='')
        # extract the relevant fields and create a new row in the DataFrame
        book = {
            'title': book_data['items'][0]['volumeInfo'].get('title', ''),
            'subtitle': book_data['items'][0]['volumeInfo'].get('subtitle', ''),
            'authors': book_data['items'][0]['volumeInfo'].get('authors', ''),
            'publisher': book_data['items'][0]['volumeInfo'].get('publisher', ''),
            'publishdate': book_data['items'][0]['volumeInfo'].get('publishedDate', ''),
            'description': book_data['items'][0]['volumeInfo'].get('description', ''),
            # 'isbn_10': book_data['items'][0]['volumeInfo'].get('industryIdentifiers', [{'type': '', 'identifier': ''}])[0].get('identifier', ''),
            # 'isbn_13': book_data['items'][0]['volumeInfo'].get('industryIdentifiers', [{'type': '', 'identifier': ''}])[1].get('identifier', ''),
            'page_count': book_data['items'][0]['volumeInfo'].get('pageCount', ''),
            'main_categories': book_data['items'][0]['volumeInfo'].get('categories', ''),
            'categories': book_data['items'][0]['volumeInfo'].get('categories', ''),
            'average_rating': book_data['items'][0]['volumeInfo'].get('averageRating', ''),
            'ratings_count': book_data['items'][0]['volumeInfo'].get('ratingsCount', ''),
            'maturity_rating': book_data['items'][0]['volumeInfo'].get('maturityRating', '')
        }
        # append the new dictionary to the book_data_list
        book_data_list.append(book)
    else:

        # handle the case where no results were returned for the ISBN-13 number
        # print(f"No results found for ISBN-13 {isbn}")
        pass

    print()
# convert the list of dictionaries to a DataFrame
response_df = pd.DataFrame(book_data_list)
# Out:
# 0   9780439785969: dict_keys(['kind', 'totalItems']):
# 1   9780439358071: dict_keys(['kind', 'totalItems']):
# 2   9780439554893: dict_keys(['kind', 'totalItems', 'items']): 1: Harry Potter and the Chamber of Secrets
# 3   9780439655484: dict_keys(['kind', 'totalItems', 'items']): 1: Harry Potter and the Prisoner of Azkaban
# 4   9780439682589: dict_keys(['kind', 'totalItems', 'items']): 1: Harry Potter
# 5   9780976540601: dict_keys(['kind', 'totalItems', 'items']): 1: Unauthorized Harry Potter and the Deathly Hallows News
# 6   9780439827607: dict_keys(['kind', 'totalItems', 'items']): 2: The Harry Potter Collection
# 7   9780517226957: dict_keys(['kind', 'totalItems', 'items']): 1: The Ultimate Hitchhiker's Guide
# 8   9780345453747: dict_keys(['kind', 'totalItems', 'items']): 1: The Ultimate Hitchhiker's Guide to the Galaxy
# 9   9781400052929: dict_keys(['kind', 'totalItems', 'items']): 2: The Hitchhiker's Guide to the Galaxy 25th Anniversary Edition
# 10   9780739322208: dict_keys(['kind', 'totalItems']):
# 11   9780517149256: dict_keys(['kind', 'totalItems', 'items']): 1: The Ultimate Hitchhiker's Guide
# 12   9780767908184: dict_keys(['kind', 'totalItems', 'items']): 1: A Short History of Nearly Everything
# 13   9780767915069: dict_keys(['kind', 'totalItems', 'items']): 1: Bill Bryson's African Diary
# 14   9780767910439: dict_keys(['kind', 'totalItems', 'items']): 1: Bryson's Dictionary of Troublesome Words
# 15   9780767903868: dict_keys(['kind', 'totalItems', 'items']): 1: In a Sunburned Country
# 16   9780767903820: dict_keys(['kind', 'totalItems', 'items']): 1: I'm a Stranger Here Myself
# 17   9780060920081: dict_keys(['kind', 'totalItems', 'items']): 1: The Lost Continent
# 18   9780380713806: dict_keys(['kind', 'totalItems', 'items']): 1: Neither Here Nor There:
# 19   9780380727506: dict_keys(['kind', 'totalItems', 'items']): 1: Notes from a Small Island
# 20   9780380715435: dict_keys(['kind', 'totalItems', 'items']): 2: The Mother Tongue
# 21   9780345538376: dict_keys(['kind', 'totalItems', 'items']): 1: The Hobbit / The Lord of the Rings
# 22   9780618517657: dict_keys(['kind', 'totalItems', 'items']): 1: The Lord of the Rings
# 23   9780618346257: dict_keys(['kind', 'totalItems', 'items']): 2: The Lord of the Rings
# 24   9780618260584: dict_keys(['kind', 'totalItems', 'items']): 3: The Two Towers
# 25   9780618391004: dict_keys(['kind', 'totalItems', 'items']): 1: The Lord of the Rings
# 26   9780618510825: dict_keys(['kind', 'totalItems', 'items']): 1: The Lord of the Rings Complete Visual Companion
# 27   9780976694007: dict_keys(['kind', 'totalItems', 'items']): 1: Agile Web Development with Rails
# 28   9780689840920: dict_keys(['kind', 'totalItems', 'items']): 1: Hatchet
# 29   9781557344496: dict_keys(['kind', 'totalItems', 'items']): 1: A Guide for Using Hatchet in the Classroom
# 30   9780385326506: dict_keys(['kind', 'totalItems', 'items']): 1: Guts
# 31   9781575606248: dict_keys(['kind', 'totalItems', 'items']): 1: Molly Hatchet
# 32   9781595580276: dict_keys(['kind', 'totalItems', 'items']): 1: Hatchet Jobs
# 33   9781595962805: dict_keys(['kind', 'totalItems', 'items']): 1: A Changeling for All Seasons
# 34   9780670059676: dict_keys(['kind', 'totalItems', 'items']): 1: Changeling
# 35   9780141312620: dict_keys(['kind', 'totalItems', 'items']): 1: The Changeling Sea
# 36   9780595321803: dict_keys(['kind', 'totalItems']):
# 37   9781590301944: dict_keys(['kind', 'totalItems', 'items']): 1: The Changeling
# 38   9780449146972: dict_keys(['kind', 'totalItems', 'items']): 1: The Changeling
# 39   9780061159176: dict_keys(['kind', 'totalItems', 'items']): 1: The Known World
# 40   9780060762735: dict_keys(['kind', 'totalItems']):
# 41   9780060749910: dict_keys(['kind', 'totalItems', 'items']): 1: The Known World LP
# 42   9780273704744: dict_keys(['kind', 'totalItems', 'items']): 1: Traders, Guns & Money
# 43   9781932386103: dict_keys(['kind', 'totalItems', 'items']): 1: Artesia: Adventures In The Known World RPG
# 44   9780374517199: dict_keys(['kind', 'totalItems']):
# 45   9780374280390: dict_keys(['kind', 'totalItems', 'items']): 1: Uncommon Carriers
# 46   9780374519742: dict_keys(['kind', 'totalItems', 'items']): 1: Heirs of General Practice
# 47   9780374522599: dict_keys(['kind', 'totalItems', 'items']): 1: The Control of Nature
# 48   9780374518738: dict_keys(['kind', 'totalItems', 'items']): 1: Annals of the Former World
# 49   9780374522872: dict_keys(['kind', 'totalItems', 'items']): 1: Coming Into the Country
# 50   9780374519322: dict_keys(['kind', 'totalItems']):
# 51   9780374516000: dict_keys(['kind', 'totalItems', 'items']): 1: Giving Good Weight
# 52   9780374520656: dict_keys(['kind', 'totalItems', 'items']): 1: Rising from the Plains
# 53   9780822205104: dict_keys(['kind', 'totalItems', 'items']): 1: The Heidi Chronicles
# 54   9780679734994: dict_keys(['kind', 'totalItems', 'items']): 1: The Heidi Chronicles
# 55   9781596670235: dict_keys(['kind', 'totalItems', 'items']): 1: Active Literacy Across the Curriculum
# 56   9781581807745: dict_keys(['kind', 'totalItems', 'items']): 2: Simply Beautiful Beaded Jewelry
# 57   9780800793616: dict_keys(['kind', 'totalItems', 'items']): 1: Always Enough
# 58   9780871202864: dict_keys(['kind', 'totalItems', 'items']): 2: Mapping the Big Picture
# 59   9780753454947: dict_keys(['kind', 'totalItems', 'items']): 1: Heidi
# 60   9780871209993: dict_keys(['kind', 'totalItems', 'items']): 1: Getting Results with Curriculum Mapping
# 61   9781852402877: dict_keys(['kind', 'totalItems', 'items']): 1: There is Always Enough
# 62   9780761129585: dict_keys(['kind', 'totalItems', 'items']): 1: What to Expect the First Year
# 63   9780972016414: dict_keys(['kind', 'totalItems', 'items']): 1: The Player's Handbook
# 64   9781581805635: dict_keys(['kind', 'totalItems', 'items']): 1: Simply Beautiful Beading
# 65   9780441294671: dict_keys(['kind', 'totalItems']):
# 66   9780441102679: dict_keys(['kind', 'totalItems', 'items']): 1: Chapterhouse: Dune
# 67   9780441172696: dict_keys(['kind', 'totalItems', 'items']): 1: Dune Messiah
# 68   9780765306470: dict_keys(['kind', 'totalItems', 'items']): 1: Dreamer of Dune
# 69   9780399128981: dict_keys(['kind', 'totalItems', 'items']): 1: Heretics of Dune
# 70   9780765353702: dict_keys(['kind', 'totalItems', 'items']): 1: The Road to Dune
# 71   9780441328000: dict_keys(['kind', 'totalItems', 'items']): 1: Heretics of Dune
# 72   9780618212903: dict_keys(['kind', 'totalItems', 'items']): 1: The Lord of the Rings
# 73   9780345410054: dict_keys(['kind', 'totalItems', 'items']): 1: The Power of One
# 74   9780385732543: dict_keys(['kind', 'totalItems', 'items']): 1: The Power of One
# 75   9780785260059: dict_keys(['kind', 'totalItems', 'items']): 1: The Power of One
# 76   9780471780939: dict_keys(['kind', 'totalItems', 'items']): 1: Power of An Hour
# 77   9780325001531: dict_keys(['kind', 'totalItems', 'items']): 1: The Power of One
# 78   9780060762872: dict_keys(['kind', 'totalItems', 'items']): 1: How to Buy, Sell, and Profit on eBay
# 79   9780470045299: dict_keys(['kind', 'totalItems', 'items']): 1: eBay For Dummies
# 80   9780072262780: dict_keys(['kind', 'totalItems', 'items']): 1: What to Sell on eBay and Where to Get It
# 81   9780764569241: dict_keys(['kind', 'totalItems', 'items']): 1: Starting an eBay Business For Dummies
# 82   9780471933823: dict_keys(['kind', 'totalItems', 'items']): 1: eBay
# 83   9780764559914: dict_keys(['kind', 'totalItems', 'items']): 1: eBay Timesaving Techniques For Dummies
# 84   9780764584381: dict_keys(['kind', 'totalItems', 'items']): 1: eBay Business All-in-One Desk Reference For Dummies
# 85   9780596523695: dict_keys(['kind', 'totalItems', 'items']): 1: Ruby Cookbook
# 86   9780806523491: dict_keys(['kind', 'totalItems', 'items']): 1: Ruby Ann's Down Home Trailer Park Cookbook
# 87   9780806525365: dict_keys(['kind', 'totalItems', 'items']): 1: Ruby Ann's Down Home Trailer Park Bbqin' Cookbook
# 88   9780596527310: dict_keys(['kind', 'totalItems', 'items']): 1: Rails Cookbook
# 89   9780143035008: dict_keys(['kind', 'totalItems', 'items']): 2: Anna Karenina
# 90   9780451528612: dict_keys(['kind', 'totalItems', 'items']): 1: Anna Karenina
# 91   9780140449174: dict_keys(['kind', 'totalItems', 'items']): 1: Penguin Classics Anna Karenina
# 92   9780822001836: dict_keys(['kind', 'totalItems', 'items']): 2: CliffsNotes on Tolstoy's Anna Karenina
# 93   9781593080273: dict_keys(['kind', 'totalItems', 'items']): 1: Anna Karenina
# 94   9780486437965: dict_keys(['kind', 'totalItems', 'items']): 1: Anna Karenina
# 95   9781593081775: dict_keys(['kind', 'totalItems', 'items']): 1: Anna Karenina
# 96   9780778322276: dict_keys(['kind', 'totalItems', 'items']): 1: Dinner with Anna Karenina
# 97   9780521313254: dict_keys(['kind', 'totalItems', 'items']): 1: Tolstoy: Anna Karenina
# 98   9780140183955: dict_keys(['kind', 'totalItems', 'items']): 1: Untouchable
# 99   9780679767473: dict_keys(['kind', 'totalItems', 'items']): 1: The Untouchable
# 100   9781568491981: dict_keys(['kind', 'totalItems', 'items']): 1: The Untouchables
# 101   9780743270793: dict_keys(['kind', 'totalItems', 'items']): 1: Untouchables
# 102   9780932863058: dict_keys(['kind', 'totalItems', 'items']): 1: Dalit
# 103   9780742508804: dict_keys(['kind', 'totalItems', 'items']): 1: Growing Up Untouchable in India
# 104   9780205358625: dict_keys(['kind', 'totalItems', 'items']): 1: The Evidence-based Social Work Skills Book
# 105   9781557344038: dict_keys(['kind', 'totalItems', 'items']): 1: A Guide for Using A Wrinkle in Time in the Classroom, Based on the Book Written by Madeleine L'Engle
# 106   9780380720446: dict_keys(['kind', 'totalItems', 'items']): 1: Wrinkles in Time
# 107   9780821925324: dict_keys(['kind', 'totalItems', 'items']): 1: A Wrinkle in Time
# 108   9780439271691: dict_keys(['kind', 'totalItems', 'items']): 1: A Wrinkle in Time
# 109   9780606105262: dict_keys(['kind', 'totalItems', 'items']): 1: Una arruga en el tiempo
# 110   9780751506433: dict_keys(['kind', 'totalItems', 'items']): 1: The Long Shadow
# 111   9780060786717: dict_keys(['kind', 'totalItems', 'items']): 1: A Long Shadow
# 112   9780743499347: dict_keys(['kind', 'totalItems', 'items']): 1: Long Way Round
# 113   9780765313409: dict_keys(['kind', 'totalItems', 'items']): 1: A Shadow in Summer
# 114   9781400032495: dict_keys(['kind', 'totalItems', 'items']): 1: New Hope for the Dead
# 115   9781400032488: dict_keys(['kind', 'totalItems', 'items']): 1: Sideswipe
# 116   9781400032464: dict_keys(['kind', 'totalItems', 'items']): 1: Miami Blues
# 117   9780679732525: dict_keys(['kind', 'totalItems', 'items']): 1: The Burnt Orange Heresy
# 118   9780312424442: dict_keys(['kind', 'totalItems', 'items']): 1: I Am Charlotte Simmons
# 119   9780806930770: dict_keys(['kind', 'totalItems', 'items']): 1: Edward Lear
# 120   9780140366600: dict_keys(['kind', 'totalItems', 'items']): 1: The Puffin Book of Nonsense Verse
# 121   9780811201124: dict_keys(['kind', 'totalItems', 'items']): 2: Henry Miller on Writing
# 122   9780802130167: dict_keys(['kind', 'totalItems', 'items']): 1: Quiet Days in Clichy
# 123   9780802131782: dict_keys(['kind', 'totalItems', 'items']): 1: Tropic of Cancer
# 124   9780802151827: dict_keys(['kind', 'totalItems', 'items']): 1: Tropic of Capricorn
# 125   9780802151780: dict_keys(['kind', 'totalItems', 'items']): 2: The Rosy Crucifixion
# 126   9780802151803: dict_keys(['kind', 'totalItems', 'items']): 1: The Rosy Crucifixion: Sexus
# 127   9780811201063: dict_keys(['kind', 'totalItems', 'items']): 2: The Air-conditioned Nightmare
# 128   9780141439631: dict_keys(['kind', 'totalItems', 'items']): 1: The Portrait of a Lady
# 129   9781593080969: dict_keys(['kind', 'totalItems', 'items']): 1: The Portrait of a Lady
# 130   9781571290533: dict_keys(['kind', 'totalItems', 'items']): 1: Writing
# 131   9781565842212: dict_keys(['kind', 'totalItems', 'items']): 1: The War
# 132   9780394743042: dict_keys(['kind', 'totalItems', 'items']): 1: The Ravishing of Lol Stein
# 133   9781851681822: dict_keys(['kind', 'totalItems', 'items']): 1: Love Letters
# 134   9781566562492: dict_keys(['kind', 'totalItems', 'items']): 1: Kahlil Gibran
# 135   9780140195538: dict_keys(['kind', 'totalItems', 'items']): 1: The Beloved
# 136   9780394431246: dict_keys(['kind', 'totalItems', 'items']): 1: Jesus the Son of Man
# 137   9780806501901: dict_keys(['kind', 'totalItems', 'items']): 1: The Broken Wings
# 138   9780679439202: dict_keys(['kind', 'totalItems', 'items']): 1: Sand and Foam
# 139   9780753453803: dict_keys(['kind', 'totalItems', 'items']): 1: Treasure Island
# 140   9781402714573: dict_keys(['kind', 'totalItems', 'items']): 2: Unabridged: Treasure Island
# 141   9781416500292: dict_keys(['kind', 'totalItems', 'items']): 1: Treasure Island
# 142   9780689854682: dict_keys(['kind', 'totalItems', 'items']): 1: Treasure Island
# 143   9780517221143: dict_keys(['kind', 'totalItems', 'items']): 1: Treasure Island
# 144   9781577658054: dict_keys(['kind', 'totalItems', 'items']): 1: Treasure Island
# 145   9780933121188: dict_keys(['kind', 'totalItems', 'items']): 1: 100 Years of Lynchings
# 146   9780785950103: dict_keys(['kind', 'totalItems', 'items']): 1: Cien Años de Soledad
# 147   9780394800844: dict_keys(['kind', 'totalItems', 'items']): 1: On Beyond Zebra
# 148   9780821778258: dict_keys(['kind', 'totalItems', 'items']): 1: The Wedding Clause
# 149   9780060733032: dict_keys(['kind', 'totalItems', 'items']): 1: The Zebra Wall
# 150   9788432216060: dict_keys(['kind', 'totalItems', 'items']): 1: El perfume
# 151   9780345413994: dict_keys(['kind', 'totalItems', 'items']): 1: The Door Into Summer
# 152   9780441788385: dict_keys(['kind', 'totalItems', 'items']): 1: Stranger in a Strange Land
# 153   9780441748600: dict_keys(['kind', 'totalItems', 'items']): 1: To Sail Beyond the Sunset
# 154   9780345316509: dict_keys(['kind', 'totalItems', 'items']): 1: Job, a Comedy of Justice
# 155   9780765314932: dict_keys(['kind', 'totalItems', 'items']): 1: Time for the Stars
# 156   9780671742515: dict_keys(['kind', 'totalItems', 'items']): 1: Long Dark Tea-Time of the Soul
# 157   9780345455291: dict_keys(['error']):
# 158   9780345476517: dict_keys(['error']):
# 159   9780345368430: dict_keys(['kind', 'totalItems', 'items']): 1: Douglas Adams's Starship Titanic
# 160   9781417622856: dict_keys(['error']):
# 161   9780573650963: dict_keys(['kind', 'totalItems', 'items']): 1: The Phantom Tollbooth
# 162   9780691122946: dict_keys(['kind', 'totalItems', 'items']): 1: On Bullshit
# 163   9780393329407: dict_keys(['kind', 'totalItems', 'items']): 1: Another Bullshit Night in Suck City: A Memoir
# 164   9780671867423: dict_keys(['kind', 'totalItems', 'items']): 1: Lincoln at Gettysburg
# 165   9780395883976: dict_keys(['error']):
# 166   9780684848150: dict_keys(['kind', 'totalItems', 'items']): 1: Underworld
# 167   9780140156041: dict_keys(['error']):
# 168   9780140119480: dict_keys(['error']):
# 169   9780679722946: dict_keys(['error']):
# 170   9780743244251: dict_keys(['error']):
# 171   9780140179170: dict_keys(['error']):
# 172   9780679722953: dict_keys(['error']):
# 173   9781594201202: dict_keys(['error']):
# 174   9780060930219: dict_keys(['error']):
# 175   9780060931674: dict_keys(['kind', 'totalItems', 'items']): 1: The Crying of Lot 49
# 176   9780140283389: dict_keys(['kind', 'totalItems', 'items']): 1: Gravity's Rainbow
# 177   9780312423209: dict_keys(['error']):
# 178   9780141180632: dict_keys(['error']):
# 179   9780143039945: dict_keys(['kind', 'totalItems', 'items']): 1: Gravity's Rainbow (Classics Deluxe Edition)
# 180   9780316724432: dict_keys(['kind', 'totalItems', 'items']): 1: Slow Learner
# 181   9780140189308: dict_keys(['kind', 'totalItems', 'items']): 1: Been Down So Long it Looks Like Up to Me
# 182   9781400043149: dict_keys(['kind', 'totalItems', 'items']): 1: The Year of Magical Thinking
# 183   9780374522216: dict_keys(['kind', 'totalItems', 'items']): 1: The White Album
# 184   9780679754862: dict_keys(['kind', 'totalItems', 'items']): 1: A Book of Common Prayer
# 185   9780679752868: dict_keys(['kind', 'totalItems', 'items']): 1: Where I Was From
# 186   9780374521721: dict_keys(['error']):
# 187   9780679754855: dict_keys(['error']):
# 188   9780307264879: dict_keys(['error']):
# 189   9780374529949: dict_keys(['error']):
# 190   9780143039839: dict_keys(['kind', 'totalItems', 'items']): 1: The New York Trilogy
# 191   9780140097313: dict_keys(['kind', 'totalItems', 'items']): 2: City of Glass
# 192   9780140097351: dict_keys(['error']):
# 193   9780940650763: dict_keys(['error']):
# 194   9780963188922: dict_keys(['kind', 'totalItems', 'items']): 1: Pyramids of Montauk
# 195   9780312426231: dict_keys(['error']):
# 196   9780140115857: dict_keys(['error']):
# 197   9780140154078: dict_keys(['error']):
# 198   9780805081459: dict_keys(['kind', 'totalItems', 'items']): 1: Travels in the Scriptorium
# 199   9780140178135: dict_keys(['error']):
# 200   9780811214988: dict_keys(['error']):
# 201   9782742741465: dict_keys(['error']):
# 202   9780143036555: dict_keys(['kind', 'totalItems', 'items']): 1: Collapse
# 203   9780446579780: dict_keys(['error']):
# 204   9780521386739: dict_keys(['kind', 'totalItems', 'items']): 1: The Collapse of Complex Societies
# 205   9780743203043: dict_keys(['kind', 'totalItems', 'items']): 1: Bowling Alone
# 206   9780345438713: dict_keys(['kind', 'totalItems', 'items']): 1: The Collapse of the Common Good
# 207   9780393318289: dict_keys(['kind', 'totalItems', 'items']): 1: Reinventing the Enemy's Language
# 208   9781599869940: dict_keys(['kind', 'totalItems', 'items']): 1: My Inventions
# 209   9780806519609: dict_keys(['error']):
# 210   9780822549208: dict_keys(['error']):
# 211   9780932813862: dict_keys(['kind', 'totalItems', 'items']): 1: The Tesla Papers
# 212   9780373792689: dict_keys(['error']):
# 213   9780974514055: dict_keys(['error']):
# 214   9780764585975: dict_keys(['kind', 'totalItems', 'items']): 1: CliffsNotes on Golding's Lord of the Flies
# 215   9780307281708: dict_keys(['kind', 'totalItems']):
# 216   9780812969702: dict_keys(['error']):
# 217   9780060255084: dict_keys(['error']):
# 218   9780330485388: dict_keys(['error']):
# 219   9781594130236: dict_keys(['error']):
# 220   9780345360359: dict_keys(['error']):
# 221   785342303476: dict_keys(['kind', 'totalItems']):
# 222   9780321430847: dict_keys(['error']):
# 223   9783822840856: dict_keys(['kind', 'totalItems', 'items']): 1: 1000 Record Covers
# 224   9780743264464: dict_keys(['kind', 'totalItems', 'items']): 1: Killing Yourself to Live
# 225   9780743236010: dict_keys(['error']):
# 226   9780553572490: dict_keys(['error']):
# 227   9780060589462: dict_keys(['error']):
# 228   9780802789471: dict_keys(['error']):
# 229   9780688060695: dict_keys(['kind', 'totalItems', 'items']): 1: Guidebook to Zen and the Art of Motorcycle Maintenance
# 230   9781859605158: dict_keys(['error']):
# 231   9781592530878: dict_keys(['error']):
# 232   9780451528803: dict_keys(['error']):
# 233   9780192833983: dict_keys(['error']):
# 234   9780486451381: dict_keys(['error']):
# 235   9780452011878: dict_keys(['error']):
# 236   9780451163080: dict_keys(['error']):
# 237   9780452286757: dict_keys(['error']):
# 238   9780451163936: dict_keys(['kind', 'totalItems', 'items']): 1: The Virtue of Selfishness
# 239   9780452281257: dict_keys(['error']):
# 240   9780451187840: dict_keys(['kind', 'totalItems', 'items']): 1: We the Living
# 241   9780451147950: dict_keys(['error']):
# 242   9780452274044: dict_keys(['error']):
# 243   9780471791430: dict_keys(['error']):
# 244   9780553803815: dict_keys(['error']):
# 245   9780375755194: dict_keys(['kind', 'totalItems', 'items']): 1: Sailing Alone Around the Room
# 246   9781592283194: dict_keys(['error']):
# 247   9780975599518: dict_keys(['kind', 'totalItems', 'items']): 1: Natural Cures "they" Don't Want You to Know about
# 248   9780374502003: dict_keys(['kind', 'totalItems', 'items']): 1: The Natural
# 249   9780307263940: dict_keys(['kind', 'totalItems', 'items']): 1: Digging to America
# 250   9780312405540: dict_keys(['error']):
# 251   9780195170139: dict_keys(['error']):
# 252   9781400079490: dict_keys(['error']):
# 253   9780688171629: dict_keys(['error']):
# 254   9780060932688: dict_keys(['error']):
# 255   9781400034956: dict_keys(['error']):
# 256   9780307350428: dict_keys(['error']):
# 257   9780307350442: dict_keys(['error']):
# 258   9781400034543: dict_keys(['error']):
# 259   9781400095803: dict_keys(['error']):
# 260   9780375708114: dict_keys(['error']):
# 261   9780861714926: dict_keys(['kind', 'totalItems', 'items']): 1: Pure and Simple
# 262   9781843535843: dict_keys(['error']):
# 263   9781740594776: dict_keys(['error']):
# 264   9788408064763: dict_keys(['error']):
# 265   9781740592055: dict_keys(['kind', 'totalItems', 'items']): 1: Out to Eat
# 266   9780618710539: dict_keys(['kind', 'totalItems', 'items']): 1: Three Nights in August
# 267   9780060512804: dict_keys(['kind', 'totalItems', 'items']): 1: Cryptonomicon
# 268   9782228894166: dict_keys(['error']):
# 269   9780060733353: dict_keys(['kind', 'totalItems', 'items']): 1: The Confusion
# 270   9780060593087: dict_keys(['kind', 'totalItems', 'items']): 1: Quicksilver
# 271   9780553383447: dict_keys(['error']):
# 272   9780380816033: dict_keys(['error']):
# 273   9780553380965: dict_keys(['kind', 'totalItems', 'items']): 2: The Diamond Age
# 274   9780553383430: dict_keys(['kind', 'totalItems', 'items']): 1: Interface
# 275   9780060833183: dict_keys(['kind', 'totalItems', 'items']): 1: Odalisque
# 276   9780553380958: dict_keys(['error']):
# 277   9781880685358: dict_keys(['kind', 'totalItems', 'items']): 2: Harrington on Hold 'em: The endgame
# 278   9781880685334: dict_keys(['error']):
# 279   9780465067107: dict_keys(['kind', 'totalItems']):
# 280   9780465051366: dict_keys(['kind', 'totalItems']):
# 281   9780465067091: dict_keys(['error']):
# 282   9780898709193: dict_keys(['kind', 'totalItems', 'items']): 1: No Price Too High
# 283   9780060887964: dict_keys(['kind', 'totalItems']):
# 284   9780061122415: dict_keys(['error']):
# 285   9781421504605: dict_keys(['kind', 'totalItems', 'items']): 2: Fullmetal Alchemist, Vol. 9
# 286   9781591169253: dict_keys(['error']):
# 287   9781421504599: dict_keys(['kind', 'totalItems']):
# 288   9781591169208: dict_keys(['kind', 'totalItems', 'items']): 1: Fullmetal Alchemist, Vol. 1
# 289   9781591169291: dict_keys(['error']):
# 290   9780060192501: dict_keys(['error']):
# 291   9781591169239: dict_keys(['kind', 'totalItems']):
# 292   9780812974614: dict_keys(['error']):
# 293   9781587157394: dict_keys(['kind', 'totalItems', 'items']): 1: The Last Days of Pompeii
# 294   9780142000670: dict_keys(['error']):
# 295   9780060554736: dict_keys(['error']):
# 296   9780142401200: dict_keys(['kind', 'totalItems', 'items']): 1: The Westing Game (Puffin Modern Classics)
# 297   9780808553038: dict_keys(['error']):
# 298   9781400096893: dict_keys(['error']):
# 299   9780739326220: dict_keys(['error']):
# 300   9780099498186: dict_keys(['error']):
# 301   9781557046833: dict_keys(['error']):
# 302   9780099771517: dict_keys(['kind', 'totalItems', 'items']): 1: Memoirs of a Geisha
# 303   9780743430593: dict_keys(['error']):
# 304   9781932664393: dict_keys(['kind', 'totalItems', 'items']): 1: Han'guk-sik Sarang
# 305   9780521750844: dict_keys(['error']):
# 306   9780802415318: dict_keys(['error']):
# 307   9781416524793: dict_keys(['error']):
# 308   9788495618771: dict_keys(['error']):
# 309   9780972859899: dict_keys(['error']):
# 310   9780307277671: dict_keys(['error']):
# 311   9780767926034: dict_keys(['error']):
# 312   9782266144346: dict_keys(['error']):
# 313   9781416524809: dict_keys(['kind', 'totalItems', 'items']): 1: Deception Point
# 314   9780552151764: dict_keys(['kind', 'totalItems', 'items']): 1: Deception Point
# 315   9780593055076: dict_keys(['error']):
# 316   9780786016068: dict_keys(['error']):
# 317   9780671015206: dict_keys(['error']):
# 318   9781585424337: dict_keys(['error']):
# 319   9781932429237: dict_keys(['kind', 'totalItems', 'items']): 1: Think and Grow Rich: The 21st-Century Edition
# 320   9780977616657: dict_keys(['kind', 'totalItems', 'items']): 1: Pragmatic Version Control Using Subversion
# 321   9781563410901: dict_keys(['kind', 'totalItems', 'items']): 1: Read My Lips
# 322   9780345479174: dict_keys(['kind', 'totalItems', 'items']): 1: Trump
# 323   9780451205360: dict_keys(['kind', 'totalItems', 'items']): 1: The Richest Man in Babylon
# 324   9781419349997: dict_keys(['kind', 'totalItems']):
# 325   9781400098033: dict_keys(['kind', 'totalItems', 'items']): 1: Shibumi
# 326   9780743226721: dict_keys(['kind', 'totalItems', 'items']): 1: Seventeen Seventy-six
# 327   9780140481396: dict_keys(['error']):
# 328   9780226014906: dict_keys(['kind', 'totalItems', 'items']): 1: The Crescent Obscured
# 329   9781416500186: dict_keys(['kind', 'totalItems', 'items']): 1: The Good Earth
# 330   9780310258971: dict_keys(['error']):
# 331   9780060838584: dict_keys(['kind', 'totalItems', 'items']): 1: Fast Food Nation
# 332   9780141006871: dict_keys(['kind', 'totalItems', 'items']): 1: Fast Food Nation
# 333   9780812968064: dict_keys(['kind', 'totalItems', 'items']): 1: Snow Flower and the Secret Fan
# 334   9780385340540: dict_keys(['error']):
# 335   9780394720241: dict_keys(['kind', 'totalItems', 'items']): 2: The Power Broker
# 336   9780345480606: dict_keys(['kind', 'totalItems', 'items']): 1: The Power Broker
# 337   9780060193393: dict_keys(['kind', 'totalItems', 'items']): 1: Body For Life
# 338   9781579546014: dict_keys(['error']):
# 339   9780972018418: dict_keys(['error']):
# 340   9780471743675: dict_keys(['kind', 'totalItems', 'items']): 1: The Warren Buffett Way
# 341   9780471430452: dict_keys(['kind', 'totalItems', 'items']): 1: The Warren Buffett CEO
# 342   9780805431575: dict_keys(['kind', 'totalItems', 'items']): 1: Monkey Business
# 343   9780679838869: dict_keys(['kind', 'totalItems', 'items']): 2: Junie B. Jones #2: Junie B. Jones and a Little Monkey Business
# 344   9780373250714: dict_keys(['kind', 'totalItems', 'items']): 1: Monkey Business
# 345   9780140143454: dict_keys(['kind', 'totalItems', 'items']): 1: Liar's Poker
# 346   9780802732293: dict_keys(['error']):
# 347   694055000612: dict_keys(['error']):
# 348   9780307238276: dict_keys(['kind', 'totalItems', 'items']): 1: Giada's Family Dinners
# 349   9781400052585: dict_keys(['kind', 'totalItems', 'items']): 1: Everyday Italian
# 350   9780307346582: dict_keys(['kind', 'totalItems', 'items']): 1: Everyday Pasta
# 351   9781400052387: dict_keys(['kind', 'totalItems', 'items']): 1: Tyler's Ultimate
# 352   9780609609972: dict_keys(['kind', 'totalItems', 'items']): 1: Tyler Florence's Real Kitchen
# 353   9781400052370: dict_keys(['error']):
# 354   9780061234002: dict_keys(['kind', 'totalItems', 'items']): 1: Freakonomics Rev Ed
# 355   9788466625128: dict_keys(['kind', 'totalItems', 'items']): 1: Freakonomics
# 356   9780061245138: dict_keys(['kind', 'totalItems', 'items']): 1: Freakonomics Rev Ed LP
# 357   9780399153594: dict_keys(['error']):
# 358   9780156030205: dict_keys(['kind', 'totalItems', 'items']): 1: Book Club
# 359   9780828808392: dict_keys(['kind', 'totalItems', 'items']): 1: Lexicon of Pasta, 1982
# 360   9780140285970: dict_keys(['kind', 'totalItems', 'items']): 1: Shadows and Wind
# 361   9780307276902: dict_keys(['kind', 'totalItems', 'items']): 1: A Million Little Pieces
# 362   9781411677319: dict_keys(['kind', 'totalItems', 'items']): 1: A Million Little Pieces of Feces
# 363   9780061171468: dict_keys(['kind', 'totalItems', 'items']): 1: A Million Little Lies
# 364   9780787968335: dict_keys(['error']):
# 365   9780446394598: dict_keys(['error']):
# 366   9780131494848: dict_keys(['kind', 'totalItems', 'items']): 1: Leadership in Organizations
# 367   9780316861014: dict_keys(['kind', 'totalItems', 'items']): 1: Leadership
# 368   9780060574215: dict_keys(['error']):
# 369   9780060192778: dict_keys(['kind', 'totalItems', 'items']): 1: Mars and Venus Book of Days
# 370   9780061232053: dict_keys(['kind', 'totalItems']):
# 371   9780735200302: dict_keys(['kind', 'totalItems', 'items']): 1: How to Succeed with Women
# 372   9780553381672: dict_keys(['kind', 'totalItems', 'items']): 2: The Clan of the Cave Bear
# 373   9780517542026: dict_keys(['kind', 'totalItems', 'items']): 1: The Clan of the Cave Bear
# 374   9780393324815: dict_keys(['kind', 'totalItems', 'items']): 1: Moneyball: The Art of Winning an Unfair Game
# 375   9780744005615: dict_keys(['kind', 'totalItems', 'items']): 1: Juiced
# 376   9780140280197: dict_keys(['kind', 'totalItems', 'items']): 1: The 48 Laws of Power
# 377   9780553383683: dict_keys(['kind', 'totalItems', 'items']): 1: Gates of Fire
# 378   9780553295412: dict_keys(['kind', 'totalItems', 'items']): 1: Fire Sea
# 379   9780812590104: dict_keys(['kind', 'totalItems', 'items']): 1: The Gate of Fire
# 380   9780385516419: dict_keys(['kind', 'totalItems', 'items']): 1: The Afghan Campaign
# 381   9780553381399: dict_keys(['kind', 'totalItems', 'items']): 1: Tides of War
# 382   9780553382044: dict_keys(['kind', 'totalItems', 'items']): 1: Last of the Amazons
# 383   9780446691437: dict_keys(['kind', 'totalItems', 'items']): 1: The War of Art
# 384   9780826413017: dict_keys(['kind', 'totalItems', 'items']): 1: Gita on the Green
# 385   9780811701648: dict_keys(['error']):
# 386   9780140442755: dict_keys(['kind', 'totalItems', 'items']): 1: Phaedrus
# 387   9780192802774: dict_keys(['kind', 'totalItems', 'items']): 1: Phaedrus
# 388   9780140449747: dict_keys(['kind', 'totalItems', 'items']): 1: Phaedrus
# 389   9780879756321: dict_keys(['kind', 'totalItems', 'items']): 1: On Homosexuality
# 390   9781890318239: dict_keys(['error']):
# 391   9780872207882: dict_keys(['kind', 'totalItems', 'items']): 1: Plato on Love
# 392   9780801435300: dict_keys(['kind', 'totalItems', 'items']): 1: "Gorgias" and "Phaedrus"
# 393   9780872204621: dict_keys(['kind', 'totalItems', 'items']): 1: Statesman
# 394   9780140449044: dict_keys(['kind', 'totalItems', 'items']): 1: Gorgias
# 395   9780140449082: dict_keys(['kind', 'totalItems', 'items']): 1: The Histories
# 396   9780140446388: dict_keys(['kind', 'totalItems', 'items']): 1: The Histories
# 397   9780879757779: dict_keys(['kind', 'totalItems', 'items']): 1: The History
# 398   9780192824257: dict_keys(['kind', 'totalItems', 'items']): 1: The Histories
# 399   9780140440348: dict_keys(['kind', 'totalItems', 'items']): 2: The Histories
# 400   9780393959468: dict_keys(['kind', 'totalItems', 'items']): 1: Herodotus
# 401   9780375400612: dict_keys(['error']):
# 402   9780226327709: dict_keys(['error']):
# 403   9780140275360: dict_keys(['kind', 'totalItems', 'items']): 1: The Iliad
# 404   9780872203525: dict_keys(['kind', 'totalItems', 'items']): 1: Iliad
# 405   9780374529055: dict_keys(['kind', 'totalItems', 'items']): 1: The Iliad
# 406   9780147712554: dict_keys(['kind', 'totalItems', 'items']): 1: Iliad and Odyssey Boxed Set
# 407   9780140447941: dict_keys(['kind', 'totalItems', 'items']): 1: The Iliad
# 408   9780451527370: dict_keys(['kind', 'totalItems', 'items']): 1: The Iliad
# 409   9780872205420: dict_keys(['error']):
# 410   9780143039952: dict_keys(['kind', 'totalItems', 'items']): 1: The Odyssey
# 411   9780374525743: dict_keys(['kind', 'totalItems']):
# 412   9780060931957: dict_keys(['error']):
# 413   9780140449112: dict_keys(['error']):
# 414   9780451527363: dict_keys(['kind', 'totalItems', 'items']): 1: The Odyssey
# 415   9780865165847: dict_keys(['kind', 'totalItems', 'items']): 1: Vergil's Aeneid
# 416   9780674995833: dict_keys(['kind', 'totalItems', 'items']): 27: Eclogues. Georgics. Aeneid
# 417   9781891190230: dict_keys(['error']):
# 418   9780192837684: dict_keys(['error']):
# 419   9781558321250: dict_keys(['kind', 'totalItems', 'items']): 1: Paul Kirk's Championship Barbecue Sauces
# 420   9780141000589: dict_keys(['kind', 'totalItems', 'items']): 2: The Complete Pelican Shakespeare
# 421   9780517092941: dict_keys(['kind', 'totalItems', 'items']): 1: William Shakespeare, the Complete Works
# 422   9780521618748: dict_keys(['kind', 'totalItems', 'items']): 1: Hamlet
# 423   9781557831576: dict_keys(['kind', 'totalItems', 'items']): 1: The Reduced Shakespeare Company's the Complete Works of William Shakespeare (abridged)
# 424   9780062512796: dict_keys(['kind', 'totalItems', 'items']): 1: The Pilgrimage
# 425   9780062513342: dict_keys(['kind', 'totalItems', 'items']): 1: The Valkyries
# 426   9780060527983: dict_keys(['kind', 'totalItems', 'items']): 1: Warrior of the Light
# 427   9780060832810: dict_keys(['kind', 'totalItems', 'items']): 1: The Zahir
# 428   9780061122095: dict_keys(['error']):
# 429   9780060930134: dict_keys(['kind', 'totalItems', 'items']): 1: The Fifth Mountain
# 430   9780061124266: dict_keys(['kind', 'totalItems', 'items']): 1: Veronika Decides to Die
# 431   9780140714548: dict_keys(['kind', 'totalItems', 'items']): 2: The Tragical History of Hamlet Prince of Denmark
# 432   9780764586033: dict_keys(['kind', 'totalItems', 'items']): 2: CliffsNotes on Shakespeare's Hamlet
# 433   9780764585685: dict_keys(['kind', 'totalItems', 'items']): 2: CliffsComplete Hamlet
# 434   9780879232153: dict_keys(['error']):
# 435   9780674991200: dict_keys(['kind', 'totalItems', 'items']): 4: Thucydides: Books VII and VIII
# 436   9780872201682: dict_keys(['kind', 'totalItems', 'items']): 1: On Justice, Power, and Human Nature
# 437   9780674991224: dict_keys(['kind', 'totalItems', 'items']): 1: History of the Peloponnesian War
# 438   9780872203945: dict_keys(['error']):
# 439   9780393971675: dict_keys(['kind', 'totalItems', 'items']): 1: The Peloponnesian War
# 440   9780674991873: dict_keys(['kind', 'totalItems', 'items']): 4: Thucydides
# 441   9780929524351: dict_keys(['error']):
# 442   9780226307800: dict_keys(['error']):
# 443   9780226307848: dict_keys(['kind', 'totalItems', 'items']): 1: Euripides
# 444   9780226307831: dict_keys(['error']):
# 445   9781590171806: dict_keys(['kind', 'totalItems', 'items']): 1: Grief Lessons
# 446   9780553213638: dict_keys(['kind', 'totalItems', 'items']): 1: Ten Plays by Euripides
# 447   9780226307824: dict_keys(['kind', 'totalItems', 'items']): 1: Hecuba
# 448   9780226307817: dict_keys(['error']):
# 449   9780140449297: dict_keys(['error']):
# 450   9780674995604: dict_keys(['kind', 'totalItems', 'items']): 29: Euripides
# 451   9780521643863: dict_keys(['error']):
# 452   9780140447262: dict_keys(['error']):
# 453   9780195125986: dict_keys(['error']):
# 454   9780413752802: dict_keys(['kind', 'totalItems', 'items']): 1: Euripides Plays: 1
# 455   9780486424620: dict_keys(['error']):
# 456   9780393325836: dict_keys(['error']):
# 457   9780192832603: dict_keys(['error']):
# 458   9780674995338: dict_keys(['kind', 'totalItems', 'items']): 20: Children of Heracles
# 459   9780195061666: dict_keys(['error']):
# 460   9780674995666: dict_keys(['error']):
# 461   9780195145663: dict_keys(['error']):
# 462   9780715631874: dict_keys(['error']):
# 463   9780822004240: dict_keys(['error']):
# 464   9780674995741: dict_keys(['error']):
# 465   9780674996007: dict_keys(['error']):
# 466   9780715629949: dict_keys(['error']):
# 467   9780226307664: dict_keys(['kind', 'totalItems', 'items']): 1: The Complete Greek Tragedies: Euripides
# 468   9780226307787: dict_keys(['kind', 'totalItems', 'items']): 4: Aeschylus I
# 469   9780226307947: dict_keys(['kind', 'totalItems', 'items']): 2: Aeschylus II
# 470   9780195135923: dict_keys(['error']):
# 471   9780140443332: dict_keys(['error']):
# 472   9780872203907: dict_keys(['error']):
# 473   9780140441123: dict_keys(['error']):
# 474   9780374527051: dict_keys(['kind', 'totalItems', 'items']): 1: The Oresteia of Aeschylus
# 475   9780812216271: dict_keys(['error']):
# 476   9780226307640: dict_keys(['error']):
# 477   9780521539814: dict_keys(['error']):
# 478   9781400041923: dict_keys(['error']):
# 479   9780812216714: dict_keys(['error']):
# 480   9780486292427: dict_keys(['error']):
# 481   9781419150012: dict_keys(['kind', 'totalItems']):
# 482   9780226307862: dict_keys(['kind', 'totalItems', 'items']): 2: The Complete Greek Tragedies
# 483   9780452011670: dict_keys(['kind', 'totalItems', 'items']): 2: The Oedipus Plays of Sophocles
# 484   9780451527844: dict_keys(['error']):
# 485   9780156027649: dict_keys(['error']):
# 486   9780140444254: dict_keys(['error']):
# 487   9780872205857: dict_keys(['kind', 'totalItems', 'items']): 1: Theban Plays
# 488   9780679431329: dict_keys(['kind', 'totalItems', 'items']): 1: The Theban Plays
# 489   9780140440287: dict_keys(['kind', 'totalItems', 'items']): 1: Electra and Other Plays
# 490   9780192835888: dict_keys(['kind', 'totalItems', 'items']): 1: Antigone ; Oedipus the King ; Electra
# 491   9781580495936: dict_keys(['kind', 'totalItems', 'items']): 1: Oedipus Rex
# 492   9780451621603: dict_keys(['kind', 'totalItems', 'items']): 1: The Oedipus Plays of Sophocles
# 493   9780521617352: dict_keys(['kind', 'totalItems', 'items']): 1: Sophocles: Oedipus Rex
# 494   9781416500339: dict_keys(['error']):
# 495   9780452007178: dict_keys(['error']):
# 496   9780415907446: dict_keys(['error']):
# 497   9780553213430: dict_keys(['error']):
# 498   9780812234565: dict_keys(['error']):
# 499   9780872203617: dict_keys(['error']):
# 500   9780140448146: dict_keys(['error']):
# 501   9781585100873: dict_keys(['kind', 'totalItems', 'items']): 1: Acharnians
# 502   9780199120093: dict_keys(['error']):
# 503   9780674995376: dict_keys(['kind', 'totalItems', 'items']): 21: Aristophanes
# 504   9780140441529: dict_keys(['error']):
# 505   9780156027656: dict_keys(['error']):
# 506   9780674995963: dict_keys(['error']):
# 507   49086007763: dict_keys(['error']):
# 508   9780198721598: dict_keys(['error']):
# 509   9780451616227: dict_keys(['error']):
# 510   9780198140818: dict_keys(['kind', 'totalItems', 'items']): 1: Aristophanes' Peace
# 511   9780872206038: dict_keys(['error']):
# 512   9780140443325: dict_keys(['error']):
# 513   9780521774338: dict_keys(['kind', 'totalItems', 'items']): 1: Genres in Dialogue
# 514   9781400032716: dict_keys(['kind', 'totalItems', 'items']): 1: The Curious Incident of the Dog in the Night-Time
# 515   9780316156509: dict_keys(['error']):
# 516   9780743482776: dict_keys(['error']):
# 517   9780743271325: dict_keys(['kind', 'totalItems', 'items']): 1: Brokeback Mountain
# 518   9780142000281: dict_keys(['kind', 'totalItems', 'items']): 1: Getting Things Done
# 519   9781576751725: dict_keys(['error']):
# 520   9788433924636: dict_keys(['error']):
# 521   9788433968777: dict_keys(['error']):
# 522   9781862076655: dict_keys(['error']):
# 523   9788433924711: dict_keys(['error']):
# 524   9788433924629: dict_keys(['error']):
# 525   9780321317100: dict_keys(['error']):
# 526   9780321365200: dict_keys(['error']):
# 527   9788432216428: dict_keys(['kind', 'totalItems']):
# 528   9781565480841: dict_keys(['kind', 'totalItems', 'items']): 2: The Works of Saint Augustine: v. 1. The confessions
# 529   9780679783190: dict_keys(['error']):
# 530   9781565481244: dict_keys(['error']):
# 531   9780520227576: dict_keys(['error']):
# 532   9780024021502: dict_keys(['error']):
# 533   9780872201866: dict_keys(['kind', 'totalItems', 'items']): 1: Confessions
# 534   9780143035985: dict_keys(['kind', 'totalItems', 'items']): 1: Saint Augustine
# 535   9780192854520: dict_keys(['error']):
# 536   9781565482012: dict_keys(['error']):
# 537   9780060934910: dict_keys(['kind', 'totalItems', 'items']): 1: Kitchen Confidential
# 538   9788466308953: dict_keys(['error']):
# 539   9780156001267: dict_keys(['kind', 'totalItems', 'items']): 1: The Metamorphoses of Ovid
# 540   9780140447897: dict_keys(['kind', 'totalItems', 'items']): 1: Metamorphoses
# 541   9780393058109: dict_keys(['kind', 'totalItems', 'items']): 1: Metamorphoses
# 542   9780806128948: dict_keys(['error']):
# 543   9780806114569: dict_keys(['error']):
# 544   9780814317327: dict_keys(['error']):
# 545   9780674992559: dict_keys(['kind', 'totalItems', 'items']): 26: Ovid
# 546   9780520242609: dict_keys(['kind', 'totalItems', 'items']): 1: The Poems of Exile
# 547   9780674990470: dict_keys(['error']):
# 548   9780674990463: dict_keys(['kind', 'totalItems', 'items']): 55: Metamorphoses
# 549   9780814326114: dict_keys(['kind', 'totalItems', 'items']): 1: Practice! Practice!
# 550   9780806115603: dict_keys(['error']):
# 551   9780691015972: dict_keys(['error']):
# 552   9780195143102: dict_keys(['error']):
# 553   9780195143737: dict_keys(['error']):
# 554   9780130158857: dict_keys(['error']):
# 555   9781857150605: dict_keys(['kind', 'totalItems', 'items']): 1: The Iliad
# 556   9780226301198: dict_keys(['error']):
# 557   9780521315791: dict_keys(['error']):
# 558   9780521011761: dict_keys(['error']):
# 559   9780521479349: dict_keys(['error']):
# 560   9781585424832: dict_keys(['error']):
# 561   9780767907439: dict_keys(['error']):
# 562   9780743233217: dict_keys(['kind', 'totalItems', 'items']): 1: Them
# 563   9780743270601: dict_keys(['error']):
# 564   9780393061314: dict_keys(['error']):
# 565   9780865475090: dict_keys(['error']):
# 566   9780385486804: dict_keys(['kind', 'totalItems', 'items']): 2: Into the Wild
# 567   9780785268833: dict_keys(['kind', 'totalItems', 'items']): 1: Wild at Heart
# 568   9780743246989: dict_keys(['error']):
# 569   9780446579674: dict_keys(['kind', 'totalItems', 'items']): 1: Born in Death
# 570   9780515142396: dict_keys(['error']):
# 571   9780439227148: dict_keys(['error']):
# 572   9780375825385: dict_keys(['kind', 'totalItems', 'items']): 1: Wild About Books
# 573   9781591583660: dict_keys(['kind', 'totalItems', 'items']): 1: Crash Course in Web Design for Libraries
# 574   9780805063899: dict_keys(['kind', 'totalItems', 'items']): 1: Nickel and Dimed
# 575   9780394417752: dict_keys(['kind', 'totalItems', 'items']): 3: The History of Sexuality: An introduction
# 576   9780140268683: dict_keys(['error']):
# 577   9780140137347: dict_keys(['error']):
# 578   9780140251579: dict_keys(['kind', 'totalItems', 'items']): 1: The Making of Pride and Prejudice
# 579   9780192802385: dict_keys(['error']):
# 580   9780143036234: dict_keys(['kind', 'totalItems', 'items']): 1: Pride and Prejudice
# 581   9780486440910: dict_keys(['error']):
# 582   9781593083243: dict_keys(['error']):
# 583   9781400032808: dict_keys(['error']):
# 584   9780375752674: dict_keys(['error']):
# 585   9780385494786: dict_keys(['error']):
# 586   9780679783619: dict_keys(['kind', 'totalItems', 'items']): 1: In the Land of White Death
# 587   9780374292799: dict_keys(['kind', 'totalItems', 'items']): 1: The World Is Flat [Updated and Expanded]
# 588   9788427032224: dict_keys(['error']):
# 589   9780898868098: dict_keys(['kind', 'totalItems', 'items']): 1: The Avalanche Handbook
# 590   9780590422673: dict_keys(['error']):
# 591   9780451529305: dict_keys(['error']):
# 592   9781402714580: dict_keys(['kind', 'totalItems', 'items']): 1: Little Women
# 593   9780439101363: dict_keys(['error']):
# 594   9780517221167: dict_keys(['error']):
# 595   9781931082730: dict_keys(['error']):
# 596   9781904633273: dict_keys(['kind', 'totalItems', 'items']): 1: Little Women
# 597   9780743487603: dict_keys(['error']):
# 598   9781593081386: dict_keys(['kind', 'totalItems', 'items']): 1: A Tale of Two Cities
# 599   9781586633523: dict_keys(['error']):
# 600   9781593080556: dict_keys(['error']):
# 601   9781857151435: dict_keys(['kind', 'totalItems', 'items']): 1: A Tale of Two Cities
# 602   9780671792275: dict_keys(['error']):
# 603   9781405228183: dict_keys(['error']):
# 604   9780517093399: dict_keys(['error']):
# 605   9780375760051: dict_keys(['kind', 'totalItems', 'items']): 1: Bleak House
# 606   9780451530042: dict_keys(['error']):
# 607   9780671882365: dict_keys(['kind', 'totalItems', 'items']): 1: What Jane Austen Ate and Charles Dickens Knew
# 608   9780670030774: dict_keys(['error']):
# 609   9780140436143: dict_keys(['error']):
# 610   9780465031269: dict_keys(['kind', 'totalItems', 'items']): 1: Why Is Sex Fun?
# 611   9780060183073: dict_keys(['error']):
# 612   9780822533894: dict_keys(['kind', 'totalItems', 'items']): 1: J.K. Rowling
# 613   9780439321624: dict_keys(['error']):
# 614   9780826452320: dict_keys(['kind', 'totalItems', 'items']): 1: JK Rowling's Harry Potter Novels
# 615   9780747584667:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/w2/c53crljd2y523fsqplb9bml00000gp/T/ipykernel_6462/1140953692.py in <module>
#      11
#      12     # get the book data; convert it to a dictionary using .json()
# ---> 13     book_data = requests.get(url).json()
#      14
#      15     print(book_data.keys(), end=': ')
#
# ~/Library/Python/3.8/lib/python/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/Library/Python/3.8/lib/python/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/Library/Python/3.8/lib/python/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# ~/Library/Python/3.8/lib/python/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# ~/Library/Python/3.8/lib/python/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438         try:
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#     442                     url=url,
#
# ~/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/Library/Python/3.8/lib/python/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in getresponse(self)
#    1320         try:
#    1321             try:
# -> 1322                 response.begin()
#    1323             except ConnectionError:
#    1324                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Using Google Books API to fix missing data in Kaggle Dataset

# %%
# get the faulty ISBN
isbn = isbn_13.loc[0]
print(isbn)

# url for the book
url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn}"

# get the book
response = requests.get(url)

# convert the HTTP Response object to a dict
json = response.json()

# get the keys for the dict
json.keys()
# Out:
# 9780439785969
# dict_keys(['kind', 'totalItems'])

# %%
print(f'in_google: {in_google}\nnot_in_google: {not_in_google}')
# Out:
# in_google: 575
# not_in_google: 318

# %%
json['items'][0]['volumeInfo']
# Out:
# {'title': "The Ultimate Hitchhiker's Guide",
#  'authors': ['Douglas Adams'],
#  'publisher': 'Wings',
#  'publishedDate': '1996',
#  'description': '6 Science fiction-romaner.',
#  'industryIdentifiers': [{'type': 'OTHER',
#    'identifier': 'UOM:39015060636746'}],
#  'readingModes': {'text': False, 'image': False},
#  'pageCount': 840,
#  'printType': 'BOOK',
#  'categories': ['Dent, Arthur (Fictitious character)'],
#  'averageRating': 4.5,
#  'ratingsCount': 16,
#  'maturityRating': 'NOT_MATURE',
#  'allowAnonLogging': False,
#  'contentVersion': '0.2.2.0.preview.0',
#  'panelizationSummary': {'containsEpubBubbles': False,
#   'containsImageBubbles': False},
#  'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=oL1lAAAAMAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#   'thumbnail': 'http://books.google.com/books/content?id=oL1lAAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#  'language': 'en',
#  'previewLink': 'http://books.google.com/books?id=oL1lAAAAMAAJ&dq=isbn:9780517149256&hl=&cd=1&source=gbs_api',
#  'infoLink': 'http://books.google.com/books?id=oL1lAAAAMAAJ&dq=isbn:9780517149256&hl=&source=gbs_api',
#  'canonicalVolumeLink': 'https://books.google.com/books/about/The_Ultimate_Hitchhiker_s_Guide.html?hl=&id=oL1lAAAAMAAJ'}
